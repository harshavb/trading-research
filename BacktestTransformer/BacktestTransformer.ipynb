# %% [markdown]
# ##### Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
import keras
from keras import layers
from keras import Input
from keras import Model
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping

# %% [markdown]
# ##### Miscellaneous

# %%
# Used for interactive plots (zooming in)
# %matplotlib widget

np.set_printoptions(threshold=np.inf, linewidth=300)

tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Data acquisition method

# %% [markdown]
# ##### Load from file (obtained through data extraction tool)

# %%
def get_stock_data_and_period_csv(filepath: str):
    df = pd.read_csv(filepath)

    start_date = df['Date'].iloc[0]
    end_date = df['Date'].iloc[-1]

    print('Time Period: ' + str(start_date) + ' to ' + str(end_date))

    return df, start_date, end_date

# %% [markdown]
# # Data Transform

# %%
def dataframe_copy(df: pd.DataFrame):
    df_copy = df.copy()
    return df_copy

# %%
def dataframe_clean(df: pd.DataFrame):
    clean_df = df.dropna()
    clean_df = clean_df.drop(['Date'], axis=1)  # we remove 'Date' here so the original data is untouched.
    return clean_df

# %%
def dataframe_stats(df: pd.DataFrame):
    print(df.shape)
    print(df.columns)
    print(df.isnull().sum())

# %% [markdown]
# ##### Preparing data for loading into model

# %%
def set_column_as_first(df: pd.DataFrame, col_name: str):
    col_loc = df.columns.get_loc(col_name)
    if col_loc != 0:
        cols = list(df.columns)
        a, b = cols.index(col_name), cols.index(df.columns[0])
        cols[b], cols[a] = cols[a], cols[b]
        df = df[cols]
    
    return df

# %%
# used for plotting purposes
def scaler_fit_column(df: pd.DataFrame, target: str = 'Close'):
    scaler = MinMaxScaler(feature_range=(0, 1))   # fit to data, used by graphs to plot prices instead of values in the (0, 1) range
    scaler.fit(df[[target]])

    return scaler

# %%
def transform_data(df: pd.DataFrame):
    # Scale the data
    cols = df.columns

    scaler = MinMaxScaler(feature_range=(0, 1))
    df_scaled = scaler.fit_transform(df)    # fit and transform for all data
    df_scaled = pd.DataFrame(df_scaled)
    df_scaled.columns = cols

    return df_scaled

# %%
# by default, the target is the 'Close' price of the stock
def get_features_and_target(df: pd.DataFrame, target: str = 'Close'):
    df_features = df
    df_target = df[[target]]

    return df_features, df_target

# %% [markdown]
# ##### Train Data Setup

# %%
def setup_train_data(features: pd.DataFrame, target: pd.DataFrame, train_data_percent: float = 0.8):
    train_data_len = math.ceil(len(features.to_numpy()) * train_data_percent)

    train_x = features[0:train_data_len].to_numpy()
    train_y = target[0:train_data_len].to_numpy()

    return train_x, train_y, train_data_len

# %%
def prepare_train_as_sliding_window(train_x, train_y, sliding_window_size: int = 5):
    x_train_sw = []
    y_train_sw = []

    # The sliding window size (in days) we use as input. There are 5 trading days in a week
    for i in range(sliding_window_size, len(train_x)):
        x_train_sw.append(train_x[i-sliding_window_size:i,:])
        y_train_sw.append(train_y[i:i+1, 0])

    x_train_sw, y_train_sw = np.array(x_train_sw), np.array(y_train_sw)   # convert to numpy array

    return x_train_sw, y_train_sw

# %%
def setup_test_data(features, target, train_data_len):
    test_x = features[train_data_len:].to_numpy()
    test_y = target[train_data_len:].to_numpy()

    return test_x, test_y

# %%
def prepare_test_as_sliding_window(test_x, test_y, sliding_window_size: int = 5):
    x_test_sw = []  # features
    y_test_sw = []  # target
    y_remaining = []    # features remaining

    for i in range(sliding_window_size, len(test_x)):
        x_test_sw.append(test_x[i-sliding_window_size:i,:])
        y_test_sw.append(test_y[i:i+1,0])
        y_remaining.append(test_x[i:i+1,1:])

    x_test_sw = np.array(x_test_sw)
    y_test_sw = np.array(y_test_sw)
    y_remaining = np.array(y_remaining)

    return x_test_sw, y_test_sw, y_remaining

# %% [markdown]
# # Transformer Model

# %%
def transformer_encoder(
    inputs, 
    head_size, 
    num_heads, 
    ff_dim, 
    dropout=0.0
):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

# %%
def build_model(    
    x_train_sw,
    sliding_window_size: int = 5,
    head_size=128,
    num_heads=16,
    ff_dim=8,
    num_transformer_blocks=8,
    mlp_units=128,
    mlp_dropout=0.05,
    dropout=0.05,
):
    input_shape = x_train_sw.shape[1:]
    input_shape = (sliding_window_size, input_shape[1])
    inputs = Input(shape=input_shape)

    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    mlp_units_array = [mlp_units]
    for dim in mlp_units_array:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(1)(x)    # this tells us that the output is one prediction step.
    return Model(inputs, outputs)

# %% [markdown]
# ##### Model Callbacks

# %%
# you can add new callbacks by adding them here
def get_model_callbacks():
    # Adding EarlyStopping callback (for lots of epochs)
    # 33 is a nice sweet spot for allowing a stagnant model in training to get back to reducing validation loss.
    early_stopping = EarlyStopping(patience=33, restore_best_weights=True)

    # Adding ModelCheckpoint callback
    # Define the path to save the best weights. The best weights will be restored in training when new validation loss is higher than the previous validation loss.
    checkpoint_path = 'best_weights.h5'
    checkpoint = ModelCheckpoint(checkpoint_path, save_best_only=True, save_weights_only=True, monitor='val_loss', mode='min', verbose=1)

    model_callbacks = [early_stopping, checkpoint]

    return model_callbacks

# %% [markdown]
# ##### Model Creation and Training

# %%
def compile_model(model: Model, metrics=['mse', 'mae', 'mape'], learning_rate=0.0001):
    model.compile(
    loss="mean_squared_error",
    optimizer=keras.optimizers.Adam(learning_rate=learning_rate), 
    metrics=metrics
    )

    return model

# General guidelines for hyperparameters
# - head_size and mlp_units should be large values (i.e. 256 for head_size and mlp_units, 8 num_heads, ff_dim, num_transformer_blocks)
# - you can't just keep increasing the hyperparameter values, memory is your constraint.

# %% [markdown]
# ##### Model Fitting

# %%
# train the model in a function here.
def train_model(model: Model, model_callbacks, x_train, y_train, train_validation_split: float = 0.8, epochs: int = 20, batch_size: int = 128):  
    # A higher train_validation_split value will mean more data is used for training, less for validation.
    history = model.fit(
                x_train,
                y_train,
                validation_split=1-train_validation_split,  # lil bug was hiding here
                epochs=epochs,
                batch_size=batch_size,
                callbacks=model_callbacks
            )

    # Load the best weights into the model
    model.load_weights('best_weights.h5')

    return model, history

# %% [markdown]
# ##### Model Evaluation

# %%
def evaluate_model(model: Model, x_test_sw, y_test_sw):
    model.evaluate(x_test_sw, y_test_sw, verbose=1)

# %% [markdown]
# ##### Performing Prediction Steps

# %%
# This function performs a single step prediction and adds supporting values from data for another prediction. Calling this multiple times resembles a multistep model.
# Prediction steps uses ground truth data (except target) per step.
def perform_prediction_step_on_ground_truth(model: Model, input_data, remaining_y):

    # reshape the input to (1, sliding_window_size, features)
    test_input = np.reshape(input_data, (1, input_data.shape[0], input_data.shape[1]))

    # perform a prediction step
    prediction_value = model.predict(test_input, verbose=0)
    last_gt_price = np.reshape(input_data[0][0], (1, 1))

    # concatenate the prediction value to beginning of the data columns
    final = np.concatenate((last_gt_price, remaining_y), axis=1)

    # concatenate the input data to the beginning of
    test_x = np.concatenate((input_data, final), axis=0)

    # shifting the sliding window one step forward
    test_x = test_x[1:]

    return test_x, prediction_value

# %%
# This function performs a single step prediction without adding feature values. 
def perform_prediction_step_tomorrow(model: Model, input_data):
    test_input = np.reshape(input_data,(1,input_data.shape[0], input_data.shape[1]))
    prediction_value = model.predict(test_input)
    return prediction_value

# %%
def perform_model_predictions(model, test_x, y_remaining):
    prediction_values = []
    new_test_x = test_x[0].copy()

    # Repeated single step prediction with the available data
    for i in range(y_remaining.shape[0]):
        new_test_x, prediction = perform_prediction_step_on_ground_truth(model, new_test_x, y_remaining[i])
        prediction_values.append(prediction)

    # Single step prediction into the future!
    prediction = perform_prediction_step_tomorrow(model, new_test_x)
    prediction_values.append(prediction)

    pred_vals = np.array(prediction_values)
    pred_vals = pred_vals.squeeze(1)

    return pred_vals

# %% [markdown]
# ##### RMSE

# %%
def calculate_rmse(ground_truth, predicted):
    rmse = mean_squared_error(ground_truth, predicted, squared=False)
    return rmse

# %%
def calculate_mape(ground_truth, predicted):
    mape = mean_absolute_percentage_error(ground_truth, predicted)
    return mape

# %% [markdown]
# # Output

# %%
# Calculate the adjusted final prediction value so that the value is only offsetted by the prediction
# In other words, use the final ground truth value instead of the second to last prediction value as the "starting point".
def calculate_adjusted_prediction(scaler: MinMaxScaler, predicted_values, ground_truth_values):
    last_pred = predicted_values[-1]    # last prediction
    adjusted_pred = last_pred + (ground_truth_values[-1] - predicted_values[-2])   # adjusted prediction = last prediction + (last GT - 2nd to last prediction)
    adjusted_pred = scaler.inverse_transform([adjusted_pred])[0][0].round(2)
    print('The adjusted final prediction value is $' + str(adjusted_pred))
    return adjusted_pred

# %% [markdown]
# #### Preparation for Graph Output

# %%
def prepare_x_axis_prediction_ground_truth(y_train_sw, y_test_sw, predicted_values): 
    # we are concatenating the train data in order to show predicted values on top of ground truth values. This includes the single prediction step into the future.
    predicted = np.concatenate((y_train_sw, predicted_values), axis=0)
    ground_truth = np.concatenate((y_train_sw, y_test_sw), axis=0)

    return predicted, ground_truth

# %% [markdown]
# #### Prediction vs Ground Truth Graph

# %%
def plot_prediction_vs_gt(scaler: MinMaxScaler, predicted, ground_truth, start_date, end_date, train_data_len, train_validation_split, sliding_window_size, adjusted_prediction, target):
    # Use the unscaled data to see prices
    scaler_pred = scaler.inverse_transform(predicted)
    scaler_ground_truth = scaler.inverse_transform(ground_truth)
    gt_with_adj_pred = np.concatenate((scaler_ground_truth, [[adjusted_prediction]]))
    #scaler_pred_adj = scaler.inverse_transform(idk)

    plt.figure(figsize=(15, 6))

    # Adding the predicted, ground truth, and tomorrow's prediction
    plt.plot(scaler_pred.flatten(), label='Next Trading Day Prediction', color='#0000FF')
    plt.plot(gt_with_adj_pred.flatten(), label='Adjusted Next Trading Day Prediction', color='#F000F0')
    plt.plot(scaler_pred[:-1].flatten(), label='Predicted', color='#00FF00')
    plt.plot(scaler_ground_truth.flatten(), label='Ground Truth', color='#FF8800')

    # Adding vertical lines indicating different data usages
    plt.axvline(x=0, label='Train', color='#FF0000', ls=(0, (1, 4)))  # this data was used for model training by keras.
    plt.axvline(x=train_data_len * train_validation_split, label='Validation', color='#00FF00', ls=(0, (1, 4)))   # this data was used for model validation by keras.
    plt.axvline(x=scaler_ground_truth.size - (scaler_pred.size - train_data_len) - sliding_window_size, label='Test', color='#0000FF', ls=(0, (1, 4)))   # this is the test data - predictions are made on it, and we can compare it to ground truth.
    handles, labels = plt.gca().get_legend_handles_labels()
    order = [3,2,0,1,4,5,6]   #1,2,0,3,4,5

    plt.xlabel('Date (' + start_date + ' to ' + end_date + ') + 1')
    plt.ylabel('Stock Price ($)')
    plt.title(target + ': Prediction vs Ground Truth')
    plt.legend([handles[idx] for idx in order], [labels[idx] for idx in order])
    plt.grid(alpha=0.2)
    plt.savefig('Prediction.png')
    plt.show()

# %% [markdown]
# #### Daily Closing Prices

# %%
def plot_daily_close(df: pd.DataFrame, ticker: str, start_date, end_date):
    # Plotting daily closing prices
    plt.figure(figsize=(12, 6))
    plt.plot(df['Close'], linestyle='-')    # df['Date'], 
    plt.xlabel('Date (' + start_date + ' to ' + end_date + ')')
    plt.gca().set_xticklabels([])
    plt.xticks([])
    plt.ylabel('Closing Price')
    plt.title(ticker + ' Daily Closing Prices')
    plt.show()

# %% [markdown]
# #### Daily Stock Returns

# %%
def plot_daily_returns(df: pd.DataFrame, ticker: str, start_date, end_date):
    df['Daily_Return'] = df['Close'].pct_change()
    df.dropna(inplace=True)

    plt.figure(figsize=(12, 6))

    # Plotting daily stock returns
    plt.plot(df['Daily_Return'][1:], linestyle='-') # df['Date'][1:], 
    plt.xlabel('Date (' + start_date + ' to ' + end_date + ')')
    plt.gca().set_xticklabels([])
    plt.xticks([])
    plt.ylabel('Daily Return')
    plt.title(ticker + ' Daily Stock Return')
    plt.show()

# %% [markdown]
# #### Loss from Training and Validation

# %%
def plot_loss_chart(history):
    # Accessing training and validation loss from the history object
    training_loss = history.history['loss']
    validation_loss = history.history['val_loss']

    # Generating a list of epochs (x-axis)
    epochs = range(1, len(training_loss) + 1)


    plt.figure(figsize=(8, 4))

    # Plotting the training and validation loss over iterations
    plt.plot(epochs, training_loss, label='Training Loss', linestyle='-')
    plt.plot(epochs, validation_loss, label='Validation Loss', linestyle='-')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.show()

# %% [markdown]
# #### Pie charts

# %%
def calculate_pie_chart_values(ground_truth, predicted, tolerance_percent: int = 2):
    # Getting data for pie chart
    pie_chart_data = pd.DataFrame({
        'Predicted': predicted[:-1].flatten(),  # remove last predicted 'future' value
        'Ground_Truth': ground_truth.flatten()
    })


    # Calculating all of the necessary things for the pie chart.

    # tolerance = ((pred - gt) / gt) * 100 < tolerance_percent  # determines if the model predicted under some tolerance percent
    # gt movement = gtcurr - gtprev > 0                         # determines if the ground truth movement was up or down
    # pred movement = pred - gtprev > 0                         # determines if the model prediction was up or down
    # if the gt movement and prediction movement are both T or F, then the model predicted correctly upwards/downards.
    # if the gt movement and prediction movement are T/F or F/T, then the model predicted incorrectly downwards for T/F and incorrectly upwards for F/T
    # if the tolerance is under the %, then the model predicted accurately.
    # if the tolerance is over the %, then the model predicted inaccurately.

    predicted_values = np.array(pie_chart_data['Predicted'])
    ground_truth_values = np.array(pie_chart_data['Ground_Truth'])

    #tolerance_percent = 2   # integer used to determine if the model was accurate or not. 1 = 1% tolerance
    tolerance = []
    ground_truth_movement = []  # T is up, F is down
    prediction_movement = []    # T is up, F is down

    # append bool values to each array based on the requirements
    for i in range(1, ground_truth_values.size):
        tolerance.append(True if abs((predicted_values[i] - ground_truth_values[i]) / ground_truth_values[i]) * 100 < tolerance_percent else False)
        ground_truth_movement.append(True if ground_truth_values[i] - ground_truth_values[i-1] > 0 else False)
        prediction_movement.append(True if predicted_values[i] - ground_truth_values[i-1] > 0 else False)



    # Categorizations of model movement prediction, ground truth movement, and tolerance 
    correct = 0
    incorrect = 0
    under = 0
    over = 0

    correct_upwards_under = 0
    correct_upwards_over = 0
    correct_downwards_under = 0
    correct_downwards_over = 0
    incorrect_upwards_under = 0
    incorrect_upwards_over = 0
    incorrect_downwards_under = 0
    incorrect_downwards_over = 0



    # TODO research a cleaner way of doing this...
    for i in range(0, ground_truth_values.size - 1):
        correct += int((ground_truth_movement[i] == True and prediction_movement[i] == True) or (ground_truth_movement[i] == False and prediction_movement[i] == False))     # model predicted correct direction
        incorrect += int((ground_truth_movement[i] == True and prediction_movement[i] == False) or (ground_truth_movement[i] == False and prediction_movement[i] == True))  # model predicted wrong direction
        under += int(tolerance[i] == True)  # model predicted under tolerance
        over += int(tolerance[i] == False)  # model predicted over tolerance

        correct_upwards_under += int(ground_truth_movement[i] == True and prediction_movement[i] == True and tolerance[i] == True)         # model predicted correctly upwards under tolerance
        correct_upwards_over += int(ground_truth_movement[i] == True and prediction_movement[i] == True and tolerance[i] == False)         # model predicted correctly updwards over tolerance
        correct_downwards_under += int(ground_truth_movement[i] == False and prediction_movement[i] == False and tolerance[i] == True)     # model predicted correctly downwards under tolerance
        correct_downwards_over += int(ground_truth_movement[i] == False and prediction_movement[i] == False and tolerance[i] == False)     # model predicted correctly downwards over tolerance
        incorrect_upwards_under += int(ground_truth_movement[i] == False and prediction_movement[i] == True and tolerance[i] == True)      # model predicted incorrectly upwards under tolerance
        incorrect_upwards_over += int(ground_truth_movement[i] == False and prediction_movement[i] == True and tolerance[i] == False)      # model predicted incorrectly upwards over tolerance
        incorrect_downwards_under += int(ground_truth_movement[i] == True and prediction_movement[i] == False and tolerance[i] == True)    # model predicted incorrectly downwards under tolerance
        incorrect_downwards_over += int(ground_truth_movement[i] == True and prediction_movement[i] == False and tolerance[i] == False)    # model predicted incorrectly downwards over tolerance

    tol_per = str(tolerance_percent)
    print('Number of times the model predicted CORRECT direction: ' + str(correct))
    print('Number of times the model predicted INCORRECT direction: ' + str(incorrect))
    print('Number of times the model predicted UNDER ' + tol_per + '% tolerance: ' + str(under))
    print('Number of times the model predicted OVER ' + tol_per + '% tolerance: ' + str(over))

    print('Number of times the model CORRECTLY predicted UPWARD movement UNDER ' + tol_per + '% tolerance: ' + str(correct_upwards_under))
    print('Number of times the model CORRECTLY predicted UPWARD movement OVER ' + tol_per + '% tolerance: ' + str(correct_upwards_over))
    print('Number of times the model CORRECTLY predicted DOWNWARD movement UNDER ' + tol_per + '% tolerance: ' + str(correct_downwards_under))
    print('Number of times the model CORRECTLY predicted DOWNWARD movement OVER ' + tol_per + '% tolerance: ' + str(correct_downwards_over))
    print('Number of times the model INCORRECTLY predicted UPWARD movement UNDER ' + tol_per + '% tolerance: ' + str(incorrect_upwards_under))
    print('Number of times the model INCORRECTLY predicted UPWARD movement OVER ' + tol_per + '% tolerance: ' + str(incorrect_upwards_over))
    print('Number of times the model INCORRECTLY predicted DOWNWARD movement UNDER ' + tol_per + '% tolerance: ' + str(incorrect_downwards_under))
    print('Number of times the model INCORRECTLY predicted DOWNWARD movement OVER ' + tol_per + '% tolerance: ' + str(incorrect_downwards_over))

    # big tuple idk how else to do it...
    return (correct, incorrect, under, over, 
        correct_upwards_under, correct_upwards_over, correct_downwards_under, correct_downwards_over, 
        incorrect_upwards_under, incorrect_upwards_over, incorrect_downwards_under, incorrect_downwards_over)

# %%
# Helper function to remove zero-percent percentages from the pie chart
def auto_percent(pct):
    return ('%1.1f%%' % pct) if pct > 0 else ''

# %%
# Data for the pie chart. Use any of these to sort the data by their respective values.

def plot_pie_categories(tolerance_percent, correct_upwards_under, correct_downwards_under, incorrect_upwards_under, incorrect_downwards_under, correct_upwards_over, correct_downwards_over, incorrect_upwards_over, incorrect_downwards_over):
    # the below are only used for plot_pie_categories
    #labels_correctness = ['Correct Upwards Under', 'Correct Upwards Over', 'Correct Downwards Under', 'Correct Downwards Over', 'Incorrect Upwards Under', 'Incorrect Upwards Over', 'Incorrect Downwards Under', 'Incorrect Downwards Over']
    #sizes_correctness = [correct_upwards_under, correct_upwards_over, correct_downwards_under, correct_downwards_over, incorrect_upwards_under, incorrect_upwards_over, incorrect_downwards_under, incorrect_downwards_over]
    labels_tolerance = ['Correct Upwards Under', 'Correct Downwards Under', 'Incorrect Upwards Under', 'Incorrect Downwards Under', 'Correct Upwards Over', 'Correct Downwards Over', 'Incorrect Upwards Over', 'Incorrect Downwards Over']
    sizes_tolerance = [correct_upwards_under, correct_downwards_under, incorrect_upwards_under, incorrect_downwards_under, correct_upwards_over, correct_downwards_over, incorrect_upwards_over, incorrect_downwards_over]

    colors = ['#00FF00', '#00AA00', '#FFFF00', '#AAAA44', '#00FFFF', '#008B8B', '#FF0000', '#880000']

    plt.figure(figsize=(12, 6))

    # Create the pie chart
    plt.pie(sizes_tolerance, labels=labels_tolerance, labeldistance=None, autopct=auto_percent, startangle=0, colors=colors)
    plt.legend(labels_tolerance, loc='best', bbox_to_anchor=(1.05, 1))
    plt.title('Model Correctness-Directionality-Tolerance Summary (' + str(tolerance_percent) + '% tolerance)')
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.show()

# %%
def plot_pie_correctness(correct: int, incorrect: int):
    colors=['#00FF00', '#FF0000']
    correctness = [correct, incorrect]
    correctness_labels = ['Correct', 'Incorrect']

    plt.figure(figsize=(12, 6))
    plt.pie(correctness, labels=['Correct', 'incorrect'], labeldistance=None, autopct=auto_percent, startangle=0, colors=colors)
    plt.legend(correctness_labels, loc='best', bbox_to_anchor=(1.05, 1))
    plt.title('Model Correctness (Directionality)')
    plt.axis('equal')
    plt.show()

# %%
def plot_pie_tolerance(tolerance_percent: int, under: int, over: int):
    colors=['#00FF00', '#FF0000']
    under_over = [under, over]
    under_over_labels = ['Under', 'Over']

    plt.figure(figsize=(12, 6))
    plt.pie(under_over, labels=under_over_labels, labeldistance=None, autopct=auto_percent, startangle=0, colors=colors)
    plt.legend(under_over_labels, loc='best', bbox_to_anchor=(1.05, 1))
    plt.title('Model Tolerance (%' + str(tolerance_percent) + ')')
    plt.axis('equal')
    plt.show()

# %% [markdown]
# # The entire program

# %%
ticker = 'QQQ'
target_col = 'Close'
filepath = 'data/ta_stock_data_' + ticker + '.csv'   # use 'ta_stock_data_TICKER.csv' for technical analysis, or 'ps_stock_data_TICKER.csv' for parallel stock.
columns_to_keep = [
    'Date',                                     # always keep the dates
    'Open', 'High', 'Low', 'Close', 'Volume',   # OHLCV - probably do not want to exclude
    'rsi', 'macd', 'macd_signal', 'bbands_upper', 'bbands_middle', 'bbands_lower',  # TA - optional
    'obv', 'adx', 'adx_pos', 'adx_neg', 'adi', 
    'ema_50', 'sma_50'
    ]

train_data_percent = 0.9        # data split between train/validation and test      TrV <-> Te
train_validation_split = 0.9    # data split between train and validation           Tr <-> V
sliding_window_size = 5         # number of lags used as input, applied for every feature
tolerance_percent = 2           # percent used to accept a prediction as 'correct', after accounting for direction

# *** A Note on Train Validation Split for Stocks ***
#   There is a chance that, due to a stock price rising over the course of its history, the model may not be able to account for all possible input values.
#   Example: SPY has consistently gone up, and the model gets trained on the first 5 years of its history. 
#   After that, the inputs will undoubtedly be larger than the model expects, so its predictions are quite unstable.
#   The ideal training data contains the highest price recorded in the stock's history.

df, start_date, end_date = get_stock_data_and_period_csv(filepath)
df = df[columns_to_keep]

df
# Out:
# Time Period: 2014-07-30 to 2023-10-18
#             Date        Open        High         Low       Close    Volume  \
# 0     2014-07-30   97.139999   97.320000   96.599998   96.980003  35348500
# 1     2014-07-31   96.180000   96.339996   94.879997   95.019997  50047900
# 2     2014-08-01   94.820000   95.339996   94.040001   94.669998  60708000
# 3     2014-08-04   94.870003   95.690002   94.519997   95.320000  33230500
# 4     2014-08-05   94.940002   95.209999   94.150002   94.589996  50331100
# ...          ...         ...         ...         ...         ...       ...
# 2317  2023-10-12  371.730011  373.739990  367.500000  369.929993  49587900
# 2318  2023-10-13  370.570007  371.160004  363.859985  365.279999  52469900
# 2319  2023-10-16  366.619995  370.480011  366.470001  369.410004  44201100
# 2320  2023-10-17  365.809998  369.920013  363.660004  368.200012  50999100
# 2321  2023-10-18  365.670013  367.910004  362.019989  363.369995  51735979
#
#             rsi      macd  macd_signal  bbands_upper  bbands_middle  \
# 0     64.825687  1.016518     1.057637     97.609735      95.869500
# 1     48.422723  0.834787     1.013067     97.613144      95.865500
# 2     46.175826  0.654972     0.941448     97.637189      95.814000
# 3     50.746729  0.558479     0.864854     97.637094      95.809500
# 4     46.019944  0.418281     0.775540     97.602587      95.826000
# ...         ...       ...          ...           ...            ...
# 2317  56.235010 -0.207676    -1.847648    374.264690     362.620500
# 2318  50.031559 -0.168386    -1.511796    373.447259     362.344000
# 2319  54.800710  0.193775    -1.170682    373.209502     362.281500
# 2320  53.198709  0.378787    -0.860788    372.916305     362.198001
# 2321  47.259644  0.134123    -0.661806    372.818736     362.139500
#
#       bbands_lower         obv        adx    adx_pos    adx_neg           adi  \
# 0        94.129265   470151300  18.788158  23.358166  22.101037  9.601811e+08
# 1        94.117856   420103400  19.102935  19.668354  31.548004  9.197314e+08
# 2        93.990812   359395400  20.038630  17.794416  34.698553  9.178634e+08
# 3        93.981906   392625900  20.435381  18.819072  31.765168  9.300763e+08
# 4        94.049413   342294800  21.089999  17.248721  31.753351  9.215291e+08
# ...            ...         ...        ...        ...        ...           ...
# 2317    350.976311  1282537800  17.469677  23.502171  16.910600  8.180775e+09
# 2318    351.240742  1230067900  16.485544  21.392236  19.868949  8.148718e+09
# 2319    351.353498  1274269000  15.571707  20.013891  18.588753  8.169331e+09
# 2320    351.479697  1223269900  14.851475  18.470961  20.616246  8.192305e+09
# 2321    351.460265  1171533921  14.538545  17.071721  21.064790  8.164285e+09
#
#           ema_50      sma_50
# 0      93.752395   93.556800
# 1      93.802104   93.697200
# 2      93.836139   93.813800
# 3      93.894330   93.935600
# 4      93.921611   94.029800
# ...          ...         ...
# 2317  365.594406  367.169599
# 2318  365.582077  366.999399
# 2319  365.732191  366.946799
# 2320  365.828969  366.806999
# 2321  365.732538  366.634399
#
# [2322 rows x 19 columns]

# %%
df_copy = dataframe_copy(df)
df = dataframe_clean(df)
dataframe_stats(df)

df
# Out:
# (2322, 18)
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'rsi', 'macd', 'macd_signal',
#        'bbands_upper', 'bbands_middle', 'bbands_lower', 'obv', 'adx',
#        'adx_pos', 'adx_neg', 'adi', 'ema_50', 'sma_50'],
#       dtype='object')
# Open             0
# High             0
# Low              0
# Close            0
# Volume           0
# rsi              0
# macd             0
# macd_signal      0
# bbands_upper     0
# bbands_middle    0
# bbands_lower     0
# obv              0
# adx              0
# adx_pos          0
# adx_neg          0
# adi              0
# ema_50           0
# sma_50           0
# dtype: int64
#             Open        High         Low       Close    Volume        rsi  \
# 0      97.139999   97.320000   96.599998   96.980003  35348500  64.825687
# 1      96.180000   96.339996   94.879997   95.019997  50047900  48.422723
# 2      94.820000   95.339996   94.040001   94.669998  60708000  46.175826
# 3      94.870003   95.690002   94.519997   95.320000  33230500  50.746729
# 4      94.940002   95.209999   94.150002   94.589996  50331100  46.019944
# ...          ...         ...         ...         ...       ...        ...
# 2317  371.730011  373.739990  367.500000  369.929993  49587900  56.235010
# 2318  370.570007  371.160004  363.859985  365.279999  52469900  50.031559
# 2319  366.619995  370.480011  366.470001  369.410004  44201100  54.800710
# 2320  365.809998  369.920013  363.660004  368.200012  50999100  53.198709
# 2321  365.670013  367.910004  362.019989  363.369995  51735979  47.259644
#
#           macd  macd_signal  bbands_upper  bbands_middle  bbands_lower  \
# 0     1.016518     1.057637     97.609735      95.869500     94.129265
# 1     0.834787     1.013067     97.613144      95.865500     94.117856
# 2     0.654972     0.941448     97.637189      95.814000     93.990812
# 3     0.558479     0.864854     97.637094      95.809500     93.981906
# 4     0.418281     0.775540     97.602587      95.826000     94.049413
# ...        ...          ...           ...            ...           ...
# 2317 -0.207676    -1.847648    374.264690     362.620500    350.976311
# 2318 -0.168386    -1.511796    373.447259     362.344000    351.240742
# 2319  0.193775    -1.170682    373.209502     362.281500    351.353498
# 2320  0.378787    -0.860788    372.916305     362.198001    351.479697
# 2321  0.134123    -0.661806    372.818736     362.139500    351.460265
#
#              obv        adx    adx_pos    adx_neg           adi      ema_50  \
# 0      470151300  18.788158  23.358166  22.101037  9.601811e+08   93.752395
# 1      420103400  19.102935  19.668354  31.548004  9.197314e+08   93.802104
# 2      359395400  20.038630  17.794416  34.698553  9.178634e+08   93.836139
# 3      392625900  20.435381  18.819072  31.765168  9.300763e+08   93.894330
# 4      342294800  21.089999  17.248721  31.753351  9.215291e+08   93.921611
# ...          ...        ...        ...        ...           ...         ...
# 2317  1282537800  17.469677  23.502171  16.910600  8.180775e+09  365.594406
# 2318  1230067900  16.485544  21.392236  19.868949  8.148718e+09  365.582077
# 2319  1274269000  15.571707  20.013891  18.588753  8.169331e+09  365.732191
# 2320  1223269900  14.851475  18.470961  20.616246  8.192305e+09  365.828969
# 2321  1171533921  14.538545  17.071721  21.064790  8.164285e+09  365.732538
#
#           sma_50
# 0      93.556800
# 1      93.697200
# 2      93.813800
# 3      93.935600
# 4      94.029800
# ...          ...
# 2317  367.169599
# 2318  366.999399
# 2319  366.946799
# 2320  366.806999
# 2321  366.634399
#
# [2322 rows x 18 columns]

# %%
df = set_column_as_first(df, col_name=target_col)

df
# Out:
#            Close        High         Low        Open    Volume        rsi  \
# 0      96.980003   97.320000   96.599998   97.139999  35348500  64.825687
# 1      95.019997   96.339996   94.879997   96.180000  50047900  48.422723
# 2      94.669998   95.339996   94.040001   94.820000  60708000  46.175826
# 3      95.320000   95.690002   94.519997   94.870003  33230500  50.746729
# 4      94.589996   95.209999   94.150002   94.940002  50331100  46.019944
# ...          ...         ...         ...         ...       ...        ...
# 2317  369.929993  373.739990  367.500000  371.730011  49587900  56.235010
# 2318  365.279999  371.160004  363.859985  370.570007  52469900  50.031559
# 2319  369.410004  370.480011  366.470001  366.619995  44201100  54.800710
# 2320  368.200012  369.920013  363.660004  365.809998  50999100  53.198709
# 2321  363.369995  367.910004  362.019989  365.670013  51735979  47.259644
#
#           macd  macd_signal  bbands_upper  bbands_middle  bbands_lower  \
# 0     1.016518     1.057637     97.609735      95.869500     94.129265
# 1     0.834787     1.013067     97.613144      95.865500     94.117856
# 2     0.654972     0.941448     97.637189      95.814000     93.990812
# 3     0.558479     0.864854     97.637094      95.809500     93.981906
# 4     0.418281     0.775540     97.602587      95.826000     94.049413
# ...        ...          ...           ...            ...           ...
# 2317 -0.207676    -1.847648    374.264690     362.620500    350.976311
# 2318 -0.168386    -1.511796    373.447259     362.344000    351.240742
# 2319  0.193775    -1.170682    373.209502     362.281500    351.353498
# 2320  0.378787    -0.860788    372.916305     362.198001    351.479697
# 2321  0.134123    -0.661806    372.818736     362.139500    351.460265
#
#              obv        adx    adx_pos    adx_neg           adi      ema_50  \
# 0      470151300  18.788158  23.358166  22.101037  9.601811e+08   93.752395
# 1      420103400  19.102935  19.668354  31.548004  9.197314e+08   93.802104
# 2      359395400  20.038630  17.794416  34.698553  9.178634e+08   93.836139
# 3      392625900  20.435381  18.819072  31.765168  9.300763e+08   93.894330
# 4      342294800  21.089999  17.248721  31.753351  9.215291e+08   93.921611
# ...          ...        ...        ...        ...           ...         ...
# 2317  1282537800  17.469677  23.502171  16.910600  8.180775e+09  365.594406
# 2318  1230067900  16.485544  21.392236  19.868949  8.148718e+09  365.582077
# 2319  1274269000  15.571707  20.013891  18.588753  8.169331e+09  365.732191
# 2320  1223269900  14.851475  18.470961  20.616246  8.192305e+09  365.828969
# 2321  1171533921  14.538545  17.071721  21.064790  8.164285e+09  365.732538
#
#           sma_50
# 0      93.556800
# 1      93.697200
# 2      93.813800
# 3      93.935600
# 4      94.029800
# ...          ...
# 2317  367.169599
# 2318  366.999399
# 2319  366.946799
# 2320  366.806999
# 2321  366.634399
#
# [2322 rows x 18 columns]

# %%
scaler = scaler_fit_column(df, target=target_col)
df = transform_data(df)

df
# Out:
#          Close      High       Low      Open    Volume       rsi      macd  \
# 0     0.016624  0.014994  0.037314  0.021323  0.147538  0.689543  0.603311
# 1     0.010346  0.011894  0.031903  0.018277  0.224254  0.441961  0.595446
# 2     0.009225  0.008731  0.029260  0.013962  0.279890  0.408047  0.587663
# 3     0.011307  0.009838  0.030770  0.014120  0.136484  0.477039  0.583487
# 4     0.008969  0.008319  0.029606  0.014342  0.225732  0.405694  0.577420
# ...        ...       ...       ...       ...       ...       ...       ...
# 2317  0.890903  0.889381  0.889630  0.892623  0.221854  0.559877  0.550328
# 2318  0.876009  0.881220  0.878178  0.888942  0.236895  0.466244  0.552029
# 2319  0.889238  0.879069  0.886389  0.876408  0.193740  0.538228  0.567703
# 2320  0.885362  0.877297  0.877549  0.873838  0.229219  0.514048  0.575710
# 2321  0.869891  0.870939  0.872389  0.873394  0.233065  0.424406  0.565121
#
#       macd_signal  bbands_upper  bbands_middle  bbands_lower       obv  \
# 0        0.603699      0.000023       0.000431      0.012441  0.155078
# 1        0.601571      0.000033       0.000418      0.012403  0.138110
# 2        0.598151      0.000109       0.000246      0.011976  0.117529
# 3        0.594493      0.000109       0.000231      0.011946  0.128795
# 4        0.590228      0.000000       0.000286      0.012173  0.111731
# ...           ...           ...            ...           ...       ...
# 2317     0.464961      0.871991       0.888405      0.874823  0.430497
# 2318     0.480999      0.869415       0.887485      0.875711  0.412708
# 2319     0.497289      0.868665       0.887277      0.876090  0.427693
# 2320     0.512087      0.867741       0.886999      0.876513  0.410403
# 2321     0.521589      0.867434       0.886804      0.876448  0.392864
#
#            adx   adx_pos   adx_neg       adi    ema_50    sma_50
# 0     0.290981  0.398741  0.230683  0.007283  0.000000  0.000000
# 1     0.299066  0.309786  0.375805  0.001835  0.000167  0.000468
# 2     0.323097  0.264609  0.424202  0.001583  0.000282  0.000857
# 3     0.333286  0.289311  0.379141  0.003228  0.000478  0.001263
# 4     0.350099  0.251453  0.378959  0.002077  0.000570  0.001577
# ...        ...       ...       ...       ...       ...       ...
# 2317  0.257119  0.402212  0.150949  0.979958  0.914985  0.912063
# 2318  0.231844  0.351346  0.196394  0.975640  0.914943  0.911495
# 2319  0.208374  0.318116  0.176728  0.978417  0.915449  0.911320
# 2320  0.189877  0.280919  0.207874  0.981512  0.915774  0.910854
# 2321  0.181840  0.247186  0.214765  0.977737  0.915450  0.910279
#
# [2322 rows x 18 columns]

# %%
features, target = get_features_and_target(df, target=target_col)

print(features.shape)
print(target.shape)
# Out:
# (2322, 18)
# (2322, 1)

# %%
features
# Out:
#          Close      High       Low      Open    Volume       rsi      macd  \
# 0     0.016624  0.014994  0.037314  0.021323  0.147538  0.689543  0.603311
# 1     0.010346  0.011894  0.031903  0.018277  0.224254  0.441961  0.595446
# 2     0.009225  0.008731  0.029260  0.013962  0.279890  0.408047  0.587663
# 3     0.011307  0.009838  0.030770  0.014120  0.136484  0.477039  0.583487
# 4     0.008969  0.008319  0.029606  0.014342  0.225732  0.405694  0.577420
# ...        ...       ...       ...       ...       ...       ...       ...
# 2317  0.890903  0.889381  0.889630  0.892623  0.221854  0.559877  0.550328
# 2318  0.876009  0.881220  0.878178  0.888942  0.236895  0.466244  0.552029
# 2319  0.889238  0.879069  0.886389  0.876408  0.193740  0.538228  0.567703
# 2320  0.885362  0.877297  0.877549  0.873838  0.229219  0.514048  0.575710
# 2321  0.869891  0.870939  0.872389  0.873394  0.233065  0.424406  0.565121
#
#       macd_signal  bbands_upper  bbands_middle  bbands_lower       obv  \
# 0        0.603699      0.000023       0.000431      0.012441  0.155078
# 1        0.601571      0.000033       0.000418      0.012403  0.138110
# 2        0.598151      0.000109       0.000246      0.011976  0.117529
# 3        0.594493      0.000109       0.000231      0.011946  0.128795
# 4        0.590228      0.000000       0.000286      0.012173  0.111731
# ...           ...           ...            ...           ...       ...
# 2317     0.464961      0.871991       0.888405      0.874823  0.430497
# 2318     0.480999      0.869415       0.887485      0.875711  0.412708
# 2319     0.497289      0.868665       0.887277      0.876090  0.427693
# 2320     0.512087      0.867741       0.886999      0.876513  0.410403
# 2321     0.521589      0.867434       0.886804      0.876448  0.392864
#
#            adx   adx_pos   adx_neg       adi    ema_50    sma_50
# 0     0.290981  0.398741  0.230683  0.007283  0.000000  0.000000
# 1     0.299066  0.309786  0.375805  0.001835  0.000167  0.000468
# 2     0.323097  0.264609  0.424202  0.001583  0.000282  0.000857
# 3     0.333286  0.289311  0.379141  0.003228  0.000478  0.001263
# 4     0.350099  0.251453  0.378959  0.002077  0.000570  0.001577
# ...        ...       ...       ...       ...       ...       ...
# 2317  0.257119  0.402212  0.150949  0.979958  0.914985  0.912063
# 2318  0.231844  0.351346  0.196394  0.975640  0.914943  0.911495
# 2319  0.208374  0.318116  0.176728  0.978417  0.915449  0.911320
# 2320  0.189877  0.280919  0.207874  0.981512  0.915774  0.910854
# 2321  0.181840  0.247186  0.214765  0.977737  0.915450  0.910279
#
# [2322 rows x 18 columns]

# %%
target
# Out:
#          Close
# 0     0.016624
# 1     0.010346
# 2     0.009225
# 3     0.011307
# 4     0.008969
# ...        ...
# 2317  0.890903
# 2318  0.876009
# 2319  0.889238
# 2320  0.885362
# 2321  0.869891
#
# [2322 rows x 1 columns]

# %%
train_x, train_y, train_data_len = setup_train_data(features, target, train_data_percent)
x_train_sw, y_train_sw = prepare_train_as_sliding_window(train_x, train_y, sliding_window_size)

print(train_x.shape)
print(train_y.shape)
print(train_data_len)
print(x_train_sw.shape)
print(y_train_sw.shape)
# Out:
# (2090, 18)
# (2090, 1)
# 2090
# (2085, 5, 18)
# (2085, 1)

# %%
test_x, test_y = setup_test_data(features, target, train_data_len)
x_test_sw, y_test_sw, y_remaining = prepare_test_as_sliding_window(test_x, test_y, sliding_window_size)

print(test_x.shape)
print(test_y.shape)
print(x_test_sw.shape)
print(y_test_sw.shape)
print(y_remaining.shape)
# Out:
# (232, 18)
# (232, 1)
# (227, 5, 18)
# (227, 1)
# (227, 1, 17)

# %%
model = build_model(
    x_train_sw, 
    sliding_window_size,
    head_size=64,      # head size of multi-head attention of transformer encoder blocks            # low impact on training time
    num_heads=18,        # number of heads in multi-head attention of transformer encoder blocks     # low impact on training time
    ff_dim=4,           # number of filters in conv1d of transformer encoder blocks                 # medium impact on training time
    num_transformer_blocks=4,   # number of transformer encoder blocks                              # HIGH impact on training time
    mlp_units=64,      # number of mlp units                                                       # low impact on training time
    mlp_dropout=0.2,    # dropout of mlp units                                                      # reduces overfitting
    dropout=0.2         # dropout of multi-head attention transformer encoder blocks                # reduces overfitting
    )
model = compile_model(model, learning_rate=0.0001)

# %%
# the best model trains fast, achieves small validation loss, and scores a low RMSE value.
model, history = train_model(model, get_model_callbacks(), x_train_sw, y_train_sw, train_validation_split, epochs=200, batch_size=128)

# in general, a val_loss of ~0.00100 (or below) is usually an indicator that the model will perform well on training (~0.02 RMSE). Of course, it varies with luck.
evaluate_model(model, x_test_sw, y_test_sw)
# Out:
# Epoch 1/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0303 - mse: 0.0303 - mae: 0.1263 - mape: 14667.2051
# Epoch 1: val_loss improved from inf to 0.00960, saving model to best_weights.h5
# 15/15 [==============================] - 5s 88ms/step - loss: 0.0303 - mse: 0.0303 - mae: 0.1263 - mape: 14667.2051 - val_loss: 0.0096 - val_mse: 0.0096 - val_mae: 0.0778 - val_mape: 12.1433
# Epoch 2/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0138 - mse: 0.0138 - mae: 0.0815 - mape: 45035.3008
# Epoch 2: val_loss improved from 0.00960 to 0.00854, saving model to best_weights.h5
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0138 - mse: 0.0138 - mae: 0.0815 - mape: 45035.3008 - val_loss: 0.0085 - val_mse: 0.0085 - val_mae: 0.0803 - val_mape: 11.8919
# Epoch 3/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0116 - mse: 0.0116 - mae: 0.0737 - mape: 42077.6484
# Epoch 3: val_loss improved from 0.00854 to 0.00360, saving model to best_weights.h5
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0116 - mse: 0.0116 - mae: 0.0737 - mape: 42077.6484 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0496 - val_mape: 7.3429
# Epoch 4/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0094 - mse: 0.0094 - mae: 0.0672 - mape: 50889.9258
# Epoch 4: val_loss did not improve from 0.00360
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0094 - mse: 0.0094 - mae: 0.0668 - mape: 48612.6680 - val_loss: 0.0050 - val_mse: 0.0050 - val_mae: 0.0590 - val_mape: 8.9665
# Epoch 5/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0089 - mse: 0.0089 - mae: 0.0634 - mape: 19450.9277
# Epoch 5: val_loss improved from 0.00360 to 0.00290, saving model to best_weights.h5
# 15/15 [==============================] - 1s 57ms/step - loss: 0.0089 - mse: 0.0089 - mae: 0.0634 - mape: 19450.9277 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0444 - val_mape: 6.5714
# Epoch 6/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0080 - mse: 0.0080 - mae: 0.0597 - mape: 22711.3848
# Epoch 6: val_loss improved from 0.00290 to 0.00269, saving model to best_weights.h5
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0080 - mse: 0.0080 - mae: 0.0597 - mape: 22711.3848 - val_loss: 0.0027 - val_mse: 0.0027 - val_mae: 0.0426 - val_mape: 6.2441
# Epoch 7/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0080 - mse: 0.0080 - mae: 0.0584 - mape: 17111.4961
# Epoch 7: val_loss improved from 0.00269 to 0.00233, saving model to best_weights.h5
# 15/15 [==============================] - 1s 57ms/step - loss: 0.0080 - mse: 0.0080 - mae: 0.0584 - mape: 17111.4961 - val_loss: 0.0023 - val_mse: 0.0023 - val_mae: 0.0393 - val_mape: 5.7531
# Epoch 8/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0080 - mse: 0.0080 - mae: 0.0592 - mape: 15655.2715
# Epoch 8: val_loss did not improve from 0.00233
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0080 - mse: 0.0080 - mae: 0.0592 - mape: 15655.2715 - val_loss: 0.0024 - val_mse: 0.0024 - val_mae: 0.0401 - val_mape: 5.9006
# Epoch 9/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0073 - mse: 0.0073 - mae: 0.0566 - mape: 26853.2539
# Epoch 9: val_loss improved from 0.00233 to 0.00185, saving model to best_weights.h5
# 15/15 [==============================] - 1s 59ms/step - loss: 0.0073 - mse: 0.0073 - mae: 0.0566 - mape: 26853.2539 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0344 - val_mape: 4.9413
# Epoch 10/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0066 - mse: 0.0066 - mae: 0.0551 - mape: 63285.7227
# Epoch 10: val_loss did not improve from 0.00185
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0064 - mse: 0.0064 - mae: 0.0546 - mape: 60453.6758 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0368 - val_mape: 5.2185
# Epoch 11/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0063 - mse: 0.0063 - mae: 0.0526 - mape: 13967.3340
# Epoch 11: val_loss did not improve from 0.00185
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0063 - mse: 0.0063 - mae: 0.0526 - mape: 13967.3340 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0390 - val_mape: 5.8099
# Epoch 12/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0066 - mse: 0.0066 - mae: 0.0529 - mape: 1923.8497
# Epoch 12: val_loss did not improve from 0.00185
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0065 - mse: 0.0065 - mae: 0.0526 - mape: 1838.7830 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0533 - val_mape: 8.0803
# Epoch 13/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0061 - mse: 0.0061 - mae: 0.0509 - mape: 17883.8965
# Epoch 13: val_loss did not improve from 0.00185
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0061 - mse: 0.0061 - mae: 0.0509 - mape: 17883.8965 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0498 - val_mape: 7.5202
# Epoch 14/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0059 - mse: 0.0059 - mae: 0.0503 - mape: 32283.5879
# Epoch 14: val_loss did not improve from 0.00185
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0503 - mape: 32283.5879 - val_loss: 0.0025 - val_mse: 0.0025 - val_mae: 0.0414 - val_mape: 6.2365
# Epoch 15/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0057 - mse: 0.0057 - mae: 0.0494 - mape: 38492.8945
# Epoch 15: val_loss did not improve from 0.00185
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0057 - mse: 0.0057 - mae: 0.0494 - mape: 38492.8945 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0368 - val_mape: 5.4493
# Epoch 16/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0058 - mse: 0.0058 - mae: 0.0489 - mape: 29.2736
# Epoch 16: val_loss did not improve from 0.00185
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0057 - mse: 0.0057 - mae: 0.0490 - mape: 31903.1484 - val_loss: 0.0024 - val_mse: 0.0024 - val_mae: 0.0406 - val_mape: 6.0254
# Epoch 17/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0061 - mse: 0.0061 - mae: 0.0493 - mape: 90.0724
# Epoch 17: val_loss improved from 0.00185 to 0.00170, saving model to best_weights.h5
# 15/15 [==============================] - 1s 60ms/step - loss: 0.0060 - mse: 0.0060 - mae: 0.0493 - mape: 87.5911 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0341 - val_mape: 4.9278
# Epoch 18/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0057 - mse: 0.0057 - mae: 0.0496 - mape: 33795.5703
# Epoch 18: val_loss did not improve from 0.00170
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0056 - mse: 0.0056 - mae: 0.0494 - mape: 32283.8828 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0342 - val_mape: 4.8881
# Epoch 19/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0054 - mse: 0.0054 - mae: 0.0477 - mape: 23759.2227
# Epoch 19: val_loss improved from 0.00170 to 0.00138, saving model to best_weights.h5
# 15/15 [==============================] - 1s 60ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0477 - mape: 23759.2227 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0300 - val_mape: 4.3118
# Epoch 20/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0051 - mse: 0.0051 - mae: 0.0482 - mape: 12221.5479
# Epoch 20: val_loss did not improve from 0.00138
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0482 - mape: 11676.9990 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0326 - val_mape: 4.6432
# Epoch 21/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0051 - mse: 0.0051 - mae: 0.0470 - mape: 28889.7520
# Epoch 21: val_loss did not improve from 0.00138
# 15/15 [==============================] - 1s 57ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0470 - mape: 28889.7520 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0324 - val_mape: 4.5703
# Epoch 22/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0045 - mse: 0.0045 - mae: 0.0445 - mape: 29.5339
# Epoch 22: val_loss did not improve from 0.00138
# 15/15 [==============================] - 1s 57ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0451 - mape: 28266.4082 - val_loss: 0.0027 - val_mse: 0.0027 - val_mae: 0.0441 - val_mape: 6.5747
# Epoch 23/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0051 - mse: 0.0051 - mae: 0.0467 - mape: 34665.4023
# Epoch 23: val_loss improved from 0.00138 to 0.00126, saving model to best_weights.h5
# 15/15 [==============================] - 1s 58ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0467 - mape: 34665.4023 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0288 - val_mape: 4.1207
# Epoch 24/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0047 - mse: 0.0047 - mae: 0.0454 - mape: 21532.2754
# Epoch 24: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0454 - mape: 21532.2754 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0399 - val_mape: 5.9136
# Epoch 25/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0046 - mse: 0.0046 - mae: 0.0454 - mape: 16236.7793
# Epoch 25: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0046 - mse: 0.0046 - mae: 0.0454 - mape: 16236.7793 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0330 - val_mape: 4.7085
# Epoch 26/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0048 - mse: 0.0048 - mae: 0.0457 - mape: 19877.4473
# Epoch 26: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0048 - mse: 0.0048 - mae: 0.0454 - mape: 18988.4102 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0367 - val_mape: 5.2361
# Epoch 27/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0042 - mse: 0.0042 - mae: 0.0420 - mape: 18556.2168
# Epoch 27: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0420 - mape: 18556.2168 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0301 - val_mape: 4.2999
# Epoch 28/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0041 - mse: 0.0041 - mae: 0.0423 - mape: 24684.0840
# Epoch 28: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0423 - mape: 24684.0840 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0306 - val_mape: 4.3876
# Epoch 29/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0048 - mse: 0.0048 - mae: 0.0442 - mape: 24854.0469
# Epoch 29: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0048 - mse: 0.0048 - mae: 0.0442 - mape: 24854.0469 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0308 - val_mape: 4.2702
# Epoch 30/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0040 - mse: 0.0040 - mae: 0.0414 - mape: 9488.8467
# Epoch 30: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0414 - mape: 9488.8467 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0304 - val_mape: 4.3656
# Epoch 31/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0041 - mse: 0.0041 - mae: 0.0418 - mape: 24097.8223
# Epoch 31: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 58ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0418 - mape: 24097.8223 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0316 - val_mape: 4.6413
# Epoch 32/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0045 - mse: 0.0045 - mae: 0.0428 - mape: 35965.2227
# Epoch 32: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 64ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0428 - mape: 35965.2227 - val_loss: 0.0042 - val_mse: 0.0042 - val_mae: 0.0563 - val_mape: 8.2804
# Epoch 33/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0040 - mse: 0.0040 - mae: 0.0416 - mape: 37634.7812
# Epoch 33: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 57ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0413 - mape: 35950.7148 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0494 - val_mape: 7.0908
# Epoch 34/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0044 - mse: 0.0044 - mae: 0.0432 - mape: 9619.3936
# Epoch 34: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0433 - mape: 9189.7920 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0331 - val_mape: 4.8024
# Epoch 35/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0044 - mse: 0.0044 - mae: 0.0426 - mape: 38298.3125
# Epoch 35: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0425 - mape: 36584.9609 - val_loss: 0.0027 - val_mse: 0.0027 - val_mae: 0.0418 - val_mape: 6.1149
# Epoch 36/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0042 - mse: 0.0042 - mae: 0.0429 - mape: 8258.7764
# Epoch 36: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0425 - mape: 7889.7959 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0283 - val_mape: 3.9682
# Epoch 37/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0042 - mse: 0.0042 - mae: 0.0410 - mape: 6163.0894
# Epoch 37: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0410 - mape: 6163.0894 - val_loss: 0.0023 - val_mse: 0.0023 - val_mae: 0.0395 - val_mape: 5.7584
# Epoch 38/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0032 - mse: 0.0032 - mae: 0.0370 - mape: 15259.8672
# Epoch 38: val_loss improved from 0.00126 to 0.00094, saving model to best_weights.h5
# 15/15 [==============================] - 1s 65ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0371 - mape: 14577.5352 - val_loss: 9.3782e-04 - val_mse: 9.3782e-04 - val_mae: 0.0246 - val_mape: 3.5212
# Epoch 39/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0035 - mse: 0.0035 - mae: 0.0383 - mape: 26.4732
# Epoch 39: val_loss did not improve from 0.00094
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0385 - mape: 22873.4668 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0281 - val_mape: 4.0215
# Epoch 40/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0035 - mse: 0.0035 - mae: 0.0400 - mape: 25140.0156
# Epoch 40: val_loss did not improve from 0.00094
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0399 - mape: 24015.5371 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0273 - val_mape: 3.9243
# Epoch 41/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0033 - mse: 0.0033 - mae: 0.0373 - mape: 15192.1084
# Epoch 41: val_loss did not improve from 0.00094
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0373 - mape: 15192.1084 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0322 - val_mape: 4.6516
# Epoch 42/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0032 - mse: 0.0032 - mae: 0.0383 - mape: 39035.3086
# Epoch 42: val_loss did not improve from 0.00094
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0386 - mape: 37288.6484 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0290 - val_mape: 4.1567
# Epoch 43/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0034 - mse: 0.0034 - mae: 0.0377 - mape: 18605.3926
# Epoch 43: val_loss did not improve from 0.00094
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0374 - mape: 17773.1348 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0326 - val_mape: 4.7676
# Epoch 44/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0033 - mse: 0.0033 - mae: 0.0382 - mape: 27692.2051
# Epoch 44: val_loss did not improve from 0.00094
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0382 - mape: 27692.2051 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0271 - val_mape: 3.9549
# Epoch 45/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0034 - mse: 0.0034 - mae: 0.0382 - mape: 16901.5684
# Epoch 45: val_loss did not improve from 0.00094
# 15/15 [==============================] - 1s 59ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0383 - mape: 16145.8652 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0506 - val_mape: 7.3176
# Epoch 46/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0032 - mse: 0.0032 - mae: 0.0374 - mape: 21767.7070
# Epoch 46: val_loss did not improve from 0.00094
# 15/15 [==============================] - 1s 57ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0373 - mape: 20793.8125 - val_loss: 0.0027 - val_mse: 0.0027 - val_mae: 0.0428 - val_mape: 6.2344
# Epoch 47/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0033 - mse: 0.0033 - mae: 0.0370 - mape: 19976.2852
# Epoch 47: val_loss did not improve from 0.00094
# 15/15 [==============================] - 1s 61ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0370 - mape: 19976.2852 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0280 - val_mape: 4.0354
# Epoch 48/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0034 - mse: 0.0034 - mae: 0.0375 - mape: 31409.3203
# Epoch 48: val_loss did not improve from 0.00094
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0375 - mape: 31409.3203 - val_loss: 0.0024 - val_mse: 0.0024 - val_mae: 0.0388 - val_mape: 5.5352
# Epoch 49/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0036 - mse: 0.0036 - mae: 0.0383 - mape: 24885.0020
# Epoch 49: val_loss did not improve from 0.00094
# 15/15 [==============================] - 1s 66ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0383 - mape: 23771.8105 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0364 - val_mape: 5.3444
# Epoch 50/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0030 - mse: 0.0030 - mae: 0.0365 - mape: 11858.3369
# Epoch 50: val_loss did not improve from 0.00094
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0369 - mape: 11329.3301 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0352 - val_mape: 5.1546
# Epoch 51/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0030 - mse: 0.0030 - mae: 0.0361 - mape: 17802.5273
# Epoch 51: val_loss did not improve from 0.00094
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0360 - mape: 17006.8926 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0274 - val_mape: 3.9941
# Epoch 52/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0030 - mse: 0.0030 - mae: 0.0360 - mape: 26310.8809
# Epoch 52: val_loss did not improve from 0.00094
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0361 - mape: 25133.4746 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0314 - val_mape: 4.6087
# Epoch 53/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0028 - mse: 0.0028 - mae: 0.0346 - mape: 4425.2573
# Epoch 53: val_loss did not improve from 0.00094
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0348 - mape: 4227.9126 - val_loss: 0.0024 - val_mse: 0.0024 - val_mae: 0.0402 - val_mape: 6.0198
# Epoch 54/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0033 - mse: 0.0033 - mae: 0.0370 - mape: 6330.3418
# Epoch 54: val_loss improved from 0.00094 to 0.00082, saving model to best_weights.h5
# 15/15 [==============================] - 1s 60ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0370 - mape: 6330.3418 - val_loss: 8.1703e-04 - val_mse: 8.1703e-04 - val_mae: 0.0225 - val_mape: 3.2592
# Epoch 55/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0029 - mse: 0.0029 - mae: 0.0356 - mape: 18243.1016
# Epoch 55: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0356 - mape: 18243.1016 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0343 - val_mape: 5.0989
# Epoch 56/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0033 - mse: 0.0033 - mae: 0.0377 - mape: 24194.0723
# Epoch 56: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0375 - mape: 23111.8145 - val_loss: 0.0023 - val_mse: 0.0023 - val_mae: 0.0392 - val_mape: 5.8935
# Epoch 57/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0028 - mse: 0.0028 - mae: 0.0343 - mape: 22367.4395
# Epoch 57: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 59ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0345 - mape: 21367.0488 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0282 - val_mape: 4.0373
# Epoch 58/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0026 - mse: 0.0026 - mae: 0.0346 - mape: 33954.5273
# Epoch 58: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0346 - mape: 33954.5273 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0320 - val_mape: 4.6991
# Epoch 59/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0027 - mse: 0.0027 - mae: 0.0345 - mape: 17708.3398
# Epoch 59: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 48ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0345 - mape: 17708.3398 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0266 - val_mape: 3.8959
# Epoch 60/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0028 - mse: 0.0028 - mae: 0.0350 - mape: 20998.3906
# Epoch 60: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0351 - mape: 20058.9238 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0345 - val_mape: 5.1301
# Epoch 61/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0026 - mse: 0.0026 - mae: 0.0343 - mape: 22.5094
# Epoch 61: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0344 - mape: 48993.7305 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0316 - val_mape: 4.6782
# Epoch 62/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0027 - mse: 0.0027 - mae: 0.0342 - mape: 31157.1836
# Epoch 62: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 71ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0343 - mape: 29762.9023 - val_loss: 0.0010 - val_mse: 0.0010 - val_mae: 0.0264 - val_mape: 3.9055
# Epoch 63/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0029 - mse: 0.0029 - mae: 0.0356 - mape: 36606.9414
# Epoch 63: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 68ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0356 - mape: 36606.9414 - val_loss: 8.3528e-04 - val_mse: 8.3528e-04 - val_mae: 0.0230 - val_mape: 3.3228
# Epoch 64/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0029 - mse: 0.0029 - mae: 0.0350 - mape: 6688.3164
# Epoch 64: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0352 - mape: 6390.2231 - val_loss: 9.3514e-04 - val_mse: 9.3514e-04 - val_mae: 0.0242 - val_mape: 3.4502
# Epoch 65/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0027 - mse: 0.0027 - mae: 0.0344 - mape: 26048.3086
# Epoch 65: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 62ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0344 - mape: 26048.3086 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0282 - val_mape: 4.0083
# Epoch 66/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0028 - mse: 0.0028 - mae: 0.0361 - mape: 20042.7305
# Epoch 66: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0361 - mape: 20042.7305 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0332 - val_mape: 4.7605
# Epoch 67/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0025 - mse: 0.0025 - mae: 0.0328 - mape: 14127.8389
# Epoch 67: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 59ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0328 - mape: 14127.8389 - val_loss: 0.0010 - val_mse: 0.0010 - val_mae: 0.0257 - val_mape: 3.7170
# Epoch 68/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0023 - mse: 0.0023 - mae: 0.0317 - mape: 18589.8926
# Epoch 68: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 63ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0317 - mape: 18589.8926 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0264 - val_mape: 3.8286
# Epoch 69/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0026 - mse: 0.0026 - mae: 0.0339 - mape: 24906.6055
# Epoch 69: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 74ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0339 - mape: 24906.6055 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0514 - val_mape: 7.4962
# Epoch 70/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0024 - mse: 0.0024 - mae: 0.0328 - mape: 10230.2988
# Epoch 70: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 80ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0328 - mape: 10230.2988 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0345 - val_mape: 5.0195
# Epoch 71/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0026 - mse: 0.0026 - mae: 0.0331 - mape: 21604.4902
# Epoch 71: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 76ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0331 - mape: 21604.4902 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0281 - val_mape: 4.0694
# Epoch 72/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0024 - mse: 0.0024 - mae: 0.0329 - mape: 19827.4375
# Epoch 72: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 83ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0329 - mape: 19827.4375 - val_loss: 0.0010 - val_mse: 0.0010 - val_mae: 0.0254 - val_mape: 3.7020
# Epoch 73/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0024 - mse: 0.0024 - mae: 0.0324 - mape: 16318.2285
# Epoch 73: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 75ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0324 - mape: 16318.2285 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0283 - val_mape: 4.1372
# Epoch 74/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0029 - mse: 0.0029 - mae: 0.0335 - mape: 23685.3066
# Epoch 74: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 81ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0335 - mape: 23685.3066 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0302 - val_mape: 4.4144
# Epoch 75/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0022 - mse: 0.0022 - mae: 0.0313 - mape: 16701.9512
# Epoch 75: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 70ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0315 - mape: 15955.1045 - val_loss: 0.0010 - val_mse: 0.0010 - val_mae: 0.0252 - val_mape: 3.6798
# Epoch 76/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0022 - mse: 0.0022 - mae: 0.0314 - mape: 14810.4160
# Epoch 76: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 73ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0314 - mape: 14810.4160 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0281 - val_mape: 4.0933
# Epoch 77/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0026 - mse: 0.0026 - mae: 0.0337 - mape: 21101.9727
# Epoch 77: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 73ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0337 - mape: 21101.9727 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0352 - val_mape: 5.2512
# Epoch 78/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0027 - mse: 0.0027 - mae: 0.0342 - mape: 23251.9004
# Epoch 78: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 77ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0342 - mape: 23251.9004 - val_loss: 0.0041 - val_mse: 0.0041 - val_mae: 0.0543 - val_mape: 8.1740
# Epoch 79/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0023 - mse: 0.0023 - mae: 0.0325 - mape: 33553.9688
# Epoch 79: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 73ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0325 - mape: 33553.9688 - val_loss: 0.0026 - val_mse: 0.0026 - val_mae: 0.0416 - val_mape: 6.2511
# Epoch 80/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0023 - mse: 0.0023 - mae: 0.0322 - mape: 32483.3125
# Epoch 80: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 72ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0322 - mape: 32483.3125 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0447 - val_mape: 6.5143
# Epoch 81/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0025 - mse: 0.0025 - mae: 0.0331 - mape: 21292.1934
# Epoch 81: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 70ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0331 - mape: 21292.1934 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0324 - val_mape: 4.6805
# Epoch 82/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0021 - mse: 0.0021 - mae: 0.0308 - mape: 15195.1045
# Epoch 82: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 71ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0308 - mape: 15195.1045 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0474 - val_mape: 6.8998
# Epoch 83/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0021 - mse: 0.0021 - mae: 0.0307 - mape: 24588.4043
# Epoch 83: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 71ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0307 - mape: 24588.4043 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0548 - val_mape: 8.0841
# Epoch 84/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0024 - mse: 0.0024 - mae: 0.0339 - mape: 7729.4282
# Epoch 84: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 71ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0339 - mape: 7729.4282 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0491 - val_mape: 7.2193
# Epoch 85/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0026 - mse: 0.0026 - mae: 0.0335 - mape: 10051.1475
# Epoch 85: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 98ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0335 - mape: 10051.1475 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0318 - val_mape: 4.6839
# Epoch 86/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0020 - mse: 0.0020 - mae: 0.0297 - mape: 21692.8770
# Epoch 86: val_loss did not improve from 0.00082
# 15/15 [==============================] - 1s 99ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0297 - mape: 21692.8770 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0386 - val_mape: 5.6883
# Epoch 87/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0024 - mse: 0.0024 - mae: 0.0314 - mape: 16976.3887
# Epoch 87: val_loss did not improve from 0.00082
# 15/15 [==============================] - 2s 101ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0314 - mape: 16976.3887 - val_loss: 0.0048 - val_mse: 0.0048 - val_mae: 0.0602 - val_mape: 8.9135
# 8/8 [==============================] - 0s 25ms/step - loss: 5.0652e-04 - mse: 5.0652e-04 - mae: 0.0182 - mape: 2.4155

# %%
predicted_values = perform_model_predictions(model, x_test_sw, y_remaining)
# Out:
# 1/1 [==============================] - 0s 27ms/step

# %%
gt_scaled = scaler.inverse_transform(y_test_sw)
pred_scaled = scaler.inverse_transform(predicted_values[:-1])

print('RMSE ($ unscaled): ' + str(calculate_rmse(y_test_sw, predicted_values[:-1])))  # average AMOUNT (unscaled) the predictions are away from ground truth
print('RMSE ($): ' + str(calculate_rmse(gt_scaled, pred_scaled))) # average AMOUNT (in $) the predictions are away from ground truth
print('MAPE (%): ' + str(calculate_mape(y_test_sw, predicted_values[:-1]))) # average PERCENTAGE the predictions are away from ground truth
# Out:
# RMSE ($ unscaled): 0.049112187587670546
# RMSE ($): 15.332826228504166
# MAPE (%): 0.04956538821066065

# %%
predicted_x_axis, ground_truth_x_axis = prepare_x_axis_prediction_ground_truth(y_train_sw, y_test_sw, predicted_values)
print(ground_truth_x_axis.size)
# Out:
# 2312

# %%
gt_value = scaler.inverse_transform([y_test_sw[-1]])[0][0].round(2)
print(ticker + ' ' + target_col + ' for today is $' + str(gt_value))
adjusted_pred = calculate_adjusted_prediction(scaler, predicted_values, y_test_sw)
percent_difference = abs((adjusted_pred - gt_value) * 100 / (gt_value)).round(2)
plus_or_minus = '+' if adjusted_pred > gt_value else '-'

print('This represents ' + plus_or_minus + str(percent_difference) + '% difference from todays ' + target_col)
# Out:
# QQQ Close for today is $363.37
# The adjusted final prediction value is $363.5
# This represents +0.04% difference from todays Close

# %%
plot_prediction_vs_gt(scaler, predicted_x_axis, ground_truth_x_axis, start_date, end_date, train_data_len, train_validation_split, sliding_window_size, adjusted_pred, target_col)
plot_loss_chart(history)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_daily_close(df_copy, ticker, start_date, end_date)
plot_daily_returns(df_copy, ticker, start_date, end_date)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
(correct, incorrect, under, over, 
        correct_upwards_under, correct_upwards_over, correct_downwards_under, correct_downwards_over, 
        incorrect_upwards_under, incorrect_upwards_over, incorrect_downwards_under, incorrect_downwards_over
        ) = calculate_pie_chart_values(y_test_sw, predicted_values, tolerance_percent=tolerance_percent)

plot_pie_categories(
        tolerance_percent, 
        correct_upwards_under, correct_downwards_under, incorrect_upwards_under, incorrect_downwards_under, 
        correct_upwards_over, correct_downwards_over, incorrect_upwards_over, incorrect_downwards_over)
plot_pie_correctness(correct, incorrect)
plot_pie_tolerance(tolerance_percent, under, over)
# Out:
# Number of times the model predicted CORRECT direction: 112
# Number of times the model predicted INCORRECT direction: 114
# Number of times the model predicted UNDER 2% tolerance: 51
# Number of times the model predicted OVER 2% tolerance: 175
# Number of times the model CORRECTLY predicted UPWARD movement UNDER 2% tolerance: 15
# Number of times the model CORRECTLY predicted UPWARD movement OVER 2% tolerance: 7
# Number of times the model CORRECTLY predicted DOWNWARD movement UNDER 2% tolerance: 28
# Number of times the model CORRECTLY predicted DOWNWARD movement OVER 2% tolerance: 62
# Number of times the model INCORRECTLY predicted UPWARD movement UNDER 2% tolerance: 2
# Number of times the model INCORRECTLY predicted UPWARD movement OVER 2% tolerance: 17
# Number of times the model INCORRECTLY predicted DOWNWARD movement UNDER 2% tolerance: 6
# Number of times the model INCORRECTLY predicted DOWNWARD movement OVER 2% tolerance: 89
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
