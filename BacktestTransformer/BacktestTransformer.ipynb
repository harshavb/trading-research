# %% [markdown]
# ##### Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
import keras
from keras import layers
from keras import Input
from keras import Model
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping

# %% [markdown]
# ##### Miscellaneous

# %%
# Used for interactive plots (zooming in)
# %matplotlib widget

np.set_printoptions(threshold=np.inf, linewidth=300)

tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Data acquisition method

# %% [markdown]
# ##### Load from file (obtained through data extraction tool)

# %%
# loads stock data (along with other column data) into a dataframe. Gets start and end date as well from data points.
def get_stock_data_and_period_csv(filepath: str):
    df = pd.read_csv(filepath)

    start_date = df['Date'].iloc[0]
    end_date = df['Date'].iloc[-1]

    print('Time Period: ' + str(start_date) + ' to ' + str(end_date))

    return df, start_date, end_date

# %% [markdown]
# # Data Transform

# %%
# creates a copy of the dataframe
def dataframe_copy(df: pd.DataFrame):
    df_copy = df.copy()
    return df_copy

# %%
# cleans the dataframe by removing date, and dropping rows with nan values.
def dataframe_clean(df: pd.DataFrame):
    clean_df = df.dropna()
    clean_df = clean_df.drop(['Date'], axis=1)  # we remove 'Date' here so the original data is untouched.
    return clean_df

# %%
# prints out dataframe shape, number of columns, and sum of null values.
def dataframe_stats(df: pd.DataFrame):
    print(df.shape)
    print(df.columns)
    print(df.isnull().sum())

# %% [markdown]
# ##### Preparing data for loading into model

# %%
# sets a column as the first column in a dataframe by swapping the location of the first column and the column we want to switch.
def set_column_as_first(df: pd.DataFrame, col_name: str):
    col_loc = df.columns.get_loc(col_name)
    if col_loc != 0:
        cols = list(df.columns)
        a, b = cols.index(col_name), cols.index(df.columns[0])
        cols[b], cols[a] = cols[a], cols[b]
        df = df[cols]
    
    return df

# %%
# used for plotting purposes
def scaler_fit_column(df: pd.DataFrame, target: str = 'Close'):
    scaler = MinMaxScaler(feature_range=(0, 1))   # fit to data, used by graphs to plot prices instead of values in the (0, 1) range
    scaler.fit(df[[target]])

    return scaler

# %%
# transforms the data by using a scaler, and returns a copy of that data
def transform_data(df: pd.DataFrame):
    # Scale the data
    cols = df.columns

    scaler = MinMaxScaler(feature_range=(0, 1))
    df_scaled = scaler.fit_transform(df)    # fit and transform for all data
    df_scaled = pd.DataFrame(df_scaled)
    df_scaled.columns = cols

    return df_scaled

# %%
# by default, the target is the 'Close' price of the stock
def get_features_and_target(df: pd.DataFrame, target: str = 'Close'):
    df_features = df
    df_target = df[[target]]

    return df_features, df_target

# %% [markdown]
# ##### Train Data Setup

# %%
# creates train datasets
def setup_train_data(features: pd.DataFrame, target: pd.DataFrame, train_data_percent: float = 0.8):
    train_data_len = math.ceil(len(features.to_numpy()) * train_data_percent)

    train_x = features[0:train_data_len].to_numpy()
    train_y = target[0:train_data_len].to_numpy()

    return train_x, train_y, train_data_len

# %%
# prepares the train data as a sliding window with a configurable sliding window size
def prepare_train_as_sliding_window(train_x, train_y, sliding_window_size: int = 5):
    x_train_sw = []
    y_train_sw = []

    # The sliding window size (in days) we use as input. There are 5 trading days in a week
    for i in range(sliding_window_size, len(train_x)):
        x_train_sw.append(train_x[i-sliding_window_size:i,:])
        y_train_sw.append(train_y[i:i+1, 0])

    x_train_sw, y_train_sw = np.array(x_train_sw), np.array(y_train_sw)   # convert to numpy array

    return x_train_sw, y_train_sw

# %%
# creates test datasets
def setup_test_data(features, target, train_data_len):
    test_x = features[train_data_len:].to_numpy()
    test_y = target[train_data_len:].to_numpy()

    return test_x, test_y

# %%
# prepares the test data as a sliding window with a configurable sliding window size
def prepare_test_as_sliding_window(test_x, test_y, sliding_window_size: int = 5):
    x_test_sw = []  # features
    y_test_sw = []  # target
    y_remaining = []    # features remaining

    for i in range(sliding_window_size, len(test_x)):
        x_test_sw.append(test_x[i-sliding_window_size:i,:])
        y_test_sw.append(test_y[i:i+1,0])
        y_remaining.append(test_x[i:i+1,1:])

    x_test_sw = np.array(x_test_sw)
    y_test_sw = np.array(y_test_sw)
    y_remaining = np.array(y_remaining)

    return x_test_sw, y_test_sw, y_remaining

# %% [markdown]
# # Transformer Model

# %%
# creates a transformer encoder block
def transformer_encoder(
    inputs, 
    head_size, 
    num_heads, 
    ff_dim, 
    dropout=0.0
):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

# %%
# builds the model with some encoder blocks, dense layers, and output layer
def build_model(    
    x_train_sw,
    sliding_window_size: int = 5,
    head_size=128,
    num_heads=16,
    ff_dim=8,
    num_transformer_blocks=8,
    mlp_units=128,
    mlp_dropout=0.05,
    dropout=0.05,
):
    input_shape = x_train_sw.shape[1:]
    input_shape = (sliding_window_size, input_shape[1])
    inputs = Input(shape=input_shape)

    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    mlp_units_array = [mlp_units]
    for dim in mlp_units_array:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(1)(x)    # this tells us that the output is one prediction step.
    return Model(inputs, outputs)

# %% [markdown]
# ##### Model Callbacks

# %%
# returns callbacks, you can add new callbacks by putting them here
def get_model_callbacks():
    # Adding EarlyStopping callback (for lots of epochs)
    # 33 is a nice sweet spot for allowing a stagnant model in training to get back to reducing validation loss.
    early_stopping = EarlyStopping(patience=33, restore_best_weights=True)

    # Adding ModelCheckpoint callback
    # Define the path to save the best weights. The best weights will be restored in training when new validation loss is higher than the previous validation loss.
    checkpoint_path = 'best_weights.h5'
    checkpoint = ModelCheckpoint(checkpoint_path, save_best_only=True, save_weights_only=True, monitor='val_loss', mode='min', verbose=1)

    model_callbacks = [early_stopping, checkpoint]

    return model_callbacks

# %% [markdown]
# ##### Model Creation and Training

# %%
# simply compiles the model with some metrics and a learning rate
def compile_model(model: Model, metrics=['mse', 'mae', 'mape'], learning_rate=0.0001):
    model.compile(
    loss="mean_squared_error",
    optimizer=keras.optimizers.Adam(learning_rate=learning_rate), 
    metrics=metrics
    )

    return model

# General guidelines for hyperparameters
# - head_size and mlp_units should be large values (i.e. 256 for head_size and mlp_units, 8 num_heads, ff_dim, num_transformer_blocks)
# - you can't just keep increasing the hyperparameter values, memory is your constraint.

# %% [markdown]
# ##### Model Fitting

# %%
# trains the model, increase epochs to increase training time, and increase batch size to train faster at the cost of more memory (and a little accuracy?)
def train_model(model: Model, model_callbacks, x_train, y_train, train_validation_split: float = 0.8, epochs: int = 20, batch_size: int = 128):  
    # A higher train_validation_split value will mean more data is used for training, less for validation.
    history = model.fit(
                x_train,
                y_train,
                validation_split=1-train_validation_split,  # lil bug was hiding here
                epochs=epochs,
                batch_size=batch_size,
                callbacks=model_callbacks
            )

    # Load the best weights into the model
    model.load_weights('best_weights.h5')

    return model, history

# %% [markdown]
# ##### Model Evaluation

# %%
# evaluates the model using test data
def evaluate_model(model: Model, x_test_sw, y_test_sw):
    model.evaluate(x_test_sw, y_test_sw, verbose=1)

# %% [markdown]
# ##### Performing Prediction Steps

# %%
# This function performs a single step prediction and adds supporting values from data for another prediction. Calling this multiple times resembles a multistep model.
# Prediction steps uses ground truth data (except target) per step.
def perform_prediction_step_on_ground_truth(model: Model, input_data, remaining_y):

    # reshape the input to (1, sliding_window_size, features)
    test_input = np.reshape(input_data, (1, input_data.shape[0], input_data.shape[1]))

    # perform a prediction step
    prediction_value = model.predict(test_input, verbose=0)
    last_gt_price = np.reshape(input_data[0][0], (1, 1))

    # concatenate the prediction value to beginning of the data columns
    final = np.concatenate((last_gt_price, remaining_y), axis=1)

    # concatenate the input data to the beginning of
    test_x = np.concatenate((input_data, final), axis=0)

    # shifting the sliding window one step forward
    test_x = test_x[1:]

    return test_x, prediction_value

# %%
# This function performs a single step prediction without adding feature values. 
def perform_prediction_step_tomorrow(model: Model, input_data):
    test_input = np.reshape(input_data,(1,input_data.shape[0], input_data.shape[1]))
    prediction_value = model.predict(test_input)
    return prediction_value

# %%
# gathers the predictions from the model and returns them
def perform_model_predictions(model, test_x, y_remaining):
    prediction_values = []
    new_test_x = test_x[0].copy()

    # Repeated single step prediction with the available data
    for i in range(y_remaining.shape[0]):
        new_test_x, prediction = perform_prediction_step_on_ground_truth(model, new_test_x, y_remaining[i])
        prediction_values.append(prediction)

    # Single step prediction into the future!
    prediction = perform_prediction_step_tomorrow(model, new_test_x)
    prediction_values.append(prediction)

    pred_vals = np.array(prediction_values)
    pred_vals = pred_vals.squeeze(1)

    return pred_vals

# %% [markdown]
# ##### RMSE

# %%
# RMSE calculation
def calculate_rmse(ground_truth, predicted):
    rmse = mean_squared_error(ground_truth, predicted, squared=False)
    return rmse

# %%
# MAPE calculation
def calculate_mape(ground_truth, predicted):
    mape = mean_absolute_percentage_error(ground_truth, predicted)
    return mape

# %% [markdown]
# # Output

# %%
# Calculate the adjusted final prediction value so that the value is only offsetted by the prediction
# In other words, use the final ground truth value instead of the second to last prediction value as the "starting point".
def calculate_adjusted_prediction(scaler: MinMaxScaler, predicted_values, ground_truth_values):
    last_pred = predicted_values[-1]    # last prediction
    adjusted_pred = last_pred + (ground_truth_values[-1] - predicted_values[-2])   # adjusted prediction = last prediction + (last GT - 2nd to last prediction)
    adjusted_pred = scaler.inverse_transform([adjusted_pred])[0][0].round(2)
    print('The adjusted final prediction value is $' + str(adjusted_pred))
    return adjusted_pred

# %% [markdown]
# #### Preparation for Graph Output

# %%
# creates two axes: one for prediction and one for ground truth
def prepare_x_axis_prediction_ground_truth(y_train_sw, y_test_sw, predicted_values): 
    # we are concatenating the train data in order to show predicted values on top of ground truth values. This includes the single prediction step into the future.
    predicted = np.concatenate((y_train_sw, predicted_values), axis=0)
    ground_truth = np.concatenate((y_train_sw, y_test_sw), axis=0)

    return predicted, ground_truth

# %% [markdown]
# #### Prediction vs Ground Truth Graph

# %%
# plots the prediction vs ground truth, as well as the future prediction value
def plot_prediction_vs_gt(scaler: MinMaxScaler, predicted, ground_truth, start_date, end_date, train_data_len, train_validation_split, sliding_window_size, adjusted_prediction, target):
    # Use the unscaled data to see prices
    scaler_pred = scaler.inverse_transform(predicted)
    scaler_ground_truth = scaler.inverse_transform(ground_truth)
    gt_with_adj_pred = np.concatenate((scaler_ground_truth, [[adjusted_prediction]]))
    #scaler_pred_adj = scaler.inverse_transform(idk)

    plt.figure(figsize=(15, 6))

    # Adding the predicted, ground truth, and tomorrow's prediction
    plt.plot(scaler_pred.flatten(), label='Next Trading Day Prediction', color='#0000FF')
    plt.plot(gt_with_adj_pred.flatten(), label='Adjusted Next Trading Day Prediction', color='#F000F0')
    plt.plot(scaler_pred[:-1].flatten(), label='Predicted', color='#00FF00')
    plt.plot(scaler_ground_truth.flatten(), label='Ground Truth', color='#FF8800')

    # Adding vertical lines indicating different data usages
    plt.axvline(x=0, label='Train', color='#FF0000', ls=(0, (1, 4)))  # this data was used for model training by keras.
    plt.axvline(x=train_data_len * train_validation_split, label='Validation', color='#00FF00', ls=(0, (1, 4)))   # this data was used for model validation by keras.
    plt.axvline(x=scaler_ground_truth.size - (scaler_pred.size - train_data_len) - sliding_window_size, label='Test', color='#0000FF', ls=(0, (1, 4)))   # this is the test data - predictions are made on it, and we can compare it to ground truth.
    handles, labels = plt.gca().get_legend_handles_labels()
    order = [3,2,0,1,4,5,6]   #1,2,0,3,4,5

    plt.xlabel('Date (' + start_date + ' to ' + end_date + ') + 1')
    plt.ylabel('Stock Price ($)')
    plt.title(target + ': Prediction vs Ground Truth')
    plt.legend([handles[idx] for idx in order], [labels[idx] for idx in order])
    plt.grid(alpha=0.2)
    plt.savefig('Prediction.png')
    plt.show()

# %% [markdown]
# #### Daily Closing Prices

# %%
# plots daily closing prices
def plot_daily_close(df: pd.DataFrame, ticker: str, start_date, end_date):
    # Plotting daily closing prices
    plt.figure(figsize=(12, 6))
    plt.plot(df['Close'], linestyle='-')    # df['Date'], 
    plt.xlabel('Date (' + start_date + ' to ' + end_date + ')')
    plt.gca().set_xticklabels([])
    plt.xticks([])
    plt.ylabel('Closing Price')
    plt.title(ticker + ' Daily Closing Prices')
    plt.show()

# %% [markdown]
# #### Daily Stock Returns

# %%
# plots daily returns
def plot_daily_returns(df: pd.DataFrame, ticker: str, start_date, end_date):
    df['Daily_Return'] = df['Close'].pct_change()
    df.dropna(inplace=True)

    plt.figure(figsize=(12, 6))

    # Plotting daily stock returns
    plt.plot(df['Daily_Return'][1:], linestyle='-') # df['Date'][1:], 
    plt.xlabel('Date (' + start_date + ' to ' + end_date + ')')
    plt.gca().set_xticklabels([])
    plt.xticks([])
    plt.ylabel('Daily Return')
    plt.title(ticker + ' Daily Stock Return')
    plt.show()

# %% [markdown]
# #### Loss from Training and Validation

# %%
# plots the train and validation loss
def plot_loss_chart(history):
    # Accessing training and validation loss from the history object
    training_loss = history.history['loss']
    validation_loss = history.history['val_loss']

    # Generating a list of epochs (x-axis)
    epochs = range(1, len(training_loss) + 1)


    plt.figure(figsize=(8, 4))

    # Plotting the training and validation loss over iterations
    plt.plot(epochs, training_loss, label='Training Loss', linestyle='-')
    plt.plot(epochs, validation_loss, label='Validation Loss', linestyle='-')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.show()

# %% [markdown]
# #### Pie charts

# %%
# prepares the pie chart values for correctness, tolerance, and prediction movement
def calculate_pie_chart_values(ground_truth, predicted, tolerance_percent: int = 2):
    # Getting data for pie chart
    pie_chart_data = pd.DataFrame({
        'Predicted': predicted[:-1].flatten(),  # remove last predicted 'future' value
        'Ground_Truth': ground_truth.flatten()
    })


    # Calculating all of the necessary things for the pie chart.

    # tolerance = ((pred - gt) / gt) * 100 < tolerance_percent  # determines if the model predicted under some tolerance percent
    # gt movement = gtcurr - gtprev > 0                         # determines if the ground truth movement was up or down
    # pred movement = pred - gtprev > 0                         # determines if the model prediction was up or down
    # if the gt movement and prediction movement are both T or F, then the model predicted correctly upwards/downards.
    # if the gt movement and prediction movement are T/F or F/T, then the model predicted incorrectly downwards for T/F and incorrectly upwards for F/T
    # if the tolerance is under the %, then the model predicted accurately.
    # if the tolerance is over the %, then the model predicted inaccurately.

    predicted_values = np.array(pie_chart_data['Predicted'])
    ground_truth_values = np.array(pie_chart_data['Ground_Truth'])

    #tolerance_percent = 2   # integer used to determine if the model was accurate or not. 1 = 1% tolerance
    tolerance = []
    ground_truth_movement = []  # T is up, F is down
    prediction_movement = []    # T is up, F is down

    # append bool values to each array based on the requirements
    for i in range(1, ground_truth_values.size):
        tolerance.append(True if abs((predicted_values[i] - ground_truth_values[i]) / ground_truth_values[i]) * 100 < tolerance_percent else False)
        ground_truth_movement.append(True if ground_truth_values[i] - ground_truth_values[i-1] > 0 else False)
        prediction_movement.append(True if predicted_values[i] - ground_truth_values[i-1] > 0 else False)



    # Categorizations of model movement prediction, ground truth movement, and tolerance 
    correct = 0
    incorrect = 0
    under = 0
    over = 0

    correct_upwards_under = 0
    correct_upwards_over = 0
    correct_downwards_under = 0
    correct_downwards_over = 0
    incorrect_upwards_under = 0
    incorrect_upwards_over = 0
    incorrect_downwards_under = 0
    incorrect_downwards_over = 0



    # TODO research a cleaner way of doing this...
    for i in range(0, ground_truth_values.size - 1):
        correct += int((ground_truth_movement[i] == True and prediction_movement[i] == True) or (ground_truth_movement[i] == False and prediction_movement[i] == False))     # model predicted correct direction
        incorrect += int((ground_truth_movement[i] == True and prediction_movement[i] == False) or (ground_truth_movement[i] == False and prediction_movement[i] == True))  # model predicted wrong direction
        under += int(tolerance[i] == True)  # model predicted under tolerance
        over += int(tolerance[i] == False)  # model predicted over tolerance

        correct_upwards_under += int(ground_truth_movement[i] == True and prediction_movement[i] == True and tolerance[i] == True)         # model predicted correctly upwards under tolerance
        correct_upwards_over += int(ground_truth_movement[i] == True and prediction_movement[i] == True and tolerance[i] == False)         # model predicted correctly updwards over tolerance
        correct_downwards_under += int(ground_truth_movement[i] == False and prediction_movement[i] == False and tolerance[i] == True)     # model predicted correctly downwards under tolerance
        correct_downwards_over += int(ground_truth_movement[i] == False and prediction_movement[i] == False and tolerance[i] == False)     # model predicted correctly downwards over tolerance
        incorrect_upwards_under += int(ground_truth_movement[i] == False and prediction_movement[i] == True and tolerance[i] == True)      # model predicted incorrectly upwards under tolerance
        incorrect_upwards_over += int(ground_truth_movement[i] == False and prediction_movement[i] == True and tolerance[i] == False)      # model predicted incorrectly upwards over tolerance
        incorrect_downwards_under += int(ground_truth_movement[i] == True and prediction_movement[i] == False and tolerance[i] == True)    # model predicted incorrectly downwards under tolerance
        incorrect_downwards_over += int(ground_truth_movement[i] == True and prediction_movement[i] == False and tolerance[i] == False)    # model predicted incorrectly downwards over tolerance

    tol_per = str(tolerance_percent)
    print('Number of times the model predicted CORRECT direction: ' + str(correct))
    print('Number of times the model predicted INCORRECT direction: ' + str(incorrect))
    print('Number of times the model predicted UNDER ' + tol_per + '% tolerance: ' + str(under))
    print('Number of times the model predicted OVER ' + tol_per + '% tolerance: ' + str(over))

    print('Number of times the model CORRECTLY predicted UPWARD movement UNDER ' + tol_per + '% tolerance: ' + str(correct_upwards_under))
    print('Number of times the model CORRECTLY predicted UPWARD movement OVER ' + tol_per + '% tolerance: ' + str(correct_upwards_over))
    print('Number of times the model CORRECTLY predicted DOWNWARD movement UNDER ' + tol_per + '% tolerance: ' + str(correct_downwards_under))
    print('Number of times the model CORRECTLY predicted DOWNWARD movement OVER ' + tol_per + '% tolerance: ' + str(correct_downwards_over))
    print('Number of times the model INCORRECTLY predicted UPWARD movement UNDER ' + tol_per + '% tolerance: ' + str(incorrect_upwards_under))
    print('Number of times the model INCORRECTLY predicted UPWARD movement OVER ' + tol_per + '% tolerance: ' + str(incorrect_upwards_over))
    print('Number of times the model INCORRECTLY predicted DOWNWARD movement UNDER ' + tol_per + '% tolerance: ' + str(incorrect_downwards_under))
    print('Number of times the model INCORRECTLY predicted DOWNWARD movement OVER ' + tol_per + '% tolerance: ' + str(incorrect_downwards_over))

    # big tuple idk how else to do it...
    return (correct, incorrect, under, over, 
        correct_upwards_under, correct_upwards_over, correct_downwards_under, correct_downwards_over, 
        incorrect_upwards_under, incorrect_upwards_over, incorrect_downwards_under, incorrect_downwards_over)

# %%
# Helper function to remove zero-percent percentages from the pie chart
def auto_percent(pct):
    return ('%1.1f%%' % pct) if pct > 0 else ''

# %%
# Data for the pie chart. Use any of these to sort the data by their respective values.
def plot_pie_categories(tolerance_percent, correct_upwards_under, correct_downwards_under, incorrect_upwards_under, incorrect_downwards_under, correct_upwards_over, correct_downwards_over, incorrect_upwards_over, incorrect_downwards_over):
    # the below are only used for plot_pie_categories
    #labels_correctness = ['Correct Upwards Under', 'Correct Upwards Over', 'Correct Downwards Under', 'Correct Downwards Over', 'Incorrect Upwards Under', 'Incorrect Upwards Over', 'Incorrect Downwards Under', 'Incorrect Downwards Over']
    #sizes_correctness = [correct_upwards_under, correct_upwards_over, correct_downwards_under, correct_downwards_over, incorrect_upwards_under, incorrect_upwards_over, incorrect_downwards_under, incorrect_downwards_over]
    labels_tolerance = ['Correct Upwards Under', 'Correct Downwards Under', 'Incorrect Upwards Under', 'Incorrect Downwards Under', 'Correct Upwards Over', 'Correct Downwards Over', 'Incorrect Upwards Over', 'Incorrect Downwards Over']
    sizes_tolerance = [correct_upwards_under, correct_downwards_under, incorrect_upwards_under, incorrect_downwards_under, correct_upwards_over, correct_downwards_over, incorrect_upwards_over, incorrect_downwards_over]

    colors = ['#00FF00', '#00AA00', '#FFFF00', '#AAAA44', '#00FFFF', '#008B8B', '#FF0000', '#880000']

    plt.figure(figsize=(12, 6))

    # Create the pie chart
    plt.pie(sizes_tolerance, labels=labels_tolerance, labeldistance=None, autopct=auto_percent, startangle=0, colors=colors)
    plt.legend(labels_tolerance, loc='best', bbox_to_anchor=(1.05, 1))
    plt.title('Model Correctness-Directionality-Tolerance Summary (' + str(tolerance_percent) + '% tolerance)')
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.show()

# %%
# plots the correctness chart (the model's movement vs the ground truth movement)
def plot_pie_correctness(correct: int, incorrect: int):
    colors=['#00FF00', '#FF0000']
    correctness = [correct, incorrect]
    correctness_labels = ['Correct', 'Incorrect']

    plt.figure(figsize=(12, 6))
    plt.pie(correctness, labels=['Correct', 'incorrect'], labeldistance=None, autopct=auto_percent, startangle=0, colors=colors)
    plt.legend(correctness_labels, loc='best', bbox_to_anchor=(1.05, 1))
    plt.title('Model Correctness (Directionality)')
    plt.axis('equal')
    plt.show()

# %%
# plots the tolerance chart (how close the price was to gt price)
def plot_pie_tolerance(tolerance_percent: int, under: int, over: int):
    colors=['#00FF00', '#FF0000']
    under_over = [under, over]
    under_over_labels = ['Under', 'Over']

    plt.figure(figsize=(12, 6))
    plt.pie(under_over, labels=under_over_labels, labeldistance=None, autopct=auto_percent, startangle=0, colors=colors)
    plt.legend(under_over_labels, loc='best', bbox_to_anchor=(1.05, 1))
    plt.title('Model Tolerance (%' + str(tolerance_percent) + ')')
    plt.axis('equal')
    plt.show()

# %% [markdown]
# # The entire program

# %%
ticker = 'SPY'
target_col = 'Close'
filepath = 'data/ps_stock_data_' + ticker + '.csv'   # use 'ta_stock_data_TICKER.csv' for technical analysis, or 'ps_stock_data_TICKER.csv' for parallel stock.
# Technical Analysis columns
# columns_to_keep = [
#     'Date',                                     # always keep the dates
#     'Open', 'High', 'Low', 'Close', 'Volume',   # OHLCV - probably do not want to exclude
#     'rsi', 'macd', 'macd_signal', 'bbands_upper', 'bbands_middle', 'bbands_lower',  # TA - optional
#     'obv', 'adx', 'adx_pos', 'adx_neg', 'adi', 
#     'ema_50', 'sma_50'
#     ]
# Stock price columns
columns_to_keep = [
    'Date',                                     # always keep the dates
    'Open', 'High', 'Low', 'Close', 'Volume',   # OHLCV - probably do not want to exclude
    'AAPL', 'MSFT', 'GOOGL', 'TSLA', 'NVDA', 'META', 'NFLX'
    ]

train_data_percent = 0.9        # data split between train/validation and test      TrV <-> Te
train_validation_split = 0.9    # data split between train and validation           Tr <-> V
sliding_window_size = 5         # number of lags used as input, applied for every feature
tolerance_percent = 2           # percent used to accept a prediction as 'correct', after accounting for direction

# *** A Note on Train Validation Split for Stocks ***
#   There is a chance that, due to a stock price rising over the course of its history, the model may not be able to account for all possible input values.
#   Example: SPY has consistently gone up, and the model gets trained on the first 5 years of its history. 
#   After that, the inputs will undoubtedly be larger than the model expects, so its predictions are quite unstable.
#   The ideal training data contains the highest price recorded in the stock's history.

df, start_date, end_date = get_stock_data_and_period_csv(filepath)
df = df[columns_to_keep]

df
# Out:
# Time Period: 2013-10-07 to 2023-11-03
#             Date        Open        High         Low       Close     Volume  \
# 0     2013-10-07  167.419998  168.449997  167.250000  167.429993   96295000
# 1     2013-10-08  167.399994  167.619995  165.360001  165.479996  178015000
# 2     2013-10-09  165.800003  166.199997  164.529999  165.600006  168973000
# 3     2013-10-10  167.289993  169.259995  167.229996  169.169998  195955000
# 4     2013-10-11  168.910004  170.320007  168.770004  170.259995  105040000
# ...          ...         ...         ...         ...         ...        ...
# 2533  2023-10-30  413.559998  416.679993  412.220001  415.589996   86562700
# 2534  2023-10-31  416.179993  418.529999  414.209991  418.200012   79665200
# 2535  2023-11-01  419.200012  423.500000  418.649994  422.660004   98068100
# 2536  2023-11-02  426.579987  430.920013  426.559998  430.760010   94938900
# 2537  2023-11-03  433.140015  436.290009  433.010010  434.690002  100110800
#
#             AAPL        MSFT       GOOGL        TSLA        NVDA        META  \
# 0      17.419643   33.299999   21.665165   12.204667    3.897500   50.520000
# 1      17.176430   33.009998   21.363113   11.648667    3.865000   47.139999
# 2      17.378214   33.070000   21.417917   11.252000    3.805000   46.770000
# 3      17.487143   33.759998   21.727728   11.528667    3.847500   49.049999
# 4      17.600357   34.130001   21.821571   11.913333    3.815000   49.110001
# ...          ...         ...         ...         ...         ...         ...
# 2533  170.289993  337.309998  124.459999  197.360001  411.609985  302.660004
# 2534  170.770004  338.109985  124.080002  200.839996  407.799988  301.269989
# 2535  173.970001  346.070007  126.449997  205.660004  423.250000  311.850006
# 2536  177.570007  348.320007  127.489998  218.509995  435.059998  310.869995
# 2537  176.649994  352.799988  129.100006  219.960007  450.049988  314.600006
#
#             NFLX
# 0      45.451427
# 1      43.188572
# 2      41.204285
# 3      43.427143
# 4      42.978573
# ...          ...
# 2533  410.079987
# 2534  411.690002
# 2535  420.190002
# 2536  424.709991
# 2537  432.359985
#
# [2538 rows x 13 columns]

# %%
df_copy = dataframe_copy(df)
df = dataframe_clean(df)
dataframe_stats(df)

df
# Out:
# (2538, 12)
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'AAPL', 'MSFT', 'GOOGL',
#        'TSLA', 'NVDA', 'META', 'NFLX'],
#       dtype='object')
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# AAPL      0
# MSFT      0
# GOOGL     0
# TSLA      0
# NVDA      0
# META      0
# NFLX      0
# dtype: int64
#             Open        High         Low       Close     Volume        AAPL  \
# 0     167.419998  168.449997  167.250000  167.429993   96295000   17.419643
# 1     167.399994  167.619995  165.360001  165.479996  178015000   17.176430
# 2     165.800003  166.199997  164.529999  165.600006  168973000   17.378214
# 3     167.289993  169.259995  167.229996  169.169998  195955000   17.487143
# 4     168.910004  170.320007  168.770004  170.259995  105040000   17.600357
# ...          ...         ...         ...         ...        ...         ...
# 2533  413.559998  416.679993  412.220001  415.589996   86562700  170.289993
# 2534  416.179993  418.529999  414.209991  418.200012   79665200  170.770004
# 2535  419.200012  423.500000  418.649994  422.660004   98068100  173.970001
# 2536  426.579987  430.920013  426.559998  430.760010   94938900  177.570007
# 2537  433.140015  436.290009  433.010010  434.690002  100110800  176.649994
#
#             MSFT       GOOGL        TSLA        NVDA        META        NFLX
# 0      33.299999   21.665165   12.204667    3.897500   50.520000   45.451427
# 1      33.009998   21.363113   11.648667    3.865000   47.139999   43.188572
# 2      33.070000   21.417917   11.252000    3.805000   46.770000   41.204285
# 3      33.759998   21.727728   11.528667    3.847500   49.049999   43.427143
# 4      34.130001   21.821571   11.913333    3.815000   49.110001   42.978573
# ...          ...         ...         ...         ...         ...         ...
# 2533  337.309998  124.459999  197.360001  411.609985  302.660004  410.079987
# 2534  338.109985  124.080002  200.839996  407.799988  301.269989  411.690002
# 2535  346.070007  126.449997  205.660004  423.250000  311.850006  420.190002
# 2536  348.320007  127.489998  218.509995  435.059998  310.869995  424.709991
# 2537  352.799988  129.100006  219.960007  450.049988  314.600006  432.359985
#
# [2538 rows x 12 columns]

# %%
df = set_column_as_first(df, col_name=target_col)

df
# Out:
#            Close        High         Low        Open     Volume        AAPL  \
# 0     167.429993  168.449997  167.250000  167.419998   96295000   17.419643
# 1     165.479996  167.619995  165.360001  167.399994  178015000   17.176430
# 2     165.600006  166.199997  164.529999  165.800003  168973000   17.378214
# 3     169.169998  169.259995  167.229996  167.289993  195955000   17.487143
# 4     170.259995  170.320007  168.770004  168.910004  105040000   17.600357
# ...          ...         ...         ...         ...        ...         ...
# 2533  415.589996  416.679993  412.220001  413.559998   86562700  170.289993
# 2534  418.200012  418.529999  414.209991  416.179993   79665200  170.770004
# 2535  422.660004  423.500000  418.649994  419.200012   98068100  173.970001
# 2536  430.760010  430.920013  426.559998  426.579987   94938900  177.570007
# 2537  434.690002  436.290009  433.010010  433.140015  100110800  176.649994
#
#             MSFT       GOOGL        TSLA        NVDA        META        NFLX
# 0      33.299999   21.665165   12.204667    3.897500   50.520000   45.451427
# 1      33.009998   21.363113   11.648667    3.865000   47.139999   43.188572
# 2      33.070000   21.417917   11.252000    3.805000   46.770000   41.204285
# 3      33.759998   21.727728   11.528667    3.847500   49.049999   43.427143
# 4      34.130001   21.821571   11.913333    3.815000   49.110001   42.978573
# ...          ...         ...         ...         ...         ...         ...
# 2533  337.309998  124.459999  197.360001  411.609985  302.660004  410.079987
# 2534  338.109985  124.080002  200.839996  407.799988  301.269989  411.690002
# 2535  346.070007  126.449997  205.660004  423.250000  311.850006  420.190002
# 2536  348.320007  127.489998  218.509995  435.059998  310.869995  424.709991
# 2537  352.799988  129.100006  219.960007  450.049988  314.600006  432.359985
#
# [2538 rows x 12 columns]

# %%
scaler = scaler_fit_column(df, target=target_col)
df = transform_data(df)

df
# Out:
#          Close      High       Low      Open    Volume      AAPL      MSFT  \
# 0     0.006245  0.007171  0.008731  0.005169  0.156117  0.001357  0.000888
# 1     0.000000  0.004525  0.002664  0.005105  0.323929  0.000000  0.000000
# 2     0.000384  0.000000  0.000000  0.000000  0.305361  0.001126  0.000184
# 3     0.011818  0.009752  0.008667  0.004754  0.360769  0.001733  0.002297
# 4     0.015309  0.013130  0.013610  0.009923  0.174075  0.002365  0.003431
# ...        ...       ...       ...       ...       ...       ...       ...
# 2533  0.801044  0.798266  0.795076  0.790505  0.136132  0.854078  0.932063
# 2534  0.809403  0.804162  0.801464  0.798864  0.121968  0.856755  0.934514
# 2535  0.823688  0.820001  0.815716  0.808500  0.159758  0.874605  0.958895
# 2536  0.849630  0.843648  0.841107  0.832046  0.153332  0.894686  0.965787
# 2537  0.862217  0.860762  0.861811  0.852977  0.163953  0.889554  0.979509
#
#          GOOGL      TSLA      NVDA      META      NFLX
# 0     0.002351  0.010378  0.000531  0.016896  0.006529
# 1     0.000000  0.008995  0.000464  0.006877  0.003050
# 2     0.000427  0.008008  0.000342  0.005780  0.000000
# 3     0.002838  0.008696  0.000429  0.012539  0.003417
# 4     0.003568  0.009653  0.000362  0.012716  0.002728
# ...        ...       ...       ...       ...       ...
# 2533  0.802464  0.471036  0.832746  0.764287  0.567077
# 2534  0.799506  0.479694  0.824969  0.760167  0.569552
# 2535  0.817953  0.491686  0.856505  0.791528  0.582620
# 2536  0.826048  0.523656  0.880611  0.788623  0.589568
# 2537  0.838580  0.527264  0.911209  0.799680  0.601329
#
# [2538 rows x 12 columns]

# %%
features, target = get_features_and_target(df, target=target_col)

print(features.shape)
print(target.shape)
# Out:
# (2538, 12)
# (2538, 1)

# %%
features
# Out:
#          Close      High       Low      Open    Volume      AAPL      MSFT  \
# 0     0.006245  0.007171  0.008731  0.005169  0.156117  0.001357  0.000888
# 1     0.000000  0.004525  0.002664  0.005105  0.323929  0.000000  0.000000
# 2     0.000384  0.000000  0.000000  0.000000  0.305361  0.001126  0.000184
# 3     0.011818  0.009752  0.008667  0.004754  0.360769  0.001733  0.002297
# 4     0.015309  0.013130  0.013610  0.009923  0.174075  0.002365  0.003431
# ...        ...       ...       ...       ...       ...       ...       ...
# 2533  0.801044  0.798266  0.795076  0.790505  0.136132  0.854078  0.932063
# 2534  0.809403  0.804162  0.801464  0.798864  0.121968  0.856755  0.934514
# 2535  0.823688  0.820001  0.815716  0.808500  0.159758  0.874605  0.958895
# 2536  0.849630  0.843648  0.841107  0.832046  0.153332  0.894686  0.965787
# 2537  0.862217  0.860762  0.861811  0.852977  0.163953  0.889554  0.979509
#
#          GOOGL      TSLA      NVDA      META      NFLX
# 0     0.002351  0.010378  0.000531  0.016896  0.006529
# 1     0.000000  0.008995  0.000464  0.006877  0.003050
# 2     0.000427  0.008008  0.000342  0.005780  0.000000
# 3     0.002838  0.008696  0.000429  0.012539  0.003417
# 4     0.003568  0.009653  0.000362  0.012716  0.002728
# ...        ...       ...       ...       ...       ...
# 2533  0.802464  0.471036  0.832746  0.764287  0.567077
# 2534  0.799506  0.479694  0.824969  0.760167  0.569552
# 2535  0.817953  0.491686  0.856505  0.791528  0.582620
# 2536  0.826048  0.523656  0.880611  0.788623  0.589568
# 2537  0.838580  0.527264  0.911209  0.799680  0.601329
#
# [2538 rows x 12 columns]

# %%
target
# Out:
#          Close
# 0     0.006245
# 1     0.000000
# 2     0.000384
# 3     0.011818
# 4     0.015309
# ...        ...
# 2533  0.801044
# 2534  0.809403
# 2535  0.823688
# 2536  0.849630
# 2537  0.862217
#
# [2538 rows x 1 columns]

# %%
train_x, train_y, train_data_len = setup_train_data(features, target, train_data_percent)
x_train_sw, y_train_sw = prepare_train_as_sliding_window(train_x, train_y, sliding_window_size)

print(train_x.shape)
print(train_y.shape)
print(train_data_len)
print(x_train_sw.shape)
print(y_train_sw.shape)
# Out:
# (2285, 12)
# (2285, 1)
# 2285
# (2280, 5, 12)
# (2280, 1)

# %%
test_x, test_y = setup_test_data(features, target, train_data_len)
x_test_sw, y_test_sw, y_remaining = prepare_test_as_sliding_window(test_x, test_y, sliding_window_size)

print(test_x.shape)
print(test_y.shape)
print(x_test_sw.shape)
print(y_test_sw.shape)
print(y_remaining.shape)
# Out:
# (253, 12)
# (253, 1)
# (248, 5, 12)
# (248, 1)
# (248, 1, 11)

# %%
model = build_model(
    x_train_sw, 
    sliding_window_size,
    head_size=64,      # head size of multi-head attention of transformer encoder blocks            # low impact on training time
    num_heads=4,        # number of heads in multi-head attention of transformer encoder blocks     # low impact on training time
    ff_dim=4,           # number of filters in conv1d of transformer encoder blocks                 # medium impact on training time
    num_transformer_blocks=4,   # number of transformer encoder blocks                              # HIGH impact on training time
    mlp_units=64,      # number of mlp units                                                       # low impact on training time
    mlp_dropout=0.2,    # dropout of mlp units                                                      # reduces overfitting
    dropout=0.2         # dropout of multi-head attention transformer encoder blocks                # reduces overfitting
    )
model = compile_model(model, learning_rate=0.0001)

# %%
# the best model trains fast, achieves small validation loss, and scores a low RMSE value.
model, history = train_model(model, get_model_callbacks(), x_train_sw, y_train_sw, train_validation_split, epochs=100, batch_size=128)

# in general, a val_loss of ~0.00100 (or below) is usually an indicator that the model will perform well on training (~0.05 MAPE). Of course, it varies with luck.
evaluate_model(model, x_test_sw, y_test_sw)
# Out:
# Epoch 1/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.1018 - mse: 0.1018 - mae: 0.2421 - mape: 88.2556
# Epoch 1: val_loss improved from inf to 0.34262, saving model to best_weights.h5
# 17/17 [==============================] - 5s 84ms/step - loss: 0.1017 - mse: 0.1017 - mae: 0.2420 - mape: 88.3171 - val_loss: 0.3426 - val_mse: 0.3426 - val_mae: 0.5821 - val_mape: 72.6105
# Epoch 2/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0601 - mse: 0.0601 - mae: 0.1746 - mape: 65.3920
# Epoch 2: val_loss improved from 0.34262 to 0.19203, saving model to best_weights.h5
# 17/17 [==============================] - 1s 51ms/step - loss: 0.0603 - mse: 0.0603 - mae: 0.1748 - mape: 65.3474 - val_loss: 0.1920 - val_mse: 0.1920 - val_mae: 0.4342 - val_mape: 54.0293
# Epoch 3/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0422 - mse: 0.0422 - mae: 0.1459 - mape: 57.5055
# Epoch 3: val_loss improved from 0.19203 to 0.09378, saving model to best_weights.h5
# 17/17 [==============================] - 1s 57ms/step - loss: 0.0421 - mse: 0.0421 - mae: 0.1457 - mape: 57.4723 - val_loss: 0.0938 - val_mse: 0.0938 - val_mae: 0.3006 - val_mape: 37.2109
# Epoch 4/100
# 17/17 [==============================] - ETA: 0s - loss: 0.0341 - mse: 0.0341 - mae: 0.1310 - mape: 53.3408
# Epoch 4: val_loss improved from 0.09378 to 0.05915, saving model to best_weights.h5
# 17/17 [==============================] - 1s 57ms/step - loss: 0.0341 - mse: 0.0341 - mae: 0.1310 - mape: 53.3408 - val_loss: 0.0592 - val_mse: 0.0592 - val_mae: 0.2366 - val_mape: 29.2226
# Epoch 5/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0300 - mse: 0.0300 - mae: 0.1226 - mape: 49.3402
# Epoch 5: val_loss improved from 0.05915 to 0.04350, saving model to best_weights.h5
# 17/17 [==============================] - 1s 58ms/step - loss: 0.0300 - mse: 0.0300 - mae: 0.1226 - mape: 49.3317 - val_loss: 0.0435 - val_mse: 0.0435 - val_mae: 0.2007 - val_mape: 24.6791
# Epoch 6/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0269 - mse: 0.0269 - mae: 0.1131 - mape: 43.6921
# Epoch 6: val_loss improved from 0.04350 to 0.03514, saving model to best_weights.h5
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0268 - mse: 0.0268 - mae: 0.1130 - mape: 43.6514 - val_loss: 0.0351 - val_mse: 0.0351 - val_mae: 0.1787 - val_mape: 21.8811
# Epoch 7/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0241 - mse: 0.0241 - mae: 0.1076 - mape: 40.9546
# Epoch 7: val_loss improved from 0.03514 to 0.02467, saving model to best_weights.h5
# 17/17 [==============================] - 1s 60ms/step - loss: 0.0241 - mse: 0.0241 - mae: 0.1078 - mape: 40.9668 - val_loss: 0.0247 - val_mse: 0.0247 - val_mae: 0.1466 - val_mape: 17.8432
# Epoch 8/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0233 - mse: 0.0233 - mae: 0.1052 - mape: 40.3757
# Epoch 8: val_loss improved from 0.02467 to 0.01490, saving model to best_weights.h5
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0233 - mse: 0.0233 - mae: 0.1052 - mape: 40.3595 - val_loss: 0.0149 - val_mse: 0.0149 - val_mae: 0.1097 - val_mape: 13.2498
# Epoch 9/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0213 - mse: 0.0213 - mae: 0.0989 - mape: 35.9635
# Epoch 9: val_loss improved from 0.01490 to 0.01129, saving model to best_weights.h5
# 17/17 [==============================] - 1s 57ms/step - loss: 0.0213 - mse: 0.0213 - mae: 0.0987 - mape: 35.9034 - val_loss: 0.0113 - val_mse: 0.0113 - val_mae: 0.0936 - val_mape: 11.2836
# Epoch 10/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0178 - mse: 0.0178 - mae: 0.0916 - mape: 34.8717
# Epoch 10: val_loss improved from 0.01129 to 0.00974, saving model to best_weights.h5
# 17/17 [==============================] - 1s 57ms/step - loss: 0.0178 - mse: 0.0178 - mae: 0.0916 - mape: 34.8782 - val_loss: 0.0097 - val_mse: 0.0097 - val_mae: 0.0862 - val_mape: 10.3927
# Epoch 11/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0176 - mse: 0.0176 - mae: 0.0920 - mape: 34.4715
# Epoch 11: val_loss improved from 0.00974 to 0.00947, saving model to best_weights.h5
# 17/17 [==============================] - 1s 58ms/step - loss: 0.0176 - mse: 0.0176 - mae: 0.0920 - mape: 34.4602 - val_loss: 0.0095 - val_mse: 0.0095 - val_mae: 0.0849 - val_mape: 10.2576
# Epoch 12/100
# 17/17 [==============================] - ETA: 0s - loss: 0.0171 - mse: 0.0171 - mae: 0.0878 - mape: 31.9892
# Epoch 12: val_loss improved from 0.00947 to 0.00877, saving model to best_weights.h5
# 17/17 [==============================] - 1s 59ms/step - loss: 0.0171 - mse: 0.0171 - mae: 0.0878 - mape: 31.9892 - val_loss: 0.0088 - val_mse: 0.0088 - val_mae: 0.0812 - val_mape: 9.8184
# Epoch 13/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0150 - mse: 0.0150 - mae: 0.0837 - mape: 31.2105
# Epoch 13: val_loss improved from 0.00877 to 0.00587, saving model to best_weights.h5
# 17/17 [==============================] - 1s 58ms/step - loss: 0.0150 - mse: 0.0150 - mae: 0.0837 - mape: 31.2843 - val_loss: 0.0059 - val_mse: 0.0059 - val_mae: 0.0639 - val_mape: 7.7427
# Epoch 14/100
# 17/17 [==============================] - ETA: 0s - loss: 0.0167 - mse: 0.0167 - mae: 0.0863 - mape: 30.5880
# Epoch 14: val_loss did not improve from 0.00587
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0167 - mse: 0.0167 - mae: 0.0863 - mape: 30.5880 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0725 - val_mape: 8.7643
# Epoch 15/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0158 - mse: 0.0158 - mae: 0.0856 - mape: 31.6169
# Epoch 15: val_loss did not improve from 0.00587
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0158 - mse: 0.0158 - mae: 0.0857 - mape: 31.6112 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0686 - val_mape: 8.2968
# Epoch 16/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0135 - mse: 0.0135 - mae: 0.0796 - mape: 29.2527
# Epoch 16: val_loss improved from 0.00587 to 0.00498, saving model to best_weights.h5
# 17/17 [==============================] - 1s 59ms/step - loss: 0.0135 - mse: 0.0135 - mae: 0.0796 - mape: 29.2731 - val_loss: 0.0050 - val_mse: 0.0050 - val_mae: 0.0581 - val_mape: 7.0631
# Epoch 17/100
# 17/17 [==============================] - ETA: 0s - loss: 0.0127 - mse: 0.0127 - mae: 0.0765 - mape: 28.5489
# Epoch 17: val_loss improved from 0.00498 to 0.00417, saving model to best_weights.h5
# 17/17 [==============================] - 1s 58ms/step - loss: 0.0127 - mse: 0.0127 - mae: 0.0765 - mape: 28.5489 - val_loss: 0.0042 - val_mse: 0.0042 - val_mae: 0.0527 - val_mape: 6.4405
# Epoch 18/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0128 - mse: 0.0128 - mae: 0.0759 - mape: 29.4567
# Epoch 18: val_loss did not improve from 0.00417
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0128 - mse: 0.0128 - mae: 0.0759 - mape: 29.4366 - val_loss: 0.0044 - val_mse: 0.0044 - val_mae: 0.0543 - val_mape: 6.6046
# Epoch 19/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0117 - mse: 0.0117 - mae: 0.0732 - mape: 27.4581
# Epoch 19: val_loss improved from 0.00417 to 0.00410, saving model to best_weights.h5
# 17/17 [==============================] - 1s 58ms/step - loss: 0.0116 - mse: 0.0116 - mae: 0.0731 - mape: 27.4372 - val_loss: 0.0041 - val_mse: 0.0041 - val_mae: 0.0523 - val_mape: 6.3893
# Epoch 20/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0112 - mse: 0.0112 - mae: 0.0712 - mape: 26.9145
# Epoch 20: val_loss improved from 0.00410 to 0.00324, saving model to best_weights.h5
# 17/17 [==============================] - 1s 59ms/step - loss: 0.0112 - mse: 0.0112 - mae: 0.0712 - mape: 26.8993 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0459 - val_mape: 5.6878
# Epoch 21/100
# 17/17 [==============================] - ETA: 0s - loss: 0.0112 - mse: 0.0112 - mae: 0.0721 - mape: 26.8127
# Epoch 21: val_loss improved from 0.00324 to 0.00261, saving model to best_weights.h5
# 17/17 [==============================] - 1s 59ms/step - loss: 0.0112 - mse: 0.0112 - mae: 0.0721 - mape: 26.8127 - val_loss: 0.0026 - val_mse: 0.0026 - val_mae: 0.0414 - val_mape: 5.2271
# Epoch 22/100
# 17/17 [==============================] - ETA: 0s - loss: 0.0101 - mse: 0.0101 - mae: 0.0682 - mape: 26.4286
# Epoch 22: val_loss did not improve from 0.00261
# 17/17 [==============================] - 1s 55ms/step - loss: 0.0101 - mse: 0.0101 - mae: 0.0682 - mape: 26.4286 - val_loss: 0.0058 - val_mse: 0.0058 - val_mae: 0.0645 - val_mape: 7.8375
# Epoch 23/100
# 17/17 [==============================] - ETA: 0s - loss: 0.0097 - mse: 0.0097 - mae: 0.0676 - mape: 25.7761
# Epoch 23: val_loss did not improve from 0.00261
# 17/17 [==============================] - 1s 54ms/step - loss: 0.0097 - mse: 0.0097 - mae: 0.0676 - mape: 25.7761 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0498 - val_mape: 6.1283
# Epoch 24/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0095 - mse: 0.0095 - mae: 0.0666 - mape: 25.2562
# Epoch 24: val_loss did not improve from 0.00261
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0095 - mse: 0.0095 - mae: 0.0666 - mape: 25.2614 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0564 - val_mape: 6.9118
# Epoch 25/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0104 - mse: 0.0104 - mae: 0.0694 - mape: 25.3306
# Epoch 25: val_loss did not improve from 0.00261
# 17/17 [==============================] - 1s 55ms/step - loss: 0.0104 - mse: 0.0104 - mae: 0.0693 - mape: 25.3036 - val_loss: 0.0068 - val_mse: 0.0068 - val_mae: 0.0702 - val_mape: 8.5459
# Epoch 26/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0090 - mse: 0.0090 - mae: 0.0648 - mape: 24.2953
# Epoch 26: val_loss did not improve from 0.00261
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0090 - mse: 0.0090 - mae: 0.0648 - mape: 24.2910 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0493 - val_mape: 6.0714
# Epoch 27/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0088 - mse: 0.0088 - mae: 0.0635 - mape: 24.0562
# Epoch 27: val_loss did not improve from 0.00261
# 17/17 [==============================] - 1s 55ms/step - loss: 0.0088 - mse: 0.0088 - mae: 0.0634 - mape: 24.0495 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0515 - val_mape: 6.3132
# Epoch 28/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0077 - mse: 0.0077 - mae: 0.0618 - mape: 23.7418
# Epoch 28: val_loss did not improve from 0.00261
# 17/17 [==============================] - 1s 55ms/step - loss: 0.0077 - mse: 0.0077 - mae: 0.0617 - mape: 23.7490 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0503 - val_mape: 6.1843
# Epoch 29/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0081 - mse: 0.0081 - mae: 0.0617 - mape: 23.4692
# Epoch 29: val_loss did not improve from 0.00261
# 17/17 [==============================] - 1s 55ms/step - loss: 0.0081 - mse: 0.0081 - mae: 0.0616 - mape: 23.4841 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0433 - val_mape: 5.4176
# Epoch 30/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0083 - mse: 0.0083 - mae: 0.0612 - mape: 22.5743
# Epoch 30: val_loss did not improve from 0.00261
# 17/17 [==============================] - 1s 57ms/step - loss: 0.0083 - mse: 0.0083 - mae: 0.0611 - mape: 22.5564 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0446 - val_mape: 5.5486
# Epoch 31/100
# 17/17 [==============================] - ETA: 0s - loss: 0.0086 - mse: 0.0086 - mae: 0.0622 - mape: 23.2817
# Epoch 31: val_loss did not improve from 0.00261
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0086 - mse: 0.0086 - mae: 0.0622 - mape: 23.2817 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0449 - val_mape: 5.6031
# Epoch 32/100
# 17/17 [==============================] - ETA: 0s - loss: 0.0084 - mse: 0.0084 - mae: 0.0614 - mape: 22.9596
# Epoch 32: val_loss did not improve from 0.00261
# 17/17 [==============================] - 1s 50ms/step - loss: 0.0084 - mse: 0.0084 - mae: 0.0614 - mape: 22.9596 - val_loss: 0.0044 - val_mse: 0.0044 - val_mae: 0.0548 - val_mape: 6.7356
# Epoch 33/100
# 17/17 [==============================] - ETA: 0s - loss: 0.0077 - mse: 0.0077 - mae: 0.0592 - mape: 22.6951
# Epoch 33: val_loss did not improve from 0.00261
# 17/17 [==============================] - 1s 48ms/step - loss: 0.0077 - mse: 0.0077 - mae: 0.0592 - mape: 22.6951 - val_loss: 0.0044 - val_mse: 0.0044 - val_mae: 0.0545 - val_mape: 6.7089
# Epoch 34/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0078 - mse: 0.0078 - mae: 0.0584 - mape: 22.5231
# Epoch 34: val_loss did not improve from 0.00261
# 17/17 [==============================] - 1s 51ms/step - loss: 0.0078 - mse: 0.0078 - mae: 0.0585 - mape: 22.5123 - val_loss: 0.0035 - val_mse: 0.0035 - val_mae: 0.0482 - val_mape: 5.9622
# Epoch 35/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0079 - mse: 0.0079 - mae: 0.0591 - mape: 22.1949
# Epoch 35: val_loss did not improve from 0.00261
# 17/17 [==============================] - 1s 54ms/step - loss: 0.0078 - mse: 0.0078 - mae: 0.0591 - mape: 22.1929 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0435 - val_mape: 5.3637
# Epoch 36/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0066 - mse: 0.0066 - mae: 0.0546 - mape: 21.7468
# Epoch 36: val_loss did not improve from 0.00261
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0066 - mse: 0.0066 - mae: 0.0546 - mape: 21.7508 - val_loss: 0.0035 - val_mse: 0.0035 - val_mae: 0.0484 - val_mape: 5.9329
# Epoch 37/100
# 17/17 [==============================] - ETA: 0s - loss: 0.0075 - mse: 0.0075 - mae: 0.0584 - mape: 21.8753
# Epoch 37: val_loss did not improve from 0.00261
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0075 - mse: 0.0075 - mae: 0.0584 - mape: 21.8753 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0441 - val_mape: 5.4522
# Epoch 38/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0072 - mse: 0.0072 - mae: 0.0566 - mape: 20.7389
# Epoch 38: val_loss improved from 0.00261 to 0.00240, saving model to best_weights.h5
# 17/17 [==============================] - 1s 58ms/step - loss: 0.0072 - mse: 0.0072 - mae: 0.0565 - mape: 20.7274 - val_loss: 0.0024 - val_mse: 0.0024 - val_mae: 0.0394 - val_mape: 4.9334
# Epoch 39/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0071 - mse: 0.0071 - mae: 0.0560 - mape: 21.1598
# Epoch 39: val_loss improved from 0.00240 to 0.00231, saving model to best_weights.h5
# 17/17 [==============================] - 1s 59ms/step - loss: 0.0071 - mse: 0.0071 - mae: 0.0561 - mape: 21.1765 - val_loss: 0.0023 - val_mse: 0.0023 - val_mae: 0.0388 - val_mape: 4.8764
# Epoch 40/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0063 - mse: 0.0063 - mae: 0.0537 - mape: 20.7030
# Epoch 40: val_loss did not improve from 0.00231
# 17/17 [==============================] - 1s 54ms/step - loss: 0.0063 - mse: 0.0063 - mae: 0.0536 - mape: 20.6977 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0501 - val_mape: 6.1928
# Epoch 41/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0060 - mse: 0.0060 - mae: 0.0529 - mape: 20.9468
# Epoch 41: val_loss did not improve from 0.00231
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0060 - mse: 0.0060 - mae: 0.0529 - mape: 20.9755 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0487 - val_mape: 6.0365
# Epoch 42/100
# 17/17 [==============================] - ETA: 0s - loss: 0.0068 - mse: 0.0068 - mae: 0.0548 - mape: 20.6950
# Epoch 42: val_loss did not improve from 0.00231
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0068 - mse: 0.0068 - mae: 0.0548 - mape: 20.6950 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0444 - val_mape: 5.5135
# Epoch 43/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0067 - mse: 0.0067 - mae: 0.0554 - mape: 21.1169
# Epoch 43: val_loss improved from 0.00231 to 0.00224, saving model to best_weights.h5
# 17/17 [==============================] - 1s 58ms/step - loss: 0.0067 - mse: 0.0067 - mae: 0.0554 - mape: 21.1262 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0382 - val_mape: 4.8056
# Epoch 44/100
# 17/17 [==============================] - ETA: 0s - loss: 0.0074 - mse: 0.0074 - mae: 0.0563 - mape: 21.0731
# Epoch 44: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0563 - mape: 21.0731 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0436 - val_mape: 5.4047
# Epoch 45/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0060 - mse: 0.0060 - mae: 0.0533 - mape: 21.3768
# Epoch 45: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 54ms/step - loss: 0.0060 - mse: 0.0060 - mae: 0.0533 - mape: 21.3625 - val_loss: 0.0027 - val_mse: 0.0027 - val_mae: 0.0413 - val_mape: 5.1391
# Epoch 46/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0063 - mse: 0.0063 - mae: 0.0532 - mape: 20.8054
# Epoch 46: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0063 - mse: 0.0063 - mae: 0.0532 - mape: 20.7858 - val_loss: 0.0026 - val_mse: 0.0026 - val_mae: 0.0409 - val_mape: 5.1064
# Epoch 47/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0058 - mse: 0.0058 - mae: 0.0521 - mape: 20.5094
# Epoch 47: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0058 - mse: 0.0058 - mae: 0.0520 - mape: 20.4907 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0496 - val_mape: 6.1429
# Epoch 48/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0057 - mse: 0.0057 - mae: 0.0512 - mape: 20.3544
# Epoch 48: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0057 - mse: 0.0057 - mae: 0.0511 - mape: 20.3320 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0477 - val_mape: 5.9228
# Epoch 49/100
# 17/17 [==============================] - ETA: 0s - loss: 0.0057 - mse: 0.0057 - mae: 0.0507 - mape: 19.1975
# Epoch 49: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0057 - mse: 0.0057 - mae: 0.0507 - mape: 19.1975 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0436 - val_mape: 5.4385
# Epoch 50/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0054 - mse: 0.0054 - mae: 0.0495 - mape: 19.7268
# Epoch 50: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 51ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0496 - mape: 19.7188 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0735 - val_mape: 9.0868
# Epoch 51/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0063 - mse: 0.0063 - mae: 0.0526 - mape: 21.8648
# Epoch 51: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 54ms/step - loss: 0.0063 - mse: 0.0063 - mae: 0.0526 - mape: 21.8372 - val_loss: 0.0202 - val_mse: 0.0202 - val_mae: 0.1334 - val_mape: 16.5959
# Epoch 52/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0053 - mse: 0.0053 - mae: 0.0490 - mape: 19.0634
# Epoch 52: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0053 - mse: 0.0053 - mae: 0.0489 - mape: 19.0444 - val_loss: 0.0081 - val_mse: 0.0081 - val_mae: 0.0762 - val_mape: 9.4008
# Epoch 53/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0055 - mse: 0.0055 - mae: 0.0500 - mape: 19.5937
# Epoch 53: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0055 - mse: 0.0055 - mae: 0.0500 - mape: 19.5720 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0718 - val_mape: 8.8297
# Epoch 54/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0058 - mse: 0.0058 - mae: 0.0511 - mape: 20.4879
# Epoch 54: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 51ms/step - loss: 0.0058 - mse: 0.0058 - mae: 0.0511 - mape: 20.4676 - val_loss: 0.0043 - val_mse: 0.0043 - val_mae: 0.0535 - val_mape: 6.6036
# Epoch 55/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0050 - mse: 0.0050 - mae: 0.0466 - mape: 18.3635
# Epoch 55: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0465 - mape: 18.3349 - val_loss: 0.0040 - val_mse: 0.0040 - val_mae: 0.0513 - val_mape: 6.3469
# Epoch 56/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0050 - mse: 0.0050 - mae: 0.0474 - mape: 18.7994
# Epoch 56: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 54ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0475 - mape: 18.7925 - val_loss: 0.0061 - val_mse: 0.0061 - val_mae: 0.0661 - val_mape: 8.0931
# Epoch 57/100
# 17/17 [==============================] - ETA: 0s - loss: 0.0058 - mse: 0.0058 - mae: 0.0511 - mape: 20.4218
# Epoch 57: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0058 - mse: 0.0058 - mae: 0.0511 - mape: 20.4218 - val_loss: 0.0084 - val_mse: 0.0084 - val_mae: 0.0783 - val_mape: 9.6862
# Epoch 58/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0051 - mse: 0.0051 - mae: 0.0481 - mape: 18.8104
# Epoch 58: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0481 - mape: 18.7968 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0556 - val_mape: 6.9435
# Epoch 59/100
# 17/17 [==============================] - ETA: 0s - loss: 0.0047 - mse: 0.0047 - mae: 0.0458 - mape: 18.7360
# Epoch 59: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0458 - mape: 18.7360 - val_loss: 0.0041 - val_mse: 0.0041 - val_mae: 0.0516 - val_mape: 6.4765
# Epoch 60/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0049 - mse: 0.0049 - mae: 0.0473 - mape: 18.9421
# Epoch 60: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0049 - mse: 0.0049 - mae: 0.0474 - mape: 18.9403 - val_loss: 0.0041 - val_mse: 0.0041 - val_mae: 0.0522 - val_mape: 6.5317
# Epoch 61/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0047 - mse: 0.0047 - mae: 0.0456 - mape: 18.6396
# Epoch 61: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0455 - mape: 18.6251 - val_loss: 0.0060 - val_mse: 0.0060 - val_mae: 0.0637 - val_mape: 7.8806
# Epoch 62/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0044 - mse: 0.0044 - mae: 0.0448 - mape: 18.4403
# Epoch 62: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0448 - mape: 18.4712 - val_loss: 0.0092 - val_mse: 0.0092 - val_mae: 0.0829 - val_mape: 10.2796
# Epoch 63/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0046 - mse: 0.0046 - mae: 0.0460 - mape: 18.4291
# Epoch 63: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 54ms/step - loss: 0.0046 - mse: 0.0046 - mae: 0.0461 - mape: 18.4194 - val_loss: 0.0050 - val_mse: 0.0050 - val_mae: 0.0565 - val_mape: 7.0421
# Epoch 64/100
# 17/17 [==============================] - ETA: 0s - loss: 0.0047 - mse: 0.0047 - mae: 0.0458 - mape: 19.1447
# Epoch 64: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0458 - mape: 19.1447 - val_loss: 0.0092 - val_mse: 0.0092 - val_mae: 0.0828 - val_mape: 10.3375
# Epoch 65/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0040 - mse: 0.0040 - mae: 0.0439 - mape: 18.2297
# Epoch 65: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0438 - mape: 18.2121 - val_loss: 0.0084 - val_mse: 0.0084 - val_mae: 0.0789 - val_mape: 9.8706
# Epoch 66/100
# 17/17 [==============================] - ETA: 0s - loss: 0.0044 - mse: 0.0044 - mae: 0.0460 - mape: 18.8527
# Epoch 66: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 54ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0460 - mape: 18.8527 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0454 - val_mape: 5.7150
# Epoch 67/100
# 17/17 [==============================] - ETA: 0s - loss: 0.0045 - mse: 0.0045 - mae: 0.0453 - mape: 18.9425
# Epoch 67: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0453 - mape: 18.9425 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0601 - val_mape: 7.5367
# Epoch 68/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0040 - mse: 0.0040 - mae: 0.0426 - mape: 17.8788
# Epoch 68: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0425 - mape: 17.8598 - val_loss: 0.0048 - val_mse: 0.0048 - val_mae: 0.0559 - val_mape: 7.0352
# Epoch 69/100
# 17/17 [==============================] - ETA: 0s - loss: 0.0044 - mse: 0.0044 - mae: 0.0444 - mape: 17.8185
# Epoch 69: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0444 - mape: 17.8185 - val_loss: 0.0064 - val_mse: 0.0064 - val_mae: 0.0670 - val_mape: 8.3990
# Epoch 70/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0044 - mse: 0.0044 - mae: 0.0444 - mape: 18.4172
# Epoch 70: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0443 - mape: 18.3902 - val_loss: 0.0040 - val_mse: 0.0040 - val_mae: 0.0496 - val_mape: 6.2726
# Epoch 71/100
# 17/17 [==============================] - ETA: 0s - loss: 0.0043 - mse: 0.0043 - mae: 0.0446 - mape: 18.2087
# Epoch 71: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0446 - mape: 18.2087 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0500 - val_mape: 6.3116
# Epoch 72/100
# 17/17 [==============================] - ETA: 0s - loss: 0.0041 - mse: 0.0041 - mae: 0.0431 - mape: 17.6566
# Epoch 72: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0431 - mape: 17.6566 - val_loss: 0.0043 - val_mse: 0.0043 - val_mae: 0.0529 - val_mape: 6.6315
# Epoch 73/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0038 - mse: 0.0038 - mae: 0.0414 - mape: 17.9514
# Epoch 73: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0415 - mape: 17.9473 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0502 - val_mape: 6.2905
# Epoch 74/100
# 17/17 [==============================] - ETA: 0s - loss: 0.0044 - mse: 0.0044 - mae: 0.0451 - mape: 18.3068
# Epoch 74: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 54ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0451 - mape: 18.3068 - val_loss: 0.0046 - val_mse: 0.0046 - val_mae: 0.0551 - val_mape: 6.8626
# Epoch 75/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0042 - mse: 0.0042 - mae: 0.0448 - mape: 18.6274
# Epoch 75: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 54ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0449 - mape: 18.6545 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0459 - val_mape: 5.7989
# Epoch 76/100
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0044 - mse: 0.0044 - mae: 0.0459 - mape: 18.9435
# Epoch 76: val_loss did not improve from 0.00224
# 17/17 [==============================] - 1s 56ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0459 - mape: 18.9431 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0451 - val_mape: 5.7972
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0329 - mape: 4.0869

# %%
predicted_values = perform_model_predictions(model, x_test_sw, y_remaining)
# Out:
# 1/1 [==============================] - 0s 29ms/step

# %%
gt_scaled = scaler.inverse_transform(y_test_sw)
pred_scaled = scaler.inverse_transform(predicted_values[:-1])

print('RMSE ($ unscaled): ' + str(calculate_rmse(y_test_sw, predicted_values[:-1])))  # average AMOUNT (unscaled) the predictions are away from ground truth
print('RMSE ($): ' + str(calculate_rmse(gt_scaled, pred_scaled))) # average AMOUNT (in $) the predictions are away from ground truth
print('MAPE (%): ' + str(calculate_mape(y_test_sw, predicted_values[:-1]))) # average PERCENTAGE the predictions are away from ground truth
# Out:
# RMSE ($ unscaled): 0.042228410265911384
# RMSE ($): 13.184979132808234
# MAPE (%): 0.04209696521539936

# %%
predicted_x_axis, ground_truth_x_axis = prepare_x_axis_prediction_ground_truth(y_train_sw, y_test_sw, predicted_values)
print(ground_truth_x_axis.size)
# Out:
# 2528

# %%
gt_value = scaler.inverse_transform([y_test_sw[-1]])[0][0].round(2)
print(ticker + ' ' + target_col + ' for today is $' + str(gt_value))
adjusted_pred = calculate_adjusted_prediction(scaler, predicted_values, y_test_sw)
percent_difference = abs((adjusted_pred - gt_value) * 100 / (gt_value)).round(2)
plus_or_minus = '+' if adjusted_pred > gt_value else '-'

print('This represents ' + plus_or_minus + str(percent_difference) + '% difference from todays ' + target_col)
# Out:
# SPY Close for today is $434.69
# The adjusted final prediction value is $434.89
# This represents +0.05% difference from todays Close

# %%
plot_prediction_vs_gt(scaler, predicted_x_axis, ground_truth_x_axis, start_date, end_date, train_data_len, train_validation_split, sliding_window_size, adjusted_pred, target_col)
plot_loss_chart(history)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_daily_close(df_copy, ticker, start_date, end_date)
plot_daily_returns(df_copy, ticker, start_date, end_date)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
(correct, incorrect, under, over, 
        correct_upwards_under, correct_upwards_over, correct_downwards_under, correct_downwards_over, 
        incorrect_upwards_under, incorrect_upwards_over, incorrect_downwards_under, incorrect_downwards_over
        ) = calculate_pie_chart_values(y_test_sw, predicted_values, tolerance_percent=tolerance_percent)

plot_pie_categories(
        tolerance_percent, 
        correct_upwards_under, correct_downwards_under, incorrect_upwards_under, incorrect_downwards_under, 
        correct_upwards_over, correct_downwards_over, incorrect_upwards_over, incorrect_downwards_over)
plot_pie_correctness(correct, incorrect)
plot_pie_tolerance(tolerance_percent, under, over)
# Out:
# Number of times the model predicted CORRECT direction: 129
# Number of times the model predicted INCORRECT direction: 118
# Number of times the model predicted UNDER 2% tolerance: 86
# Number of times the model predicted OVER 2% tolerance: 161
# Number of times the model CORRECTLY predicted UPWARD movement UNDER 2% tolerance: 47
# Number of times the model CORRECTLY predicted UPWARD movement OVER 2% tolerance: 60
# Number of times the model CORRECTLY predicted DOWNWARD movement UNDER 2% tolerance: 17
# Number of times the model CORRECTLY predicted DOWNWARD movement OVER 2% tolerance: 5
# Number of times the model INCORRECTLY predicted UPWARD movement UNDER 2% tolerance: 15
# Number of times the model INCORRECTLY predicted UPWARD movement OVER 2% tolerance: 83
# Number of times the model INCORRECTLY predicted DOWNWARD movement UNDER 2% tolerance: 7
# Number of times the model INCORRECTLY predicted DOWNWARD movement OVER 2% tolerance: 13
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
