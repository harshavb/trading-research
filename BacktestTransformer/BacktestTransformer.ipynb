# %% [markdown]
# ##### Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
import keras
from keras import layers
from keras import Input
from keras import Model
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping

# %% [markdown]
# ##### Miscellaneous

# %%
# Used for interactive plots (zooming in)
# %matplotlib widget

np.set_printoptions(threshold=np.inf, linewidth=300)

tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Data acquisition method

# %% [markdown]
# ##### Load from file (obtained through data extraction tool)

# %%
# loads stock data (along with other column data) into a dataframe. Gets start and end date as well from data points.
def get_stock_data_and_period_csv(filepath: str):
    df = pd.read_csv(filepath)

    start_date = df['Date'].iloc[0]
    end_date = df['Date'].iloc[-1]

    print('Time Period: ' + str(start_date) + ' to ' + str(end_date))

    return df, start_date, end_date

# %% [markdown]
# # Data Transform

# %%
# creates a copy of the dataframe
def dataframe_copy(df: pd.DataFrame):
    df_copy = df.copy()
    return df_copy

# %%
# cleans the dataframe by removing date, and dropping rows with nan values.
def dataframe_clean(df: pd.DataFrame):
    clean_df = df.dropna()
    clean_df = clean_df.drop(['Date'], axis=1)  # we remove 'Date' here so the original data is untouched.
    return clean_df

# %%
# prints out dataframe shape, number of columns, and sum of null values.
def dataframe_stats(df: pd.DataFrame):
    print(df.shape)
    print(df.columns)
    print(df.isnull().sum())

# %% [markdown]
# ##### Preparing data for loading into model

# %%
# sets a column as the first column in a dataframe by swapping the location of the first column and the column we want to switch.
def set_column_as_first(df: pd.DataFrame, col_name: str):
    col_loc = df.columns.get_loc(col_name)
    if col_loc != 0:
        cols = list(df.columns)
        a, b = cols.index(col_name), cols.index(df.columns[0])
        cols[b], cols[a] = cols[a], cols[b]
        df = df[cols]
    
    return df

# %%
# used for plotting purposes
def scaler_fit_column(df: pd.DataFrame, target: str = 'Close'):
    scaler = MinMaxScaler(feature_range=(0, 1))   # fit to data, used by graphs to plot prices instead of values in the (0, 1) range
    scaler.fit(df[[target]])

    return scaler

# %%
# transforms the data by using a scaler, and returns a copy of that data
def transform_data(df: pd.DataFrame):
    # Scale the data
    cols = df.columns

    scaler = MinMaxScaler(feature_range=(0, 1))
    df_scaled = scaler.fit_transform(df)    # fit and transform for all data
    df_scaled = pd.DataFrame(df_scaled)
    df_scaled.columns = cols

    return df_scaled

# %%
# by default, the target is the 'Close' price of the stock
def get_features_and_target(df: pd.DataFrame, target: str = 'Close'):
    df_features = df
    df_target = df[[target]]

    return df_features, df_target

# %% [markdown]
# ##### Train Data Setup

# %%
# creates train datasets
def setup_train_data(features: pd.DataFrame, target: pd.DataFrame, train_data_percent: float = 0.8):
    train_data_len = math.ceil(len(features.to_numpy()) * train_data_percent)

    train_x = features[0:train_data_len].to_numpy()
    train_y = target[0:train_data_len].to_numpy()

    return train_x, train_y, train_data_len

# %%
# prepares the train data as a sliding window with a configurable sliding window size
def prepare_train_as_sliding_window(train_x, train_y, sliding_window_size: int = 5):
    x_train_sw = []
    y_train_sw = []

    # The sliding window size (in days) we use as input. There are 5 trading days in a week
    for i in range(sliding_window_size, len(train_x)):
        x_train_sw.append(train_x[i-sliding_window_size:i,:])
        y_train_sw.append(train_y[i:i+1, 0])

    x_train_sw, y_train_sw = np.array(x_train_sw), np.array(y_train_sw)   # convert to numpy array

    return x_train_sw, y_train_sw

# %%
# creates test datasets
def setup_test_data(features, target, train_data_len):
    test_x = features[train_data_len:].to_numpy()
    test_y = target[train_data_len:].to_numpy()

    return test_x, test_y

# %%
# prepares the test data as a sliding window with a configurable sliding window size
def prepare_test_as_sliding_window(test_x, test_y, sliding_window_size: int = 5):
    x_test_sw = []  # features
    y_test_sw = []  # target
    y_remaining = []    # features remaining

    for i in range(sliding_window_size, len(test_x)):
        x_test_sw.append(test_x[i-sliding_window_size:i,:])
        y_test_sw.append(test_y[i:i+1,0])
        y_remaining.append(test_x[i:i+1,1:])

    x_test_sw = np.array(x_test_sw)
    y_test_sw = np.array(y_test_sw)
    y_remaining = np.array(y_remaining)

    return x_test_sw, y_test_sw, y_remaining

# %% [markdown]
# # Transformer Model

# %%
# creates a transformer encoder block
def transformer_encoder(
    inputs, 
    head_size, 
    num_heads, 
    ff_dim, 
    dropout=0.0
):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

# %%
# builds the model with some encoder blocks, dense layers, and output layer
def build_model(    
    x_train_sw,
    sliding_window_size: int = 5,
    head_size=128,
    num_heads=16,
    ff_dim=8,
    num_transformer_blocks=8,
    mlp_units=128,
    mlp_dropout=0.05,
    dropout=0.05,
):
    input_shape = x_train_sw.shape[1:]
    input_shape = (sliding_window_size, input_shape[1])
    inputs = Input(shape=input_shape)

    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    mlp_units_array = [mlp_units]
    for dim in mlp_units_array:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(1)(x)    # this tells us that the output is one prediction step.
    return Model(inputs, outputs)

# %% [markdown]
# ##### Model Callbacks

# %%
# returns callbacks, you can add new callbacks by putting them here
def get_model_callbacks():
    # Adding EarlyStopping callback (for lots of epochs)
    # 33 is a nice sweet spot for allowing a stagnant model in training to get back to reducing validation loss.
    early_stopping = EarlyStopping(patience=33, restore_best_weights=True)

    # Adding ModelCheckpoint callback
    # Define the path to save the best weights. The best weights will be restored in training when new validation loss is higher than the previous validation loss.
    checkpoint_path = 'best_weights.h5'
    checkpoint = ModelCheckpoint(checkpoint_path, save_best_only=True, save_weights_only=True, monitor='val_loss', mode='min', verbose=1)

    model_callbacks = [early_stopping, checkpoint]

    return model_callbacks

# %% [markdown]
# ##### Model Creation and Training

# %%
# simply compiles the model with some metrics and a learning rate
def compile_model(model: Model, metrics=['mse', 'mae', 'mape'], learning_rate=0.0001):
    model.compile(
    loss="mean_squared_error",
    optimizer=keras.optimizers.Adam(learning_rate=learning_rate), 
    metrics=metrics
    )

    return model

# General guidelines for hyperparameters
# - head_size and mlp_units should be large values (i.e. 256 for head_size and mlp_units, 8 num_heads, ff_dim, num_transformer_blocks)
# - you can't just keep increasing the hyperparameter values, memory is your constraint.

# %% [markdown]
# ##### Model Fitting

# %%
# trains the model, increase epochs to increase training time, and increase batch size to train faster at the cost of more memory (and a little accuracy?)
def train_model(model: Model, model_callbacks, x_train, y_train, train_validation_split: float = 0.8, epochs: int = 20, batch_size: int = 128):  
    # A higher train_validation_split value will mean more data is used for training, less for validation.
    history = model.fit(
                x_train,
                y_train,
                validation_split=1-train_validation_split,  # lil bug was hiding here
                epochs=epochs,
                batch_size=batch_size,
                callbacks=model_callbacks
            )

    # Load the best weights into the model
    model.load_weights('best_weights.h5')

    return model, history

# %% [markdown]
# ##### Model Evaluation

# %%
# evaluates the model using test data
def evaluate_model(model: Model, x_test_sw, y_test_sw):
    model.evaluate(x_test_sw, y_test_sw, verbose=1)

# %% [markdown]
# ##### Performing Prediction Steps

# %%
# This function performs a single step prediction and adds supporting values from data for another prediction. Calling this multiple times resembles a multistep model.
# Prediction steps uses ground truth data (except target) per step.
def perform_prediction_step_on_ground_truth(model: Model, input_data, remaining_y):

    # reshape the input to (1, sliding_window_size, features)
    test_input = np.reshape(input_data, (1, input_data.shape[0], input_data.shape[1]))

    # perform a prediction step
    prediction_value = model.predict(test_input, verbose=0)
    last_gt_price = np.reshape(input_data[0][0], (1, 1))

    # concatenate the prediction value to beginning of the data columns
    final = np.concatenate((last_gt_price, remaining_y), axis=1)

    # concatenate the input data to the beginning of
    test_x = np.concatenate((input_data, final), axis=0)

    # shifting the sliding window one step forward
    test_x = test_x[1:]

    return test_x, prediction_value

# %%
# This function performs a single step prediction without adding feature values. 
def perform_prediction_step_tomorrow(model: Model, input_data):
    test_input = np.reshape(input_data,(1,input_data.shape[0], input_data.shape[1]))
    prediction_value = model.predict(test_input)
    return prediction_value

# %%
# gathers the predictions from the model and returns them
def perform_model_predictions(model, test_x, y_remaining):
    prediction_values = []
    new_test_x = test_x[0].copy()

    # Repeated single step prediction with the available data
    for i in range(y_remaining.shape[0]):
        new_test_x, prediction = perform_prediction_step_on_ground_truth(model, new_test_x, y_remaining[i])
        prediction_values.append(prediction)

    # Single step prediction into the future!
    prediction = perform_prediction_step_tomorrow(model, new_test_x)
    prediction_values.append(prediction)

    pred_vals = np.array(prediction_values)
    pred_vals = pred_vals.squeeze(1)

    return pred_vals

# %% [markdown]
# ##### RMSE

# %%
# RMSE calculation
def calculate_rmse(ground_truth, predicted):
    rmse = mean_squared_error(ground_truth, predicted, squared=False)
    return rmse

# %%
# MAPE calculation
def calculate_mape(ground_truth, predicted):
    mape = mean_absolute_percentage_error(ground_truth, predicted)
    return mape

# %% [markdown]
# # Output

# %%
# Calculate the adjusted final prediction value so that the value is only offsetted by the prediction
# In other words, use the final ground truth value instead of the second to last prediction value as the "starting point".
def calculate_adjusted_prediction(scaler: MinMaxScaler, predicted_values, ground_truth_values):
    last_pred = predicted_values[-1]    # last prediction
    adjusted_pred = last_pred + (ground_truth_values[-1] - predicted_values[-2])   # adjusted prediction = last prediction + (last GT - 2nd to last prediction)
    adjusted_pred = scaler.inverse_transform([adjusted_pred])[0][0].round(2)
    print('The adjusted final prediction value is $' + str(adjusted_pred))
    return adjusted_pred

# %% [markdown]
# #### Preparation for Graph Output

# %%
# creates two axes: one for prediction and one for ground truth
def prepare_x_axis_prediction_ground_truth(y_train_sw, y_test_sw, predicted_values): 
    # we are concatenating the train data in order to show predicted values on top of ground truth values. This includes the single prediction step into the future.
    predicted = np.concatenate((y_train_sw, predicted_values), axis=0)
    ground_truth = np.concatenate((y_train_sw, y_test_sw), axis=0)

    return predicted, ground_truth

# %% [markdown]
# #### Prediction vs Ground Truth Graph

# %%
# plots the prediction vs ground truth, as well as the future prediction value
def plot_prediction_vs_gt(scaler: MinMaxScaler, predicted, ground_truth, start_date, end_date, train_data_len, train_validation_split, sliding_window_size, adjusted_prediction, target):
    # Use the unscaled data to see prices
    scaler_pred = scaler.inverse_transform(predicted)
    scaler_ground_truth = scaler.inverse_transform(ground_truth)
    gt_with_adj_pred = np.concatenate((scaler_ground_truth, [[adjusted_prediction]]))
    #scaler_pred_adj = scaler.inverse_transform(idk)

    plt.figure(figsize=(15, 6))

    # Adding the predicted, ground truth, and tomorrow's prediction
    plt.plot(scaler_pred.flatten(), label='Next Trading Day Prediction', color='#0000FF')
    plt.plot(gt_with_adj_pred.flatten(), label='Adjusted Next Trading Day Prediction', color='#F000F0')
    plt.plot(scaler_pred[:-1].flatten(), label='Predicted', color='#00FF00')
    plt.plot(scaler_ground_truth.flatten(), label='Ground Truth', color='#FF8800')

    # Adding vertical lines indicating different data usages
    plt.axvline(x=0, label='Train', color='#FF0000', ls=(0, (1, 4)))  # this data was used for model training by keras.
    plt.axvline(x=train_data_len * train_validation_split, label='Validation', color='#00FF00', ls=(0, (1, 4)))   # this data was used for model validation by keras.
    plt.axvline(x=scaler_ground_truth.size - (scaler_pred.size - train_data_len) - sliding_window_size, label='Test', color='#0000FF', ls=(0, (1, 4)))   # this is the test data - predictions are made on it, and we can compare it to ground truth.
    handles, labels = plt.gca().get_legend_handles_labels()
    order = [3,2,0,1,4,5,6]   #1,2,0,3,4,5

    plt.xlabel('Date (' + start_date + ' to ' + end_date + ') + 1')
    plt.ylabel('Stock Price ($)')
    plt.title(target + ': Prediction vs Ground Truth')
    plt.legend([handles[idx] for idx in order], [labels[idx] for idx in order])
    plt.grid(alpha=0.2)
    plt.savefig('Prediction.png')
    plt.show()

# %% [markdown]
# #### Daily Closing Prices

# %%
# plots daily closing prices
def plot_daily_close(df: pd.DataFrame, ticker: str, start_date, end_date):
    # Plotting daily closing prices
    plt.figure(figsize=(12, 6))
    plt.plot(df['Close'], linestyle='-')    # df['Date'], 
    plt.xlabel('Date (' + start_date + ' to ' + end_date + ')')
    plt.gca().set_xticklabels([])
    plt.xticks([])
    plt.ylabel('Closing Price')
    plt.title(ticker + ' Daily Closing Prices')
    plt.show()

# %% [markdown]
# #### Daily Stock Returns

# %%
# plots daily returns
def plot_daily_returns(df: pd.DataFrame, ticker: str, start_date, end_date):
    df['Daily_Return'] = df['Close'].pct_change()
    df.dropna(inplace=True)

    plt.figure(figsize=(12, 6))

    # Plotting daily stock returns
    plt.plot(df['Daily_Return'][1:], linestyle='-') # df['Date'][1:], 
    plt.xlabel('Date (' + start_date + ' to ' + end_date + ')')
    plt.gca().set_xticklabels([])
    plt.xticks([])
    plt.ylabel('Daily Return')
    plt.title(ticker + ' Daily Stock Return')
    plt.show()

# %% [markdown]
# #### Loss from Training and Validation

# %%
# plots the train and validation loss
def plot_loss_chart(history):
    # Accessing training and validation loss from the history object
    training_loss = history.history['loss']
    validation_loss = history.history['val_loss']

    # Generating a list of epochs (x-axis)
    epochs = range(1, len(training_loss) + 1)


    plt.figure(figsize=(8, 4))

    # Plotting the training and validation loss over iterations
    plt.plot(epochs, training_loss, label='Training Loss', linestyle='-')
    plt.plot(epochs, validation_loss, label='Validation Loss', linestyle='-')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.show()

# %% [markdown]
# #### Pie charts

# %%
# prepares the pie chart values for correctness, tolerance, and prediction movement
def calculate_pie_chart_values(ground_truth, predicted, tolerance_percent: int = 2):
    # Getting data for pie chart
    pie_chart_data = pd.DataFrame({
        'Predicted': predicted[:-1].flatten(),  # remove last predicted 'future' value
        'Ground_Truth': ground_truth.flatten()
    })


    # Calculating all of the necessary things for the pie chart.

    # tolerance = ((pred - gt) / gt) * 100 < tolerance_percent  # determines if the model predicted under some tolerance percent
    # gt movement = gtcurr - gtprev > 0                         # determines if the ground truth movement was up or down
    # pred movement = pred - gtprev > 0                         # determines if the model prediction was up or down
    # if the gt movement and prediction movement are both T or F, then the model predicted correctly upwards/downards.
    # if the gt movement and prediction movement are T/F or F/T, then the model predicted incorrectly downwards for T/F and incorrectly upwards for F/T
    # if the tolerance is under the %, then the model predicted accurately.
    # if the tolerance is over the %, then the model predicted inaccurately.

    predicted_values = np.array(pie_chart_data['Predicted'])
    ground_truth_values = np.array(pie_chart_data['Ground_Truth'])

    #tolerance_percent = 2   # integer used to determine if the model was accurate or not. 1 = 1% tolerance
    tolerance = []
    ground_truth_movement = []  # T is up, F is down
    prediction_movement = []    # T is up, F is down

    # append bool values to each array based on the requirements
    for i in range(1, ground_truth_values.size):
        tolerance.append(True if abs((predicted_values[i] - ground_truth_values[i]) / ground_truth_values[i]) * 100 < tolerance_percent else False)
        ground_truth_movement.append(True if ground_truth_values[i] - ground_truth_values[i-1] > 0 else False)
        prediction_movement.append(True if predicted_values[i] - ground_truth_values[i-1] > 0 else False)



    # Categorizations of model movement prediction, ground truth movement, and tolerance 
    correct = 0
    incorrect = 0
    under = 0
    over = 0

    correct_upwards_under = 0
    correct_upwards_over = 0
    correct_downwards_under = 0
    correct_downwards_over = 0
    incorrect_upwards_under = 0
    incorrect_upwards_over = 0
    incorrect_downwards_under = 0
    incorrect_downwards_over = 0



    # TODO research a cleaner way of doing this...
    for i in range(0, ground_truth_values.size - 1):
        correct += int((ground_truth_movement[i] == True and prediction_movement[i] == True) or (ground_truth_movement[i] == False and prediction_movement[i] == False))     # model predicted correct direction
        incorrect += int((ground_truth_movement[i] == True and prediction_movement[i] == False) or (ground_truth_movement[i] == False and prediction_movement[i] == True))  # model predicted wrong direction
        under += int(tolerance[i] == True)  # model predicted under tolerance
        over += int(tolerance[i] == False)  # model predicted over tolerance

        correct_upwards_under += int(ground_truth_movement[i] == True and prediction_movement[i] == True and tolerance[i] == True)         # model predicted correctly upwards under tolerance
        correct_upwards_over += int(ground_truth_movement[i] == True and prediction_movement[i] == True and tolerance[i] == False)         # model predicted correctly updwards over tolerance
        correct_downwards_under += int(ground_truth_movement[i] == False and prediction_movement[i] == False and tolerance[i] == True)     # model predicted correctly downwards under tolerance
        correct_downwards_over += int(ground_truth_movement[i] == False and prediction_movement[i] == False and tolerance[i] == False)     # model predicted correctly downwards over tolerance
        incorrect_upwards_under += int(ground_truth_movement[i] == False and prediction_movement[i] == True and tolerance[i] == True)      # model predicted incorrectly upwards under tolerance
        incorrect_upwards_over += int(ground_truth_movement[i] == False and prediction_movement[i] == True and tolerance[i] == False)      # model predicted incorrectly upwards over tolerance
        incorrect_downwards_under += int(ground_truth_movement[i] == True and prediction_movement[i] == False and tolerance[i] == True)    # model predicted incorrectly downwards under tolerance
        incorrect_downwards_over += int(ground_truth_movement[i] == True and prediction_movement[i] == False and tolerance[i] == False)    # model predicted incorrectly downwards over tolerance

    tol_per = str(tolerance_percent)
    print('Number of times the model predicted CORRECT direction: ' + str(correct))
    print('Number of times the model predicted INCORRECT direction: ' + str(incorrect))
    print('Number of times the model predicted UNDER ' + tol_per + '% tolerance: ' + str(under))
    print('Number of times the model predicted OVER ' + tol_per + '% tolerance: ' + str(over))

    print('Number of times the model CORRECTLY predicted UPWARD movement UNDER ' + tol_per + '% tolerance: ' + str(correct_upwards_under))
    print('Number of times the model CORRECTLY predicted UPWARD movement OVER ' + tol_per + '% tolerance: ' + str(correct_upwards_over))
    print('Number of times the model CORRECTLY predicted DOWNWARD movement UNDER ' + tol_per + '% tolerance: ' + str(correct_downwards_under))
    print('Number of times the model CORRECTLY predicted DOWNWARD movement OVER ' + tol_per + '% tolerance: ' + str(correct_downwards_over))
    print('Number of times the model INCORRECTLY predicted UPWARD movement UNDER ' + tol_per + '% tolerance: ' + str(incorrect_upwards_under))
    print('Number of times the model INCORRECTLY predicted UPWARD movement OVER ' + tol_per + '% tolerance: ' + str(incorrect_upwards_over))
    print('Number of times the model INCORRECTLY predicted DOWNWARD movement UNDER ' + tol_per + '% tolerance: ' + str(incorrect_downwards_under))
    print('Number of times the model INCORRECTLY predicted DOWNWARD movement OVER ' + tol_per + '% tolerance: ' + str(incorrect_downwards_over))

    # big tuple idk how else to do it...
    return (correct, incorrect, under, over, 
        correct_upwards_under, correct_upwards_over, correct_downwards_under, correct_downwards_over, 
        incorrect_upwards_under, incorrect_upwards_over, incorrect_downwards_under, incorrect_downwards_over)

# %%
# Helper function to remove zero-percent percentages from the pie chart
def auto_percent(pct):
    return ('%1.1f%%' % pct) if pct > 0 else ''

# %%
# Data for the pie chart. Use any of these to sort the data by their respective values.
def plot_pie_categories(tolerance_percent, correct_upwards_under, correct_downwards_under, incorrect_upwards_under, incorrect_downwards_under, correct_upwards_over, correct_downwards_over, incorrect_upwards_over, incorrect_downwards_over):
    # the below are only used for plot_pie_categories
    #labels_correctness = ['Correct Upwards Under', 'Correct Upwards Over', 'Correct Downwards Under', 'Correct Downwards Over', 'Incorrect Upwards Under', 'Incorrect Upwards Over', 'Incorrect Downwards Under', 'Incorrect Downwards Over']
    #sizes_correctness = [correct_upwards_under, correct_upwards_over, correct_downwards_under, correct_downwards_over, incorrect_upwards_under, incorrect_upwards_over, incorrect_downwards_under, incorrect_downwards_over]
    labels_tolerance = ['Correct Upwards Under', 'Correct Downwards Under', 'Incorrect Upwards Under', 'Incorrect Downwards Under', 'Correct Upwards Over', 'Correct Downwards Over', 'Incorrect Upwards Over', 'Incorrect Downwards Over']
    sizes_tolerance = [correct_upwards_under, correct_downwards_under, incorrect_upwards_under, incorrect_downwards_under, correct_upwards_over, correct_downwards_over, incorrect_upwards_over, incorrect_downwards_over]

    colors = ['#00FF00', '#00AA00', '#FFFF00', '#AAAA44', '#00FFFF', '#008B8B', '#FF0000', '#880000']

    plt.figure(figsize=(12, 6))

    # Create the pie chart
    plt.pie(sizes_tolerance, labels=labels_tolerance, labeldistance=None, autopct=auto_percent, startangle=0, colors=colors)
    plt.legend(labels_tolerance, loc='best', bbox_to_anchor=(1.05, 1))
    plt.title('Model Correctness-Directionality-Tolerance Summary (' + str(tolerance_percent) + '% tolerance)')
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.show()

# %%
# plots the correctness chart (the model's movement vs the ground truth movement)
def plot_pie_correctness(correct: int, incorrect: int):
    colors=['#00FF00', '#FF0000']
    correctness = [correct, incorrect]
    correctness_labels = ['Correct', 'Incorrect']

    plt.figure(figsize=(12, 6))
    plt.pie(correctness, labels=['Correct', 'incorrect'], labeldistance=None, autopct=auto_percent, startangle=0, colors=colors)
    plt.legend(correctness_labels, loc='best', bbox_to_anchor=(1.05, 1))
    plt.title('Model Correctness (Directionality)')
    plt.axis('equal')
    plt.show()

# %%
# plots the tolerance chart (how close the price was to gt price)
def plot_pie_tolerance(tolerance_percent: int, under: int, over: int):
    colors=['#00FF00', '#FF0000']
    under_over = [under, over]
    under_over_labels = ['Under', 'Over']

    plt.figure(figsize=(12, 6))
    plt.pie(under_over, labels=under_over_labels, labeldistance=None, autopct=auto_percent, startangle=0, colors=colors)
    plt.legend(under_over_labels, loc='best', bbox_to_anchor=(1.05, 1))
    plt.title('Model Tolerance (%' + str(tolerance_percent) + ')')
    plt.axis('equal')
    plt.show()

# %% [markdown]
# # The entire program

# %%
ticker = 'QQQ'
target_col = 'Close'
filepath = 'data/ta_stock_data_' + ticker + '.csv'   # use 'ta_stock_data_TICKER.csv' for technical analysis, or 'ps_stock_data_TICKER.csv' for parallel stock.
columns_to_keep = [
    'Date',                                     # always keep the dates
    'Open', 'High', 'Low', 'Close', 'Volume',   # OHLCV - probably do not want to exclude
    #'rsi', 'macd', 'macd_signal', 'bbands_upper', 'bbands_middle', 'bbands_lower',  # TA - optional
    #'obv', 'adx', 'adx_pos', 'adx_neg', 'adi', 
    #'ema_50', 'sma_50'
    ]

train_data_percent = 0.9        # data split between train/validation and test      TrV <-> Te
train_validation_split = 0.9    # data split between train and validation           Tr <-> V
sliding_window_size = 5         # number of lags used as input, applied for every feature
tolerance_percent = 2           # percent used to accept a prediction as 'correct', after accounting for direction

# *** A Note on Train Validation Split for Stocks ***
#   There is a chance that, due to a stock price rising over the course of its history, the model may not be able to account for all possible input values.
#   Example: SPY has consistently gone up, and the model gets trained on the first 5 years of its history. 
#   After that, the inputs will undoubtedly be larger than the model expects, so its predictions are quite unstable.
#   The ideal training data contains the highest price recorded in the stock's history.

df, start_date, end_date = get_stock_data_and_period_csv(filepath)
df = df[columns_to_keep]

df
# Out:
# Time Period: 2014-07-30 to 2023-10-24
#             Date        Open        High         Low       Close    Volume
# 0     2014-07-30   97.139999   97.320000   96.599998   96.980003  35348500
# 1     2014-07-31   96.180000   96.339996   94.879997   95.019997  50047900
# 2     2014-08-01   94.820000   95.339996   94.040001   94.669998  60708000
# 3     2014-08-04   94.870003   95.690002   94.519997   95.320000  33230500
# 4     2014-08-05   94.940002   95.209999   94.150002   94.589996  50331100
# ...          ...         ...         ...         ...         ...       ...
# 2321  2023-10-18  365.670013  367.910004  362.019989  363.369995  54280500
# 2322  2023-10-19  364.809998  366.019989  359.160004  359.970001  72274200
# 2323  2023-10-20  359.459991  360.040009  354.369995  354.600006  72369800
# 2324  2023-10-23  353.260010  359.260010  351.119995  355.670013  60665200
# 2325  2023-10-24  357.510010  359.910004  355.790009  359.130005  47082100
#
# [2326 rows x 6 columns]

# %%
df_copy = dataframe_copy(df)
df = dataframe_clean(df)
dataframe_stats(df)

df
# Out:
# (2326, 5)
# Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64
#             Open        High         Low       Close    Volume
# 0      97.139999   97.320000   96.599998   96.980003  35348500
# 1      96.180000   96.339996   94.879997   95.019997  50047900
# 2      94.820000   95.339996   94.040001   94.669998  60708000
# 3      94.870003   95.690002   94.519997   95.320000  33230500
# 4      94.940002   95.209999   94.150002   94.589996  50331100
# ...          ...         ...         ...         ...       ...
# 2321  365.670013  367.910004  362.019989  363.369995  54280500
# 2322  364.809998  366.019989  359.160004  359.970001  72274200
# 2323  359.459991  360.040009  354.369995  354.600006  72369800
# 2324  353.260010  359.260010  351.119995  355.670013  60665200
# 2325  357.510010  359.910004  355.790009  359.130005  47082100
#
# [2326 rows x 5 columns]

# %%
df = set_column_as_first(df, col_name=target_col)

df
# Out:
#            Close        High         Low        Open    Volume
# 0      96.980003   97.320000   96.599998   97.139999  35348500
# 1      95.019997   96.339996   94.879997   96.180000  50047900
# 2      94.669998   95.339996   94.040001   94.820000  60708000
# 3      95.320000   95.690002   94.519997   94.870003  33230500
# 4      94.589996   95.209999   94.150002   94.940002  50331100
# ...          ...         ...         ...         ...       ...
# 2321  363.369995  367.910004  362.019989  365.670013  54280500
# 2322  359.970001  366.019989  359.160004  364.809998  72274200
# 2323  354.600006  360.040009  354.369995  359.459991  72369800
# 2324  355.670013  359.260010  351.119995  353.260010  60665200
# 2325  359.130005  359.910004  355.790009  357.510010  47082100
#
# [2326 rows x 5 columns]

# %%
scaler = scaler_fit_column(df, target=target_col)
df = transform_data(df)

df
# Out:
#          Close      High       Low      Open    Volume
# 0     0.016624  0.014994  0.037314  0.021323  0.147538
# 1     0.010346  0.011894  0.031903  0.018277  0.224254
# 2     0.009225  0.008731  0.029260  0.013962  0.279890
# 3     0.011307  0.009838  0.030770  0.014120  0.136484
# 4     0.008969  0.008319  0.029606  0.014342  0.225732
# ...        ...       ...       ...       ...       ...
# 2321  0.869891  0.870939  0.872389  0.873394  0.246344
# 2322  0.859001  0.864961  0.863390  0.870665  0.340254
# 2323  0.841800  0.846044  0.848320  0.853689  0.340753
# 2324  0.845227  0.843577  0.838095  0.834016  0.279666
# 2325  0.856310  0.845633  0.852788  0.847501  0.208776
#
# [2326 rows x 5 columns]

# %%
features, target = get_features_and_target(df, target=target_col)

print(features.shape)
print(target.shape)
# Out:
# (2326, 5)
# (2326, 1)

# %%
features
# Out:
#          Close      High       Low      Open    Volume
# 0     0.016624  0.014994  0.037314  0.021323  0.147538
# 1     0.010346  0.011894  0.031903  0.018277  0.224254
# 2     0.009225  0.008731  0.029260  0.013962  0.279890
# 3     0.011307  0.009838  0.030770  0.014120  0.136484
# 4     0.008969  0.008319  0.029606  0.014342  0.225732
# ...        ...       ...       ...       ...       ...
# 2321  0.869891  0.870939  0.872389  0.873394  0.246344
# 2322  0.859001  0.864961  0.863390  0.870665  0.340254
# 2323  0.841800  0.846044  0.848320  0.853689  0.340753
# 2324  0.845227  0.843577  0.838095  0.834016  0.279666
# 2325  0.856310  0.845633  0.852788  0.847501  0.208776
#
# [2326 rows x 5 columns]

# %%
target
# Out:
#          Close
# 0     0.016624
# 1     0.010346
# 2     0.009225
# 3     0.011307
# 4     0.008969
# ...        ...
# 2321  0.869891
# 2322  0.859001
# 2323  0.841800
# 2324  0.845227
# 2325  0.856310
#
# [2326 rows x 1 columns]

# %%
train_x, train_y, train_data_len = setup_train_data(features, target, train_data_percent)
x_train_sw, y_train_sw = prepare_train_as_sliding_window(train_x, train_y, sliding_window_size)

print(train_x.shape)
print(train_y.shape)
print(train_data_len)
print(x_train_sw.shape)
print(y_train_sw.shape)
# Out:
# (2094, 5)
# (2094, 1)
# 2094
# (2089, 5, 5)
# (2089, 1)

# %%
test_x, test_y = setup_test_data(features, target, train_data_len)
x_test_sw, y_test_sw, y_remaining = prepare_test_as_sliding_window(test_x, test_y, sliding_window_size)

print(test_x.shape)
print(test_y.shape)
print(x_test_sw.shape)
print(y_test_sw.shape)
print(y_remaining.shape)
# Out:
# (232, 5)
# (232, 1)
# (227, 5, 5)
# (227, 1)
# (227, 1, 4)

# %%
model = build_model(
    x_train_sw, 
    sliding_window_size,
    head_size=64,      # head size of multi-head attention of transformer encoder blocks            # low impact on training time
    num_heads=16,        # number of heads in multi-head attention of transformer encoder blocks     # low impact on training time
    ff_dim=4,           # number of filters in conv1d of transformer encoder blocks                 # medium impact on training time
    num_transformer_blocks=4,   # number of transformer encoder blocks                              # HIGH impact on training time
    mlp_units=64,      # number of mlp units                                                       # low impact on training time
    mlp_dropout=0.2,    # dropout of mlp units                                                      # reduces overfitting
    dropout=0.2         # dropout of multi-head attention transformer encoder blocks                # reduces overfitting
    )
model = compile_model(model, learning_rate=0.0001)

# %%
# the best model trains fast, achieves small validation loss, and scores a low RMSE value.
model, history = train_model(model, get_model_callbacks(), x_train_sw, y_train_sw, train_validation_split, epochs=200, batch_size=128)

# in general, a val_loss of ~0.00100 (or below) is usually an indicator that the model will perform well on training (~0.02 RMSE). Of course, it varies with luck.
evaluate_model(model, x_test_sw, y_test_sw)
# Out:
# Epoch 1/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0865 - mse: 0.0865 - mae: 0.2284 - mape: 35142.6875
# Epoch 1: val_loss improved from inf to 0.04648, saving model to best_weights.h5
# 15/15 [==============================] - 5s 100ms/step - loss: 0.0865 - mse: 0.0865 - mae: 0.2284 - mape: 35142.6875 - val_loss: 0.0465 - val_mse: 0.0465 - val_mae: 0.2018 - val_mape: 28.0716
# Epoch 2/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0489 - mse: 0.0489 - mae: 0.1615 - mape: 131918.7188
# Epoch 2: val_loss improved from 0.04648 to 0.02780, saving model to best_weights.h5
# 15/15 [==============================] - 1s 57ms/step - loss: 0.0488 - mse: 0.0488 - mae: 0.1617 - mape: 125749.1094 - val_loss: 0.0278 - val_mse: 0.0278 - val_mae: 0.1458 - val_mape: 20.0109
# Epoch 3/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0402 - mse: 0.0402 - mae: 0.1445 - mape: 19878.9922
# Epoch 3: val_loss improved from 0.02780 to 0.02471, saving model to best_weights.h5
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0402 - mse: 0.0402 - mae: 0.1445 - mape: 19878.9922 - val_loss: 0.0247 - val_mse: 0.0247 - val_mae: 0.1353 - val_mape: 18.5815
# Epoch 4/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0319 - mse: 0.0319 - mae: 0.1294 - mape: 17423.0723
# Epoch 4: val_loss improved from 0.02471 to 0.02315, saving model to best_weights.h5
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0319 - mse: 0.0319 - mae: 0.1294 - mape: 17423.0723 - val_loss: 0.0231 - val_mse: 0.0231 - val_mae: 0.1305 - val_mape: 17.9864
# Epoch 5/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0296 - mse: 0.0296 - mae: 0.1255 - mape: 61455.9570
# Epoch 5: val_loss improved from 0.02315 to 0.01934, saving model to best_weights.h5
# 15/15 [==============================] - 1s 57ms/step - loss: 0.0296 - mse: 0.0296 - mae: 0.1255 - mape: 61455.9570 - val_loss: 0.0193 - val_mse: 0.0193 - val_mae: 0.1164 - val_mape: 16.1505
# Epoch 6/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0255 - mse: 0.0255 - mae: 0.1177 - mape: 95.4866
# Epoch 6: val_loss improved from 0.01934 to 0.01709, saving model to best_weights.h5
# 15/15 [==============================] - 1s 64ms/step - loss: 0.0257 - mse: 0.0257 - mae: 0.1184 - mape: 43895.3203 - val_loss: 0.0171 - val_mse: 0.0171 - val_mae: 0.1083 - val_mape: 15.1196
# Epoch 7/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0249 - mse: 0.0249 - mae: 0.1152 - mape: 21426.3535
# Epoch 7: val_loss improved from 0.01709 to 0.01150, saving model to best_weights.h5
# 15/15 [==============================] - 1s 71ms/step - loss: 0.0249 - mse: 0.0249 - mae: 0.1152 - mape: 21426.3535 - val_loss: 0.0115 - val_mse: 0.0115 - val_mae: 0.0853 - val_mape: 11.7489
# Epoch 8/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0243 - mse: 0.0243 - mae: 0.1131 - mape: 46058.3906
# Epoch 8: val_loss did not improve from 0.01150
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0243 - mse: 0.0243 - mae: 0.1131 - mape: 46058.3906 - val_loss: 0.0139 - val_mse: 0.0139 - val_mae: 0.1003 - val_mape: 13.8361
# Epoch 9/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0217 - mse: 0.0217 - mae: 0.1087 - mape: 75952.6953
# Epoch 9: val_loss did not improve from 0.01150
# 15/15 [==============================] - 1s 48ms/step - loss: 0.0217 - mse: 0.0217 - mae: 0.1087 - mape: 75952.6953 - val_loss: 0.0130 - val_mse: 0.0130 - val_mae: 0.0983 - val_mape: 13.5005
# Epoch 10/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0209 - mse: 0.0209 - mae: 0.1062 - mape: 5726.6704
# Epoch 10: val_loss improved from 0.01150 to 0.00856, saving model to best_weights.h5
# 15/15 [==============================] - 1s 65ms/step - loss: 0.0209 - mse: 0.0209 - mae: 0.1062 - mape: 5726.6704 - val_loss: 0.0086 - val_mse: 0.0086 - val_mae: 0.0748 - val_mape: 10.1606
# Epoch 11/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0179 - mse: 0.0179 - mae: 0.0998 - mape: 22544.6934
# Epoch 11: val_loss improved from 0.00856 to 0.00816, saving model to best_weights.h5
# 15/15 [==============================] - 1s 62ms/step - loss: 0.0178 - mse: 0.0178 - mae: 0.0997 - mape: 21492.5977 - val_loss: 0.0082 - val_mse: 0.0082 - val_mae: 0.0739 - val_mape: 10.0443
# Epoch 12/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0187 - mse: 0.0187 - mae: 0.0995 - mape: 73477.0078
# Epoch 12: val_loss did not improve from 0.00816
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0187 - mse: 0.0187 - mae: 0.0995 - mape: 73477.0078 - val_loss: 0.0089 - val_mse: 0.0089 - val_mae: 0.0782 - val_mape: 10.6904
# Epoch 13/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0194 - mse: 0.0194 - mae: 0.1018 - mape: 27582.0254
# Epoch 13: val_loss improved from 0.00816 to 0.00691, saving model to best_weights.h5
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0192 - mse: 0.0192 - mae: 0.1015 - mape: 26294.3613 - val_loss: 0.0069 - val_mse: 0.0069 - val_mae: 0.0660 - val_mape: 8.9364
# Epoch 14/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0174 - mse: 0.0174 - mae: 0.0957 - mape: 21137.9375
# Epoch 14: val_loss improved from 0.00691 to 0.00633, saving model to best_weights.h5
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0174 - mse: 0.0174 - mae: 0.0957 - mape: 21137.9375 - val_loss: 0.0063 - val_mse: 0.0063 - val_mae: 0.0601 - val_mape: 8.1902
# Epoch 15/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0158 - mse: 0.0158 - mae: 0.0913 - mape: 84004.4375
# Epoch 15: val_loss improved from 0.00633 to 0.00616, saving model to best_weights.h5
# 15/15 [==============================] - 1s 58ms/step - loss: 0.0159 - mse: 0.0159 - mae: 0.0919 - mape: 80074.7734 - val_loss: 0.0062 - val_mse: 0.0062 - val_mae: 0.0592 - val_mape: 8.0758
# Epoch 16/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0152 - mse: 0.0152 - mae: 0.0916 - mape: 42591.1797
# Epoch 16: val_loss did not improve from 0.00616
# 15/15 [==============================] - 1s 58ms/step - loss: 0.0151 - mse: 0.0151 - mae: 0.0909 - mape: 40599.8555 - val_loss: 0.0084 - val_mse: 0.0084 - val_mae: 0.0755 - val_mape: 10.3824
# Epoch 17/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0150 - mse: 0.0150 - mae: 0.0887 - mape: 17770.2285
# Epoch 17: val_loss improved from 0.00616 to 0.00566, saving model to best_weights.h5
# 15/15 [==============================] - 1s 59ms/step - loss: 0.0150 - mse: 0.0150 - mae: 0.0887 - mape: 17770.2285 - val_loss: 0.0057 - val_mse: 0.0057 - val_mae: 0.0603 - val_mape: 8.2372
# Epoch 18/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0132 - mse: 0.0132 - mae: 0.0836 - mape: 23252.3086
# Epoch 18: val_loss improved from 0.00566 to 0.00311, saving model to best_weights.h5
# 15/15 [==============================] - 1s 57ms/step - loss: 0.0132 - mse: 0.0132 - mae: 0.0833 - mape: 22167.1660 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0404 - val_mape: 5.5255
# Epoch 19/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0135 - mse: 0.0135 - mae: 0.0844 - mape: 75601.8516
# Epoch 19: val_loss did not improve from 0.00311
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0135 - mse: 0.0135 - mae: 0.0842 - mape: 72065.8359 - val_loss: 0.0041 - val_mse: 0.0041 - val_mae: 0.0492 - val_mape: 6.6994
# Epoch 20/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0129 - mse: 0.0129 - mae: 0.0843 - mape: 29417.2070
# Epoch 20: val_loss did not improve from 0.00311
# 15/15 [==============================] - 1s 60ms/step - loss: 0.0129 - mse: 0.0129 - mae: 0.0843 - mape: 29417.2070 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0425 - val_mape: 5.7858
# Epoch 21/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0126 - mse: 0.0126 - mae: 0.0817 - mape: 33058.5352
# Epoch 21: val_loss did not improve from 0.00311
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0129 - mse: 0.0129 - mae: 0.0826 - mape: 31514.0156 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0539 - val_mape: 7.3583
# Epoch 22/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0132 - mse: 0.0132 - mae: 0.0846 - mape: 28205.5859
# Epoch 22: val_loss did not improve from 0.00311
# 15/15 [==============================] - 1s 48ms/step - loss: 0.0132 - mse: 0.0132 - mae: 0.0846 - mape: 28205.5859 - val_loss: 0.0044 - val_mse: 0.0044 - val_mae: 0.0529 - val_mape: 7.3161
# Epoch 23/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0114 - mse: 0.0114 - mae: 0.0801 - mape: 1957.3098
# Epoch 23: val_loss improved from 0.00311 to 0.00254, saving model to best_weights.h5
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0114 - mse: 0.0114 - mae: 0.0801 - mape: 1957.3098 - val_loss: 0.0025 - val_mse: 0.0025 - val_mae: 0.0357 - val_mape: 4.9406
# Epoch 24/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0120 - mse: 0.0120 - mae: 0.0798 - mape: 13593.6436
# Epoch 24: val_loss did not improve from 0.00254
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0120 - mse: 0.0120 - mae: 0.0798 - mape: 13593.6436 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0423 - val_mape: 5.8322
# Epoch 25/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0118 - mse: 0.0118 - mae: 0.0795 - mape: 7183.7095
# Epoch 25: val_loss improved from 0.00254 to 0.00225, saving model to best_weights.h5
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0118 - mse: 0.0118 - mae: 0.0795 - mape: 7183.7095 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0342 - val_mape: 4.8838
# Epoch 26/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0114 - mse: 0.0114 - mae: 0.0765 - mape: 26983.8066
# Epoch 26: val_loss improved from 0.00225 to 0.00200, saving model to best_weights.h5
# 15/15 [==============================] - 1s 66ms/step - loss: 0.0114 - mse: 0.0114 - mae: 0.0765 - mape: 26983.8066 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0331 - val_mape: 4.7607
# Epoch 27/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0101 - mse: 0.0101 - mae: 0.0740 - mape: 51931.1211
# Epoch 27: val_loss improved from 0.00200 to 0.00182, saving model to best_weights.h5
# 15/15 [==============================] - 1s 58ms/step - loss: 0.0102 - mse: 0.0102 - mae: 0.0742 - mape: 49503.1523 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0318 - val_mape: 4.4429
# Epoch 28/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0102 - mse: 0.0102 - mae: 0.0735 - mape: 55830.0352
# Epoch 28: val_loss did not improve from 0.00182
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0101 - mse: 0.0101 - mae: 0.0731 - mape: 53218.8398 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0344 - val_mape: 5.0256
# Epoch 29/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0110 - mse: 0.0110 - mae: 0.0753 - mape: 25606.0391
# Epoch 29: val_loss did not improve from 0.00182
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0110 - mse: 0.0110 - mae: 0.0753 - mape: 25606.0391 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0331 - val_mape: 4.7665
# Epoch 30/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0097 - mse: 0.0097 - mae: 0.0712 - mape: 28230.6465
# Epoch 30: val_loss did not improve from 0.00182
# 15/15 [==============================] - 1s 59ms/step - loss: 0.0097 - mse: 0.0097 - mae: 0.0712 - mape: 28230.6465 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0349 - val_mape: 5.1046
# Epoch 31/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0104 - mse: 0.0104 - mae: 0.0735 - mape: 416.7968
# Epoch 31: val_loss did not improve from 0.00182
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0103 - mse: 0.0103 - mae: 0.0733 - mape: 399.9100 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0381 - val_mape: 5.5428
# Epoch 32/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0097 - mse: 0.0097 - mae: 0.0728 - mape: 34596.9492
# Epoch 32: val_loss improved from 0.00182 to 0.00159, saving model to best_weights.h5
# 15/15 [==============================] - 1s 60ms/step - loss: 0.0097 - mse: 0.0097 - mae: 0.0727 - mape: 32980.7031 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0307 - val_mape: 4.3930
# Epoch 33/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0096 - mse: 0.0096 - mae: 0.0708 - mape: 31973.7168
# Epoch 33: val_loss did not improve from 0.00159
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0097 - mse: 0.0097 - mae: 0.0711 - mape: 30480.7285 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0322 - val_mape: 4.4867
# Epoch 34/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0110 - mse: 0.0110 - mae: 0.0774 - mape: 45203.5039
# Epoch 34: val_loss did not improve from 0.00159
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0110 - mse: 0.0110 - mae: 0.0774 - mape: 45203.5039 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0313 - val_mape: 4.3781
# Epoch 35/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0098 - mse: 0.0098 - mae: 0.0723 - mape: 7761.6382
# Epoch 35: val_loss did not improve from 0.00159
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0099 - mse: 0.0099 - mae: 0.0727 - mape: 7402.0645 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0360 - val_mape: 5.3030
# Epoch 36/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0093 - mse: 0.0093 - mae: 0.0708 - mape: 38318.4883
# Epoch 36: val_loss did not improve from 0.00159
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0093 - mse: 0.0093 - mae: 0.0706 - mape: 36528.2891 - val_loss: 0.0035 - val_mse: 0.0035 - val_mae: 0.0502 - val_mape: 7.4124
# Epoch 37/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0093 - mse: 0.0093 - mae: 0.0713 - mape: 9944.1904
# Epoch 37: val_loss did not improve from 0.00159
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0093 - mse: 0.0093 - mae: 0.0713 - mape: 9944.1904 - val_loss: 0.0024 - val_mse: 0.0024 - val_mae: 0.0384 - val_mape: 5.5700
# Epoch 38/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0082 - mse: 0.0082 - mae: 0.0675 - mape: 13705.8584
# Epoch 38: val_loss improved from 0.00159 to 0.00153, saving model to best_weights.h5
# 15/15 [==============================] - 1s 61ms/step - loss: 0.0082 - mse: 0.0082 - mae: 0.0675 - mape: 13067.0000 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0301 - val_mape: 4.2399
# Epoch 39/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0086 - mse: 0.0086 - mae: 0.0675 - mape: 75109.2500
# Epoch 39: val_loss did not improve from 0.00153
# 15/15 [==============================] - 1s 66ms/step - loss: 0.0086 - mse: 0.0086 - mae: 0.0675 - mape: 75109.2500 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0305 - val_mape: 4.2956
# Epoch 40/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0084 - mse: 0.0084 - mae: 0.0679 - mape: 33032.2031
# Epoch 40: val_loss improved from 0.00153 to 0.00147, saving model to best_weights.h5
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0084 - mse: 0.0084 - mae: 0.0679 - mape: 33032.2031 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0302 - val_mape: 4.2718
# Epoch 41/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0085 - mse: 0.0085 - mae: 0.0680 - mape: 5898.8467
# Epoch 41: val_loss did not improve from 0.00147
# 15/15 [==============================] - 1s 48ms/step - loss: 0.0085 - mse: 0.0085 - mae: 0.0680 - mape: 5898.8467 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0311 - val_mape: 4.3709
# Epoch 42/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0079 - mse: 0.0079 - mae: 0.0658 - mape: 62862.4297
# Epoch 42: val_loss improved from 0.00147 to 0.00146, saving model to best_weights.h5
# 15/15 [==============================] - 1s 65ms/step - loss: 0.0080 - mse: 0.0080 - mae: 0.0657 - mape: 59922.4922 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0304 - val_mape: 4.2876
# Epoch 43/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0089 - mse: 0.0089 - mae: 0.0676 - mape: 30062.5723
# Epoch 43: val_loss improved from 0.00146 to 0.00140, saving model to best_weights.h5
# 15/15 [==============================] - 1s 77ms/step - loss: 0.0089 - mse: 0.0089 - mae: 0.0676 - mape: 30062.5723 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0298 - val_mape: 4.3066
# Epoch 44/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0071 - mse: 0.0071 - mae: 0.0615 - mape: 37804.5352
# Epoch 44: val_loss did not improve from 0.00140
# 15/15 [==============================] - 1s 68ms/step - loss: 0.0070 - mse: 0.0070 - mae: 0.0608 - mape: 36037.6172 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0301 - val_mape: 4.2569
# Epoch 45/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0086 - mse: 0.0086 - mae: 0.0677 - mape: 102290.4844
# Epoch 45: val_loss did not improve from 0.00140
# 15/15 [==============================] - 1s 58ms/step - loss: 0.0086 - mse: 0.0086 - mae: 0.0677 - mape: 102290.4844 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0451 - val_mape: 6.2690
# Epoch 46/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0083 - mse: 0.0083 - mae: 0.0671 - mape: 36884.9961
# Epoch 46: val_loss improved from 0.00140 to 0.00126, saving model to best_weights.h5
# 15/15 [==============================] - 1s 58ms/step - loss: 0.0083 - mse: 0.0083 - mae: 0.0671 - mape: 36884.9961 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0286 - val_mape: 4.1398
# Epoch 47/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0075 - mse: 0.0075 - mae: 0.0630 - mape: 85195.4922
# Epoch 47: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 64ms/step - loss: 0.0075 - mse: 0.0075 - mae: 0.0630 - mape: 85195.4922 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0312 - val_mape: 4.3936
# Epoch 48/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0072 - mse: 0.0072 - mae: 0.0622 - mape: 81834.6641
# Epoch 48: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 47ms/step - loss: 0.0072 - mse: 0.0072 - mae: 0.0622 - mape: 81834.6641 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0285 - val_mape: 4.0965
# Epoch 49/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0070 - mse: 0.0070 - mae: 0.0606 - mape: 1866.8370
# Epoch 49: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 48ms/step - loss: 0.0071 - mse: 0.0071 - mae: 0.0611 - mape: 1781.8958 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0294 - val_mape: 4.2743
# Epoch 50/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0072 - mse: 0.0072 - mae: 0.0601 - mape: 11003.8027
# Epoch 50: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0072 - mse: 0.0072 - mae: 0.0601 - mape: 11003.8027 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0305 - val_mape: 4.4706
# Epoch 51/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0064 - mse: 0.0064 - mae: 0.0595 - mape: 33138.8086
# Epoch 51: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0064 - mse: 0.0064 - mae: 0.0595 - mape: 33138.8086 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0295 - val_mape: 4.2624
# Epoch 52/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0069 - mse: 0.0069 - mae: 0.0609 - mape: 27971.5938
# Epoch 52: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0069 - mse: 0.0069 - mae: 0.0609 - mape: 27971.5938 - val_loss: 0.0023 - val_mse: 0.0023 - val_mae: 0.0388 - val_mape: 5.8157
# Epoch 53/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0065 - mse: 0.0065 - mae: 0.0591 - mape: 28145.1035
# Epoch 53: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0065 - mse: 0.0065 - mae: 0.0593 - mape: 26829.2559 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0289 - val_mape: 4.2218
# Epoch 54/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0068 - mse: 0.0068 - mae: 0.0592 - mape: 13764.5908
# Epoch 54: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 49ms/step - loss: 0.0068 - mse: 0.0068 - mae: 0.0592 - mape: 13764.5908 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0323 - val_mape: 4.7664
# Epoch 55/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0064 - mse: 0.0064 - mae: 0.0590 - mape: 26508.9629
# Epoch 55: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0064 - mse: 0.0064 - mae: 0.0590 - mape: 26508.9629 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0293 - val_mape: 4.2024
# Epoch 56/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0062 - mse: 0.0062 - mae: 0.0575 - mape: 42283.7070
# Epoch 56: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0064 - mse: 0.0064 - mae: 0.0579 - mape: 40306.7891 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0309 - val_mape: 4.4018
# Epoch 57/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0063 - mse: 0.0063 - mae: 0.0582 - mape: 80733.8203
# Epoch 57: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 46ms/step - loss: 0.0064 - mse: 0.0064 - mae: 0.0583 - mape: 76956.7578 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0303 - val_mape: 4.3895
# Epoch 58/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0069 - mse: 0.0069 - mae: 0.0593 - mape: 33475.3086
# Epoch 58: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 62ms/step - loss: 0.0069 - mse: 0.0069 - mae: 0.0593 - mape: 33475.3086 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0295 - val_mape: 4.2486
# Epoch 59/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0066 - mse: 0.0066 - mae: 0.0581 - mape: 57904.1289
# Epoch 59: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0067 - mse: 0.0067 - mae: 0.0583 - mape: 55195.8398 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0288 - val_mape: 4.1793
# Epoch 60/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0060 - mse: 0.0060 - mae: 0.0564 - mape: 72504.9141
# Epoch 60: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 45ms/step - loss: 0.0060 - mse: 0.0060 - mae: 0.0564 - mape: 72504.9141 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0294 - val_mape: 4.2680
# Epoch 61/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0059 - mse: 0.0059 - mae: 0.0557 - mape: 37007.1523
# Epoch 61: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 45ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0557 - mape: 37007.1523 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0294 - val_mape: 4.2777
# Epoch 62/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0057 - mse: 0.0057 - mae: 0.0541 - mape: 2769.9194
# Epoch 62: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 46ms/step - loss: 0.0057 - mse: 0.0057 - mae: 0.0541 - mape: 2769.9194 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0317 - val_mape: 4.6746
# Epoch 63/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0061 - mse: 0.0061 - mae: 0.0571 - mape: 22901.4707
# Epoch 63: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 48ms/step - loss: 0.0061 - mse: 0.0061 - mae: 0.0571 - mape: 22901.4707 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0361 - val_mape: 5.3949
# Epoch 64/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0062 - mse: 0.0062 - mae: 0.0563 - mape: 42634.9531
# Epoch 64: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 60ms/step - loss: 0.0062 - mse: 0.0062 - mae: 0.0563 - mape: 42634.9531 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0293 - val_mape: 4.2799
# Epoch 65/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0059 - mse: 0.0059 - mae: 0.0547 - mape: 36592.8164
# Epoch 65: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 46ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0547 - mape: 36592.8164 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0313 - val_mape: 4.5971
# Epoch 66/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0054 - mse: 0.0054 - mae: 0.0536 - mape: 27942.7305
# Epoch 66: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 80ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0536 - mape: 27942.7305 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0291 - val_mape: 4.2238
# Epoch 67/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0055 - mse: 0.0055 - mae: 0.0536 - mape: 3626.9626
# Epoch 67: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 45ms/step - loss: 0.0055 - mse: 0.0055 - mae: 0.0536 - mape: 3626.9626 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0337 - val_mape: 4.9625
# Epoch 68/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0063 - mse: 0.0063 - mae: 0.0574 - mape: 35554.3555
# Epoch 68: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 66ms/step - loss: 0.0062 - mse: 0.0062 - mae: 0.0568 - mape: 33892.0273 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0316 - val_mape: 4.6680
# Epoch 69/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0058 - mse: 0.0058 - mae: 0.0550 - mape: 6031.8901
# Epoch 69: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 62ms/step - loss: 0.0058 - mse: 0.0058 - mae: 0.0550 - mape: 6031.8901 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0299 - val_mape: 4.3932
# Epoch 70/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0059 - mse: 0.0059 - mae: 0.0546 - mape: 30824.7754
# Epoch 70: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 45ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0546 - mape: 30824.7754 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0328 - val_mape: 4.8610
# Epoch 71/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0056 - mse: 0.0056 - mae: 0.0541 - mape: 24120.3730
# Epoch 71: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 45ms/step - loss: 0.0056 - mse: 0.0056 - mae: 0.0541 - mape: 24120.3730 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0288 - val_mape: 4.1476
# Epoch 72/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0053 - mse: 0.0053 - mae: 0.0525 - mape: 13819.8760
# Epoch 72: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 64ms/step - loss: 0.0053 - mse: 0.0053 - mae: 0.0525 - mape: 13819.8760 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0307 - val_mape: 4.4966
# Epoch 73/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0053 - mse: 0.0053 - mae: 0.0525 - mape: 8876.4541
# Epoch 73: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 48ms/step - loss: 0.0053 - mse: 0.0053 - mae: 0.0525 - mape: 8876.4541 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0294 - val_mape: 4.2249
# Epoch 74/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0050 - mse: 0.0050 - mae: 0.0517 - mape: 31596.1816
# Epoch 74: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 46ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0517 - mape: 31596.1816 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0325 - val_mape: 4.7989
# Epoch 75/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0050 - mse: 0.0050 - mae: 0.0513 - mape: 19597.1035
# Epoch 75: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 49ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0513 - mape: 19597.1035 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0310 - val_mape: 4.4659
# Epoch 76/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0058 - mse: 0.0058 - mae: 0.0542 - mape: 62958.8867
# Epoch 76: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 58ms/step - loss: 0.0058 - mse: 0.0058 - mae: 0.0542 - mape: 62958.8867 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0292 - val_mape: 4.2774
# Epoch 77/200
# 15/15 [==============================] - ETA: 0s - loss: 0.0051 - mse: 0.0051 - mae: 0.0506 - mape: 28917.8125
# Epoch 77: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 63ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0506 - mape: 28917.8125 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0338 - val_mape: 4.9694
# Epoch 78/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0050 - mse: 0.0050 - mae: 0.0513 - mape: 15558.1172
# Epoch 78: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0515 - mape: 14831.4160 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0296 - val_mape: 4.2982
# Epoch 79/200
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0049 - mse: 0.0049 - mae: 0.0508 - mape: 35604.4727
# Epoch 79: val_loss did not improve from 0.00126
# 15/15 [==============================] - 1s 77ms/step - loss: 0.0049 - mse: 0.0049 - mae: 0.0508 - mape: 33939.3320 - val_loss: 0.0026 - val_mse: 0.0026 - val_mae: 0.0406 - val_mape: 6.0576
# 8/8 [==============================] - 0s 25ms/step - loss: 5.2097e-04 - mse: 5.2097e-04 - mae: 0.0180 - mape: 2.4498

# %%
predicted_values = perform_model_predictions(model, x_test_sw, y_remaining)
# Out:
# 1/1 [==============================] - 0s 24ms/step

# %%
gt_scaled = scaler.inverse_transform(y_test_sw)
pred_scaled = scaler.inverse_transform(predicted_values[:-1])

print('RMSE ($ unscaled): ' + str(calculate_rmse(y_test_sw, predicted_values[:-1])))  # average AMOUNT (unscaled) the predictions are away from ground truth
print('RMSE ($): ' + str(calculate_rmse(gt_scaled, pred_scaled))) # average AMOUNT (in $) the predictions are away from ground truth
print('MAPE (%): ' + str(calculate_mape(y_test_sw, predicted_values[:-1]))) # average PERCENTAGE the predictions are away from ground truth
# Out:
# RMSE ($ unscaled): 0.04799432236630606
# RMSE ($): 14.983829254828516
# MAPE (%): 0.04905194119174698

# %%
predicted_x_axis, ground_truth_x_axis = prepare_x_axis_prediction_ground_truth(y_train_sw, y_test_sw, predicted_values)
print(ground_truth_x_axis.size)
# Out:
# 2316

# %%
gt_value = scaler.inverse_transform([y_test_sw[-1]])[0][0].round(2)
print(ticker + ' ' + target_col + ' for today is $' + str(gt_value))
adjusted_pred = calculate_adjusted_prediction(scaler, predicted_values, y_test_sw)
percent_difference = abs((adjusted_pred - gt_value) * 100 / (gt_value)).round(2)
plus_or_minus = '+' if adjusted_pred > gt_value else '-'

print('This represents ' + plus_or_minus + str(percent_difference) + '% difference from todays ' + target_col)
# Out:
# QQQ Close for today is $359.13
# The adjusted final prediction value is $358.32
# This represents -0.23% difference from todays Close

# %%
plot_prediction_vs_gt(scaler, predicted_x_axis, ground_truth_x_axis, start_date, end_date, train_data_len, train_validation_split, sliding_window_size, adjusted_pred, target_col)
plot_loss_chart(history)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_daily_close(df_copy, ticker, start_date, end_date)
plot_daily_returns(df_copy, ticker, start_date, end_date)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
(correct, incorrect, under, over, 
        correct_upwards_under, correct_upwards_over, correct_downwards_under, correct_downwards_over, 
        incorrect_upwards_under, incorrect_upwards_over, incorrect_downwards_under, incorrect_downwards_over
        ) = calculate_pie_chart_values(y_test_sw, predicted_values, tolerance_percent=tolerance_percent)

plot_pie_categories(
        tolerance_percent, 
        correct_upwards_under, correct_downwards_under, incorrect_upwards_under, incorrect_downwards_under, 
        correct_upwards_over, correct_downwards_over, incorrect_upwards_over, incorrect_downwards_over)
plot_pie_correctness(correct, incorrect)
plot_pie_tolerance(tolerance_percent, under, over)
# Out:
# Number of times the model predicted CORRECT direction: 113
# Number of times the model predicted INCORRECT direction: 113
# Number of times the model predicted UNDER 2% tolerance: 54
# Number of times the model predicted OVER 2% tolerance: 172
# Number of times the model CORRECTLY predicted UPWARD movement UNDER 2% tolerance: 17
# Number of times the model CORRECTLY predicted UPWARD movement OVER 2% tolerance: 14
# Number of times the model CORRECTLY predicted DOWNWARD movement UNDER 2% tolerance: 22
# Number of times the model CORRECTLY predicted DOWNWARD movement OVER 2% tolerance: 60
# Number of times the model INCORRECTLY predicted UPWARD movement UNDER 2% tolerance: 5
# Number of times the model INCORRECTLY predicted UPWARD movement OVER 2% tolerance: 21
# Number of times the model INCORRECTLY predicted DOWNWARD movement UNDER 2% tolerance: 10
# Number of times the model INCORRECTLY predicted DOWNWARD movement OVER 2% tolerance: 77
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
